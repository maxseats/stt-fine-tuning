# %%
import os
import json
from pydub import AudioSegment
from tqdm import tqdm
import re
from datasets import Audio, Dataset, DatasetDict
from transformers import WhisperFeatureExtractor, WhisperTokenizer
import pandas as pd

# 사용자 지정 변수를 설정해요.

DATA_DIR = '/mnt/a/maxseats-git/New_Sample' # 데이터셋이 저장된 폴더

# 원천, 라벨링 데이터 폴더 지정
json_base_dir = os.path.join(DATA_DIR, '라벨링데이터')
audio_base_dir = os.path.join(DATA_DIR, '원천데이터')

output_dir = '/mnt/a/maxseats-git/clips'   # 가공된 데이터셋이 저장될 폴더

token = "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"                     # 허깅페이스 토큰

CACHE_DIR = '/mnt/a/maxseats/.cache'                                # 허깅페이스 캐시 저장소 지정

dataset_name = "maxeats/asihub-tensor-test-dataset--tmp"                    # 허깅페이스에 올라갈 데이터셋 이름

model_name = "SungBeom/whisper-small-ko"                            # 대상 모델 / "openai/whisper-base"



'''
데이터셋 경로를 지정해서
하나의 폴더에 mp3, txt 파일로 추출해요.
추출 과정에서 원본 파일은 자동으로 삭제돼요. (저장공간 절약을 위해)
'''

def bracket_preprocess(text):
    
    # 1단계: o/ n/ 글자/ 과 같이. 앞 뒤에 ) ( 가 오지않는 /슬래쉬 는 모두 제거합니다. o,n 이 붙은 경우 해당 글자도 함께 제거합니다.
    text = re.sub(r'\b[o|n]/', '', text)
    text = re.sub(r'[^()]/', '', text)
    
    # 2단계: (70)/(칠십) 과 같은 경우, /슬래쉬 의 앞쪽 괄호의 내용만 남기고 삭제합니다.
    text = re.sub(r'\(([^)]*)\)/\([^)]*\)', r'\1', text)
    
    return text

def process_audio_and_subtitle(json_path, audio_base_dir, output_dir):
    # JSON 파일 읽기
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # 메타데이터에서 오디오 파일 이름 추출
    title = data['metadata']['title']
    
    # 각 TS, VS 폴더에서 해당 오디오 파일을 찾기
    audio_file = None
    for root, _, files in os.walk(audio_base_dir):
        for file in files:
            if file == title + '.wav':
                audio_file = os.path.join(root, file)
                break
        if audio_file:
            break
    
    # 오디오 파일 로드
    if not audio_file or not os.path.exists(audio_file):
        print(f"Audio file {audio_file} does not exist.")
        return
    
    # audio = AudioSegment.from_wav(audio_file)
    audio = AudioSegment.from_mp3(audio_file)
    
    # 발화 데이터 처리
    for utterance in data['utterance']:
        start_time = float(utterance['start']) * 1000  # 밀리초로 변환
        end_time = float(utterance['end']) * 1000      # 밀리초로 변환
        text = utterance['form']
        
        # 오디오 클립 추출
        audio_clip = audio[start_time:end_time]
        
        # 파일 이름 설정
        clip_id = utterance['id']
        audio_output_path = os.path.join(output_dir, clip_id + '.mp3')
        text_output_path = os.path.join(output_dir, clip_id + '.txt')
        
        # 오디오 클립 저장
        audio_clip.export(audio_output_path, format='mp3')
        
        # 괄호 전처리 텍스트 파일 저장
        with open(text_output_path, 'w', encoding='utf-8') as f:
            f.write(bracket_preprocess(text))

    # 오디오 파일 삭제
    os.remove(audio_file)
    os.remove(audio_file.replace('.wav', '.txt'))
    print(f"Deleted audio file: {audio_file}")

def process_all_files(json_base_dir, audio_base_dir, output_dir):
    json_files = []
    
    # JSON 파일 목록 생성
    for root, dirs, files in os.walk(json_base_dir):
        for file in files:
            if file.endswith('.json'):
                json_files.append(os.path.join(root, file))
    
    # JSON 파일 처리
    for json_file in tqdm(json_files, desc="Processing JSON files"):
        process_audio_and_subtitle(json_file, audio_base_dir, output_dir)
        
        # 완료 후 JSON 파일 삭제
        os.remove(json_file)
        print(f"Deleted JSON file: {json_file}")

# 디렉토리 생성
os.makedirs(output_dir, exist_ok=True)

# 프로세스 실행
process_all_files(json_base_dir, audio_base_dir, output_dir)



'''
가공된 mp3, txt 데이터를 학습 가능한 허깅페이스 데이터셋 형태로 변환해요.
'''

# 캐시 디렉토리 설정
os.environ['HF_HOME'] = CACHE_DIR
os.environ["HF_DATASETS_CACHE"] = CACHE_DIR
feature_extractor = WhisperFeatureExtractor.from_pretrained(model_name, cache_dir=CACHE_DIR)
tokenizer = WhisperTokenizer.from_pretrained(model_name, language="Korean", task="transcribe", cache_dir=CACHE_DIR)

def exclude_json_files(file_names: list) -> list:
    # .json으로 끝나는 원소 제거
    return [file_name for file_name in file_names if not file_name.endswith('.json')]


def get_label_list(directory):
    # 빈 리스트 생성
    label_files = []

    # 디렉토리 내 파일 목록 불러오기
    for filename in os.listdir(directory):
        # 파일 이름이 '.txt'로 끝나는지 확인
        if filename.endswith('.txt'):
            label_files.append(os.path.join(directory, filename))

    return label_files


def get_audio_list(directory):
    # 빈 리스트 생성
    audio_files = []

    # 디렉토리 내 파일 목록 불러오기
    for filename in os.listdir(directory):
        # 파일 이름이 '.wav'나 '.mp3'로 끝나는지 확인
        if filename.endswith('.wav') or filename.endswith('mp3'):
            audio_files.append(os.path.join(directory, filename))

    return audio_files

def prepare_dataset(batch):
    # 오디오 파일을 16kHz로 로드
    audio = batch["audio"]

    # input audio array로부터 log-Mel spectrogram 변환
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # target text를 label ids로 변환
    batch["labels"] = tokenizer(batch["transcripts"]).input_ids
    
    # 'input_features'와 'labels'만 포함한 새로운 딕셔너리 생성
    return {"input_features": batch["input_features"], "labels": batch["labels"]}


label_data = get_label_list(output_dir)
audio_data = get_audio_list(output_dir)

transcript_list = []
for label in tqdm(label_data):
    with open(label, 'r', encoding='UTF8') as f:
        line = f.readline()
        transcript_list.append(line)

df = pd.DataFrame(data=transcript_list, columns = ["transcript"]) # 정답 label
df['audio_data'] = audio_data # 오디오 파일 경로

# 오디오 파일 경로를 dict의 "audio" 키의 value로 넣고 이를 데이터셋으로 변환
# 이때, Whisper가 요구하는 사양대로 Sampling rate는 16,000으로 설정한다.


ds = Dataset.from_dict(
    {"audio": [path for path in df["audio_data"]],
     "transcripts": [transcript for transcript in df["transcript"]]}
).cast_column("audio", Audio(sampling_rate=16000))
# Out:
# Processing JSON files: 0it [00:00, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 100%|██████████| 1660/1660 [00:00<00:00, 24996.57it/s]

# %%
# 데이터셋을 훈련 데이터와 테스트 데이터, 밸리데이션 데이터로 분할
train_testvalid = ds.train_test_split(test_size=0.2)
test_valid = train_testvalid["test"].train_test_split(test_size=0.5)
datasets = DatasetDict(
    {"train": train_testvalid["train"],
     "test": test_valid["test"],
     "valid": test_valid["train"]}
)

# %%
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'transcripts'],
#         num_rows: 1328
#     })
#     test: Dataset({
#         features: ['audio', 'transcripts'],
#         num_rows: 166
#     })
#     valid: Dataset({
#         features: ['audio', 'transcripts'],
#         num_rows: 166
#     })
# })

# %%
datasets['train']['audio'][0]
# Out:
# {'path': '/mnt/a/maxseats-git/clips/DGBAH21000195.1.1.602.mp3',
#  'array': array([ 2.94935511e-04,  3.68657988e-04,  4.58460767e-04, ...,
#         -6.29809801e-05, -1.90640858e-05, -1.02568520e-04]),
#  'sampling_rate': 16000}

# %%
datasets['train']['audio'][0]['array']
# Out:
# array([ 2.94935511e-04,  3.68657988e-04,  4.58460767e-04, ...,
#        -6.29809801e-05, -1.90640858e-05, -1.02568520e-04])

# %%
datasets['train']['transcripts'][:5]
# Out:
# ['지금 당신은 어떻습니까 위까지 생각한 발효 (())',
#  '이와같은 거는 특히 청소년층에 대해서 미치는 영향이 상당히 크기 때문에 어~ 청소년 층이 아직 자아가 형성되지 않은 단계에서',
#  '예 우선순위 설정하는 데가 좀 고민이',
#  '그래서 이 만료된 특별법에 있는 내용 중에 우선 급한 대로 한 두 가지를 이 지금 말씀하신 그~ 법에따',
#  '의료 인력에서도 짐 양극화 현상이 심화되구 있거든요 까 고런 것도 이 수가와 연결돼서']

# %%
prepare_dataset(datasets['train'][:2])['train']['transcripts'][:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 prepare_dataset(datasets['train'][:2])['train']['transcripts'][:5]
#
# Cell In[1], line 168, in prepare_dataset(batch)
#     165 audio = batch["audio"]
#     167 # input audio array로부터 log-Mel spectrogram 변환
# --> 168 batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]
#     171 # target text를 label ids로 변환
#     172 batch["labels"] = tokenizer(batch["transcripts"]).input_ids
#
# TypeError: list indices must be integers or slices, not str

# %%
# mp3 파일 별로 array변환 후의 크기를 측정하는 코드에요.

import sys

for i in range(3):
    
    audio = datasets['train']['audio'][i]
    
    # 경로
    mp3_file_path = audio['path']
    
    # 실제 파일 크기
    mp3_size = os.path.getsize(mp3_file_path) / (1024.0)
    
    # 전처리 후 데이터셋의 array 크기
    array_size_mb = audio['array'].nbytes / (1024.0)
    
    
    input_features = feature_extractor(audio['array'], sampling_rate=audio["sampling_rate"]).input_features[0]
    labels = tokenizer(datasets['train']['transcripts'][i]).input_ids
    
    input_featuers_size = sys.getsizeof(input_features) / (1024.0)
    labels_size = sys.getsizeof(labels) / (1024.0)
   
    
    # print(f"{i}번째 데이터: {mp3_file_path}\nMP3 size: {mp3_size:.4f} MB\nArray size: {array_size_mb:.4f} MB\ninput_features size: {input_featuers_size:.4f} MB\nlabels size: {labels_size:.4f} MB\n 전처리 데이터 크기 : {input_featuers_size + labels_size:.4f} MB\n")
    print(f"{i}번째 데이터: {mp3_file_path}\nMP3 size: {mp3_size:.4f} KB\nArray size: {array_size_mb:.4f} KB\ninput_features size: {input_featuers_size:.4f} KB\nlabels size: {labels_size:.4f} KB\n -> 전처리 데이터 크기 : {input_featuers_size + labels_size:.4f} KB\n")
# Out:
# 0번째 데이터: /mnt/a/maxseats-git/clips/DGBAH21000195.1.1.276.mp3
# MP3 size: 11.7158 KB
# Array size: 479.2500 KB
# input_features size: 0.1250 KB
# labels size: 0.3516 KB
#  전처리 데이터 크기 : 0.4766 KB
#
# 1번째 데이터: /mnt/a/maxseats-git/clips/DGBAH21000190.1.1.617.mp3
# MP3 size: 27.3252 KB
# Array size: 1146.6250 KB
# input_features size: 0.1250 KB
# labels size: 0.2891 KB
#  전처리 데이터 크기 : 0.4141 KB
#
# 2번째 데이터: /mnt/a/maxseats-git/clips/DGBAH21000195.1.1.433.mp3
# MP3 size: 17.8330 KB
# Array size: 739.1250 KB
# input_features size: 0.1250 KB
# labels size: 0.3438 KB
#  전처리 데이터 크기 : 0.4688 KB

# %%
# mp3
datasets['train']['audio'][0]['array'].shape
# Out:
# (155936,)

# %%
# wav
datasets['train']['audio'][0]['array'].shape
# Out:
# (172352,)

# %%
datasets = datasets.map(prepare_dataset, num_proc=2)
datasets = datasets.remove_columns(['audio', 'transcripts']) # 불필요한 부분 제거
print('-'*48)
print(type(datasets))
print(datasets)
print('-'*48)


'''
허깅페이스 로그인 후, 최종 데이터셋을 업로드해요.
'''
# datasets.save_to_disk('./preprocessed_cache.arrow')
# datasets.push_to_hub(dataset_name, token=token)

# %%
# 허깅페이스 토큰이 만료되었을 때, 키보드입력으로 받게끔 하는 코드 테스트에요.

from datasets import Dataset, DatasetDict, Audio, load_from_disk
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2Tokenizer
import pandas as pd

# 데이터셋 및 모델 준비
df = pd.DataFrame({
    "audio_data": ["path/to/audio1.mp3", "path/to/audio2.mp3"],  # 실제 MP3 파일 경로로 대체
    "transcript": ["This is a transcript.", "This is another transcript."]
})

# 데이터셋 생성
ds = Dataset.from_dict(
    {"audio": df["audio_data"],
     "transcripts": df["transcript"]}
)


# 데이터셋을 Hugging Face Hub에 업로드
dataset_name = "push-test-tmp"
token = "your_huggingface_api_token"

while True:
    
    if token =="exit":
        break
    
    try:
        ds.push_to_hub(dataset_name, token=token)
        print(f"Dataset {dataset_name} pushed to hub successfully.")
        break
    except Exception as e:
        print(f"Failed to push dataset: {e}")
        token = input("Please enter your Hugging Face API token: ")
# Out:
# Failed to push dataset: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create (Request ID: Root=1-66695a42-57db274943700d166ba22610;074dce0c-0c47-4dd3-90e2-df3905ac33b0)
#
# Invalid username or password.
# Failed to push dataset: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create (Request ID: Root=1-66695a43-160a70001c38b3e54f94abeb;917c8465-0d74-48fe-b290-86e758b66d1e)
#
# Invalid username or password.
# Failed to push dataset: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create (Request ID: Root=1-66695a44-43e581c15e05f437039d0162;61914a57-873c-419b-96b4-a21a641ea962)
#
# Invalid username or password.
# Failed to push dataset: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create (Request ID: Root=1-66695a46-31d8b1b6531c48b435292b6b;73ed924e-503c-4dd9-bed0-2707f2d1d07e)
#
# Invalid username or password.

# %%
# 무작위 10개의 JSON 파일을 선택하고, 'form' 값을 출력하는 코드에요.

import os
import json
import random

# JSON 파일들이 저장된 기본 디렉토리
base_dir = "/mnt/a/maxseats/(주의-원본)주요 영역별 회의 음성인식 데이터"

# 모든 JSON 파일 경로를 리스트에 저장
json_files = []
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".json"):
            json_files.append(os.path.join(root, file))

# 무작위로 10개의 JSON 파일 선택
random_files = random.sample(json_files, 10)

# 선택된 JSON 파일들에서 'form' 값을 출력
for json_file in random_files:
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        print(f"File: {json_file}\n")
        for utterance in data.get('utterance', []):
            print(utterance.get('form', ''))
        print('-' * 40)
# Out:
# File: /mnt/a/maxseats/(주의-원본)주요 영역별 회의 음성인식 데이터/002.주요_영역별_회의_음성인식_데이터/01.데이터/unzipped_files/DGBAD21000120.json
#
# 학생인권조례가 기로에 섰습니다. /(bgm)
# 서울시 교육청이 학생인권조례 개정안을 입법예고했기 때문인데요. /(bgm)
# 개정 이유는 학생인권조례가 학생지도를 불가능하게 할 정도로 교권을 침해하고 있다는 것입니다. /(bgm)
# 하지만 아직도 학생 인권보호는 갈길이 먼데 다시 과거로 돌아가는 개악 행위라며 배정이 불가하다는 주장도 거셉니다. /(bgm)
# 생방송 (이비에스)/(EBS) 교육 대토론 오늘은 입법예고된 학생인권조례 개정안의 긍정적 부정적 측면을 따져보고 앞으로 나아갈 방향을 논의해 보겠습니다. /(bgm)
# 서울시 교육청이 학생인권조례 개정안을 입법예고하면서 교육계에 보혁 갈등이 일고 있습니다. /(bgm)
# 개정안의 핵심 내용은 전임 교육감 시절 만든 규정 중 학생 동의 없이 복장과 두발을 규제하거나 /(bgm)
# 소지품 검사를 할 수 없게 돼 있던 조항을 학칙으로 규제할수 있도록 바꾼 것. /(bgm)
# 개정을 찬성하는 측에서는 교권침해 사례가 하루 평균 (마흔 건이나)/(40건이나) 되는 현실에서 올바른 학생 생활지도가 불가능하며 /(bgm)
# 나아가 교권침해를 방지하기 위한 목적이라고 설명합니다. /(bgm)
# 그러나 반대하는 측에서는 구체적인 판단 기준이 없어 학생 인권을 제한할 우려가 있다며 조례 개악 시도를 중단하라고 비판합니다. /(bgm)
# 시행 (삼 년째를)/(3년째를) 맞은 학생인권조례 과연 어디로 갈 것인지 함께 논의해 봅니다. /(bgm)
# 네 오늘 함께 말씀 나눠주실 분들 소개하겠습니다.
# 공교육 살리기 학부모연합에
# 네 안녕하세요.
# 네 @상호명1
# 안녕하세요.
# 네 경희고등학교
# 안녕하세요.
# 아주대 법학전문대학원에 네 방청석에도 많은 분들이 함께하고 계십니다 토론 지켜보시면서 (좋은 의견 부탁드리겠습니다.)/(idiom)
# 생방송 도중에 전화 열어놓겠습니다.
# (공이오칠팔에)/(02578에) (일삼팔공입니다.)/(1380입니다.)
# 학생인권조례 개정에 대해서 시청자 여러분들께서는 어떻게 생각하시는지 적극적인 (의견 참여 기다리겠습니다.)/(idiom)
# 네 서울시 교육청이 시행 (이 주년이)/(2주년이) 된 학생인권조례를 개정하려고 해 논란이 일고 있습니다.
# 개정 이유는 학생인권조례가 학교 현장에서 학생 생활에 어려움은 물론 교권 침해를 불러일으킨다는 이런 지적 때문인데요.
# 그러나 개정은 학생 인권을 후퇴시키는 개악이라며 불가하다는 이런 주장도 팽팽합니다.
# 어 이러한 논란에 대해서 어떻게 생각하시는지 네 분 토론자분들의 기본 입장 들어보면서 시작하는 시간 갖도록 하겠는데요.
# 학생인권조례 개정에 대한 기본 입장 좀 먼저 (말씀 부탁드리겠습니다.)/(idiom)
# 네 이 학생인권조례는 처음 만들어 질 때부터 사회적으로 굉장히 문제를 불러일으켰어요.
# 그리고 그래서 그 염려가 그대로 현실화 됐고요.
# 왜 그랬냐 하면 그것이 처음 만들어질 때부터 의도가 담긴 그 정치적인 아주 냄새가 짙은 그런 조례였기 때문에
# 어 반대가 심했고 그 안에는 또 도저히 받아들일 수 없는 여러 독소 조항들이 숨어져 있었는데
# 어 그것은 정말 @이름1 교육감이 만들어서 많은 현장의 문제를 가져왔습니다.
# 그래서 결국은 어떤 이유가 됐든 교육감이 바뀌셨고 그래서 감이 이 문제를 깊이 인식하셨기 때문에 개정을 하신다고 했는데요.
# 그래서 개정을 해서 저희는 기대를 굉장히 많이 했습니다.
# 그런데 막상 나온 개정안에는 진짜 우리가 기대했던 그 여러 가지 문제가 있다고 지적했던 것이 일부는 고쳐졌지만
# 일부는 전혀 손대지 않은 안이기 때문에 저희는 이 개정안을 받아들일 수가 없습니다.
# 처음부터 이 정치 조례는 정치적으로 해결해야 된다라고 우리 학부모는 생각을 했고요.
# 그래서 지금 이 개정안 안에도 어~ 정말 학생 인권옹호관 같은 거 그런 것 인권옹호관이 있다고 해서 아이들 학생 인권이 지켜지는 것이 아닌데
# 그 작은 조항들은 뭐 바뀌었다 하더래도 정말 필요 없는 것을 그 안에 담은 그것을 아까 말씀드린 제가 정치적인 의도라고 말씀드린 건데
# 그 어떤 진영의 사람들이 일자리를 그 자리에서 만들려고 이런 조례를 만든 것이 아닐까?
# 그리고 또 바뀌지 않은 사항들도 있습니다.
# 아이들의 집회 자유를 그대로 아직도 허용하게 놔두었다든가 하는 그런 아직도 해결되지 않은 문제가 담긴 이 개정안은
# 어 정말 받아들이기 어렵기 때문에 이번 기회에 개정이 아니라 폐지해야 된다 처음부터 주장했듯이 전혀 어 나아진 것이 없다라고 생각하는 입장입니다.
# 네 개정에 아 반대한다는 것을 말씀을 해주실 것 같은데 한번 (말씀해 주시겠습니까?)/(idiom)
# 네 저는 학생들의 인권 보장을 정치적인 문제로 환원하는 것에부터 학생들의 인권 보장을 저해하는 굉장히 좀 슬픈 현실이 담겨있다고 생각하구요.
# 실제 초중등 교육법 (십팔 조 사 항에 의하면)/(18조 4항에 의하면) 학교나 학교장이나 또는 교육 당국은 학생 인권을 보장하여 교육하도록 되어있습니다.
# 그런데 실제 서울 학생인권조례에 의해서 학생인권 조례에 대한 교육을 제대로 받지 못한 학생들과 교사들도 여전히 많이 있거든요.
# 그리고 실제 교육감이 바뀐 이후에는 학생인권조례는 이제 효력이 없다라는 그런 유언비어까지 돌아서 실질적으로 학생들의 인권보장이 굉장히 후퇴된 상태입니다.
# 그래서 더 많은 학생들의 인권을 보장해야 할 교육청이 오히려 이런 인권보장이 굉장히 저해되고 있는 현실을 외면하고 오히려
# 어 학생인권조례 개정을 시도한다는 것이 교육 현장에 있는 교사로서는 꽤 답답한다고 생각하는 입장입니다.
# 지금 (반대되는 말씀을 해주셨고요.)/(idiom)
# 예 현 학생인권조례는 그 학생들에게만 초점이 맞춰져 있어서 어 학생인권을 지나치게 강조하므로
# 어~ 교사의 권리 또한 학부모의 권리를 침해하는 그런 잘못된 부분들이 많이 담겨져 있습니다.
# 어 학생들만이 학교의 주인이 아닙니다.
# 학교는 학생을 비롯해서 교사 학부모 또 학교 설립자 교육당국 등 다양한 주체들의 결합체입니다.
# 따라서 학교 안에서 결정되는 모든 문제는 그 각각의 주체들의 충분한 합의와 또 협의를 통해서 결정되어졌는데 현 어 그~ 인권조례는
# 어~ 그때 당시 그 @정당1의 소속 시의원들이 날치기로 통과했던 그런 아주 나쁜 선례가 있는 어 조례입니다.
# 따라서 어 이번 기회에 이러한 뿌리부터 그 근본을 좀 바꾸는 개혁이 좀 필요하고
# 또 개정을 통해서 일부 독소 조항들이 많이 사라졌긴 했지만 아직도 부족한 점들이 많습니다.
# 뭐 앞서 말씀드렸지만 그~ 집회 자유 같은 경우에는 정치적 목적으로 학생들을 이용할 수 있는 여지가 있고
# 또한 어 이 개인 성향이라는 부분이 어 동성애나 트랜스젠더 같은
# 성 윤리적 부분을 어~ 문제가 되는부분들을 또 이렇게 그 변형시킨 요소로 지금 지적이 되고 있습니다.
# 종교 교육을 침해하는 조항들도 아직도 그대로 여전히 남아있고요.
# 따라서 이번 기회에 학생인권조례를 폐기하고 오히려 학생인권 뭐 선언문이라든지 헌장이라든지 어 이런 쪽으로 대처하는 그런 계기를 만들었으면 하는 바램입니다.
# 네 그 헌법 연구자로서 참 우리 사회에서 인권에 대한 의식이나 이해가 이런 것인가 좀 그런 좀 참담함이 좀 있습니다.
# 그러니까 사실은 그 학생들은 민주시민으로서 이렇게 자라나야 된다라고 하는 게 교육의 기본 이념이고요.
# 또 헌법에서 말하는 기본권의 주체인 거죠 그렇기 때문에 그럼에도 불구하고 학교에서 그러한 인권을 제대로 보상받지 못했기 때문에 인권 조례를 통해서
# 이것이 사실은 그전에는 법률로 이것을 제정하려고 하다가 그렇지 못한 점에서
# 법률에 단지 학교장 등등은 인권을 보장해야 한다라고 하는 근거만 두고 있었던 것을 어 지방교육자치 차원에서 조례로 만든 것이거든요.
# 그런데 이번에 조례는 사실 계약이라고 해야 될 정도로 학생인권에 어쨌든 본질을 외면하고 사실상 학생인권 침해 내지는 제한을 정당화하는 이런 것에 불과한 것이 되고요.
# 또 사실은 학교 현장에서의 교사와 학생의 갈등이라고 하는 것이 분명히 존재하죠 그런데 결국 문제는 그 갈등이 왜 생겨났는지
# 또 그것을 어떻게 해결할 것인지에 대한 고민을 하지 못하고
# 오히려 학생들과 어~ 또 교사를 교권과 학생인권을 대립시켜 가면서 그것에 갈등을 조장한다는 점에서 참고로 좀 슬픈 일이라고 생각을 하고요.
# 또 마지막으로 상위법 위반의 문제를 말씀을 하시는데 정말 헌법에서 보장하고 있는 이런 인권을 제대로 보장하지 못하고 학교에 설화라는 공간 안에서
# 민주시민으로 자라나야 될 학생들에 대해서 인권을 이렇게 침해를 정당화하는 이런 식의 개약을 했다라고 하는 것이 오히려 어떤 의미에서 상위법 위반인 점을 어~ 지금 생각을 해보면
# 어~ 또 상위법 위반이라고 하는 점 또한 근거가 없다라고 하는 점에서 어~ 이것은 계약이고 어쨌든 현재의 조례를 적어도 최소한 그냥 두는 선에서 어~
# 그 머무르는 것이 어~ 지금 교육청에서 해야 될 최선의 길이라고 생각을 합니다.
# 네 지금 이제 모두 발언을 통해서 (네 분)/(4분) 토론자께서 학생인권조례 개정에 대해서 찬성 심지어는 이제 폐지까지 말씀을 하셨고요.
# 또 다른 분들께서는 반대 심지어는 계약이라고까지 말씀을 해주셨습니다.
# 그럼 이번 개정 논란의 대상인 학생인권조례에 대해서 한번 좀 평가를 먼저 해봤으면 좋겠는데요.
# 경기도에서는 시행 (삼 주년을)/(3주년을) 맞았고요 어~ 서울에서는 바로 어제인 (이십육 일에)/(26일에) 시행 (이 주년)/(2주년) 기념식이 있었던 걸로 알고 있습니다.
# 그동안 어떤 공과가 있었는지 먼저 저희가 한번 짚어봤으면 좋겠는데요.
# 경기도에서 가장 먼저 학생인권조례를 시행을 했었는데 학교에서 현장에서 좀 어떤 변화가 있었는지 좀 어 (말씀을 좀 해주시겠습니까?)/(idiom)
# 저는 어쨌든 초중고등학교 있지 않으니까 주변에서 선생님들로부터 들은 말씀이겠죠.
# 그런데 어~ 경기도의 경우 이제 학생인권 실태조사를 이제 이번이 두 번째 금년에 이제 진행 중인데요.
# 어 결국은 실태조사를 해 보면 교사들은 어쨌든 인권이 잘 보장되고 있고 조례 없이도 잘 된다라고 보고 계시는 의견이 좀 있는가 하면 학생들은 정반대 입장이거든요.
# 그러니까 학생조례의 의미라고 하는 것은 그 간극을 줄이는 데 있는 거죠.
# 그렇기 때문에 학교 선생님들의 어쨌든 교권을 제한하거나 침해하는 것이 아닌 그런 점에 있어서 어쨌든 기본적인 시각차가 있다 .
# 그런데 그 시각차를 어떻게 줄일 것인가라고 하는 것이 조례에 관점이고요.
# 근데 어쨌든 적어도 경기도에서는 이제는 체벌을 통해 통화 교육이라고 하는 더이상 용납될 수 없다라고 하는 것들이 모든 어쨌든 선생님들에게 있어서 공유되고 있고.
# 더 나아가서 학생들에게 그러면 어떻게 교육을 행할 것이고 또 더 나아가서 학교 생활에 있어서 자치와 참여에 의해서 어 이런 학교 생활을 유지할 것인가에 대한 이런 고민으로
# 학생인권이 자유권 중심에 있어서 더 자치나 자유 사회와 같은 민주주의 쪽으로 또 이렇게 발전해 나가고 있다라고 하는 이런 모습에 있어서 보면
# 학생인권조례가 바람직한 방향으로 기능하고 있는 것이지 그 반대의 것은 전혀 아니라고 말씀드릴 수 있습니다.
# @이름2 대표님 네.
# 네 저는 참 정말 교수님이 워낙 근사하게 말씀을 하신 것 같아요 그리고 그런 설문조사 결과 같은 것도 저희 학부모 입장에서는 경기도를 볼 때 정말 기가막힙니다.
# 경기도는 제가 경기도에 살다 서울로 이사를 왔는데요.
# 불과 얼마 전까지만 해도 경기도가 최고의 학력을 자랑했었어요 (일 위였어요.)/(1위였어요.)
# 그런데 경기도는 지금 최근 최근 (사 년간)/(4년간) 전국 꼴찌입니다.
# 그게 학생인권조례하고 무관할까요?
# 정말 좌파 교육감이 들어온 이후에 그 (사 년간)/(4년간) 학력이 떨어지고
# 진짜 선생님들은 너무 문제가 없다고 하는데 거기있는 학부모들은 어서 빨리 경기도를 떠나고 싶다고 할 만큼 학교에 불만이 많고
# 진짜 아이들이 인권이 존중되면 존중되고 이렇게 존중한다고 인권 조례를 얘기하시면 얘기할수록 정말 거기에서 학습권을 보호받고 공부하고 싶은 학생들은 학교가 너무 괴롭고 힘들고
# 학교 아이들의 (삼 분의 일 이나)/(3분의 1이나) 선생님의 수업을 따라갈까 나머지 아이들은 선생님으로부터 거의 방치되고 있는 그래서 학교가기 싫다고 하는 이런 사태가
# 그야말로 정말 수치로 나타나고 있는데 인권이 잘되고 있다 저희는 이 학생인권이 누가 만든 겁니까?
# 교육감이 제일 먼저 만들고 그곳에 법안을 작성한 사람이 그나마 그 당시에 방통대 교수였고
# 그다음에 나중에 그분이 서울 학생인권 조례를 만들면서 경기도보다도 더 나쁜 나쁜 사항들을 더 많이 담다가 이렇게 큰 저항에 부딪쳤고
# 하면서 경기도 조례까지도 우리가 다 같이 알게 됐고 이 학생조례야말로 우리 교육에 있어서 지금 당장 필요 없고 당장 없어져야 되는데
# 이렇게 그냥 근사하게 인권이 보장된다 정말 학교에서 체벌이 없어진 지는 참 오래됐습니다.
# 체벌이 논의된 지가 오래되면서 직접 체벌은 거의 어느 학교에서 어떤 선생님도 거의 하시려고 생각하지 않습니다.
# 이번 기회를 통해서 직접 체벌 간접 체벌이라는 것이 나뉘면서 아~ 그래 집에서 엄마들조차도 아이들도 이제 체벌 안 하겠다 굉장히 많이 사회적으로 공감대를 얻고 있습니다.
# 이 인권조례가 저는 남긴 나름대로의 역할도 있다고 생각하는데
# 그것이 그대로 존속하는 한은 학교 현장에 정말 선생님들 얘기를 듣고 싶습니다.
# 저 여기에 여기에 선생님이 못 나왔다는 것이 참
# 네 아이 지금 뭐 경기도에서 학교 현장에서의 어떤 공과 한번 간단하게 (말씀해 주시겠습니까.)/(idiom)
# 어 제가 우선 여쭤보고 싶은 것은 어 경기도의 학력 저하됐다는 것이 어떤 걸 근거로 하시는지 좀 궁금하고요.
# 예 그리고 왜냐하면 학생인권이 많이 보장되는 혁신 학교들이라든지 학생인권조례로 인해서
# 학교 문화를 바꾸는학교의 경우에 학력도 신장되고 있다는 것이 결과로 나와있는 상황이거든요.
# 그래서 저는 그것은 좀 옳지 않다고 생각하고요.
# 그리고 서울의 같은 경우에도 많은 학교는 아니지만 저희가 어제 학생인권조례 (이 주년)/(2주년) 기념 토론회를 했었는데
# 거기에서도 어쨌든 옛날에는 생활지도부 이런 거 굉장히 무시무시한 공간이었잖아요 학생들한테.
# 그런데 생활지도부가 생활교육부 인권 교육부 또 학생지원부 이런 식으로 학교의 문화를 바꾸는 역할을 하는 부서로 굉장히 많이 바뀌고
# 그러면서 교사들 교사들에 대한 신뢰도도 학생들이 굉장히 높아지고요.
# 그리고 학생들이 어 교사들을에 대해서 오히려 굉장히 존경심을 갖고 교사들이 적어도 옛날에 막 되게 힘들었던 불필요한 어떤 생활지도
# 나 이런 것들 로인하 교사 학생 간에 아주 소모적인 갈등이되게 사라졌다 이런 이야기들이 이야기되고 있거든요.
# 예 그래서 좀 더 좀 학교 현실에 대해서 좀 더 정확하게 볼 필요가 있겠다라는 생각은 듭니다.
# 그럼 저기 서울시 교육청에서 이번에 개정하겠다라는 것은 그래도 무언가 문제가 있어서라는 생각이 드는데요 어떤 점에서 문제가 있다고 생각되는지 한번 (정리해 주시겠습니까?)/(idiom)
# 네.
# 예 그 뭐 경기도 얘기 아까 하셨는데 뭐 우리 찬성 쪽에서는 좋은 면만 부각돼서 말씀하시는데요.
# 학교 현장에서 학생들은 좋아졌는지는 모르겠지만 교사들은 너무 가르치기 힘들다 아이들 지도하기 힘들다.
# 뭐 언론에 많이 보도가 되지만 매 맞는 선생님 얘기가 요즘 많이 등장을 하고 있습니다.
# 우리 교육 현실이 어떻게 됐길래 선생님이 학교에서 학생들한테 매를 맞고 예 참 이런 일이 생긴다는 게 참 안타깝습니다.
# 그만큼 이 학생인권조례가 지나치게 학생들의 인권을 강조한 나머지 교사들의 권위를 실추시키고
# 어 교사들이 그~ 인권 문제에 휘말릴까봐 학생들의 인성이나 또 학습 지도를 포기하고 또 방관자로그렇게 전락하는 그런 많은 우려를 낳았습니다.
# 이러한 경기도의 현상이 서울시에 고대로 지금 나타나고 있습니다.
# 그래서 서울시에서도 사실 수업시간에 엎드려 자는 학생들에 대해서 선생님들이 그것을 제대로 제재를 못 하신다고 하더라고요.
# 왜냐면 괜히 건드렸다가 학생인권 침해한다고 학생들이 문제 제기하면 선생님만 힘들어지고 골치 아파지고 그래서
# 아예 방치하고 그냥 가르칠 사람 말을 가르치고 공부할 사람만 가르치겠다.
# 그런 수동적인 자세로 된다고 합니다.
# 이게 어찌 학교가 그런 모습이 돼서 되겠습니까.
# 이학생인권조례로 인하여서 일어난 현상들입니다.
# 또 뭐 저희 아이도 지금 (고 삼)/(고3) 있고 또 (중 삼)/(중3) 어 아이가 있는데 오늘 제가 이 토론회 나온다고 하면서 물어봤습니다.
# 학생인권조례 생긴 다음에 좋아진 게 뭐가 있나 했더니 좋아진 것 보다는 나빠진 게 더 많다고 하더라고요.
# 왜냐면 수업시간이 너무 그 질서가 안 잡히고 학생들이 툭하면 핸드폰으로 뭐 선생님 찍겠다 뭐 이런 얘기들 하면서
# 이 학습 분위기가 도저히 안 잡혀서 공부하는 데 참 지장이 많다 이런 얘기들을 오히려 하더라구요.
# 학생들조차도 학생인권조례에 대해서 부정적으로 생각하는 학생들이 많이 늘어나고 있습니다.
# 특히 그 모든 것이 학생인권조례만의 문제이겠습니다 왜냐하면 (팔십육 년의)/(86년의) 신문을 보더라도요 그때부터 교권 침해 얘기는 계속 있었던 거거든요 그리고
# 학생인권 조례가 만들어진 시도가 있고 그렇지 않은 시도 있잖습니까 그러면 학생인권 조례가 만들어지지 않은 시도에서는 그러면
# 학습에 교실에 어떤 분위기가 전혀 없는 건지 또 교권 침해 문제는 전혀 없는 건지 이렇게 얘기할 수는 없는 거잖습니까 왜냐하면
# 학교에서 결국 교실이 결국 교육의 붕괴되는 이유라고 하는 것은 아까도 말씀하셨지만 학생들의 편차가 너무 심한 거죠.
# 그 심하게 된 이유라고 하는 것은 결국은 사교육에 의존할 수 밖에 없는 구조를 가져갈 수밖에 없는 거고요.
# 또 현재 교육의 체계나 입시 제도상으로 보면 아무리 공부를 열심히 해도 (백 명 중에)/(100 명 중에) 뭐 몇 프로 소수의 학생이 아니면
# 이른바 우리 사회에서 얘기하는 좋은 대학에 갈 수 없는 구조를 만들어 놓고 그니까 이미 그 위의 학교외적인 여건에 의해서
# 교육은 붕괴될 수밖에 없는 구조를 만들어 놓고 거기에서 어쨌든 외면되고 소외될 수밖에 없는 학생들에게 또는
# 아~ 교육의 이름으로 어쨌든 인권을 제대로 보장받지 않는 학생들에게 인권을 존중하면서 하자는 그리고 그것은 인권조례가 만들어지기 전부터
# 많은 선생님들은 학생들의 인권적으로 존중하면서 교육할 수 있는 방법 들에 대한 모색들과 연구를 진행을 하셨던 거죠 그리고 그것들을 확인하고 그거를 지원해 주기 위한 것인 것이지
# 인권조례가 생기기 전에는 그러면 정말로 학생의 인권이 유린당하고 정말 어~ 학습이 제대로 이루어지지 않고 학교가 비정상이었다는 얘기신데요.
# 인권을 존중하는 의미에서 교육을 하자라고 하는 의미였던 거고요 그게 이미 (이천칠 년에)/(2007년에)
# 초중등교육법을 개정을 하면서 어~ 학교 설립자라든지 학교의 장은 학생의 인권을 보호해야 한다라고 하는 어떤 한 조문으로 들어가게 되고
# 그것을 구체적으로 실현하기 위한 하나의 방식으로서 조례를 만들어서 그것을 구체화한 거죠.
# 정말 저는 이 학생인권조례라는 게 그러면 세계에 많은 나라에 있나 라고 봤을 때 학생인권조례 있는 나라가 세계에 하나도 없더라고요.
# 대부분의 나라들이 이번에 연구 용역을 서울시 교육청에서 줘서 해본 결과 대부분의 나라가
# 학생 뭐 아까 말씀드린 인권 선언이라든지 인권 헌장이라든지 이런 거를 통해서 모두가 다 공유하고
# 입학식날 모두가 거기에 대해서 사인을 하고 서약을 하면서 모두가 그것을 공감대를 갖는 건 반드시 필요합니다.
# 그렇지만 이거를 조례라는 것을 만들어서 학교에 엄연히 학칙이 있고 그 학교 안에서 구성원들끼리 많은 것을 그야말로 두발 자유 뭐 또
# 어 아이들의 뭐 소지품 검사 같은 것도 사실 어떤 가게에서 학교 교실 안에서 분실사고가 일어났다고 했을 때
# 저는 선생님으로서 당연히 거기에 개입을 하셔서 누가 이것을 문제를 일으켰는가 밝히는 것은 선생님의 관심이라고 생각해요.
# 근데 아까 교수님 계속 뭐 이런 현상이 제도 안에서 뭐 공부 잘하는 애들 몇 명밖에 좋은 대학에 갈 수 없는 그런 구조를 말씀하시는데
# 우리 학부모 입장에서는 그걸 선생님들에게 요구하는게 아닙니다.
# 선생님들이 아이들에게 끊임없는 관심을 더해지면 그 관심이 곧 아이들의 인권을 존중하는 건데
# 왜 이걸 조례로 하겠다고 그럼 여태까지 전교조는 선생님들 이십 년 동안 뭐하고 계시다가 지금 그런 다 인권 인권 아이들 그동안 인권 짓밟아오셨나요.
# 왜 요즘 들어서 그렇게 인권에 목을 매시죠?
# 저는 아주 그게 도대체 선생님들 왜 이러실까 여기에 무슨 목적이 있을까 라고 생각이 듭니다.
# 아 저도 다른 나라에서 학생인권조례가 없는데 우리나라만 있어야 되는 현실이 좀 개인적으로 슬픈데요 왜냐하면
# 다른 나라 같은 경우는 학생인권조례가 없어도 두발이라든지 아주 개인적인 신체의 자유라든지 아니면 소지품 검사라든지 하는 건 당연히 금지되어 있고요 왜냐하면 민주 사회 시민이기 때문이죠.
# 그런데 우리나라에서 교육이란 이름으로 잘못 그래서 어 그런 어떤 외국에서는 해오지 않았던 관행들이 교육의 이름으로 계속돼 왔던 것들에 대해서
# 그것이 정말 문제가 있다는 문제의식에서 저는 학생인권조례가 생긴 것으로 알고 있고요.
# 그리고 계속해서 이제 학습권 침해나 이런 부분들을 얘기를 하시는데 사실은 소위 말하는 학습권을 침해한다고 하는 학생들은
# 그 이전부터 오히려 학습권을 침해당해온 학생들이거든요?
# 그니까 학습결손이 있다든지 그 이전에 제대로 학습권을 보장받지 못했기 때문에 수업을 따라가지 못한다든지 학생들을 방해하는 행동을 한다는 거죠.
# 그래서 그 학생들의 하나하나의 인권을 좀 보장하는 방식으로 어떻게 학습을 도울 수 있을까 라는 고민으로 시작하는 것이 학생인권조례 출발점이라는 사실을 알아주셨으면 좋겠습니다.
# 지금 사실 학생인권조례에 대한 필요성에 대해서는 좀 저희들이 다시 또 짚어보고 계신데
# 사실 이번에 그 서울시에서 그 인제 서울특별시 교육청에서 개정안에 대한 의견 수렴을 하고 있거든요.
# 네 그리고 또 그런 과정에서 또 정책 토론회를 열었는데 굉장히 또 논란이 많았다고 들었습니다.
# 어떤 논란이 있었는데 좀 누가 간단하게 (말씀해 주시면)/(idiom)
# 제가 그 현장에 있었으니까 말씀드리겠습니다.
# 그런데 정말 그~ 학생인권조례에서 학생들이 많이 왔어요 저는 보통 학생들인 줄 알았어요.
# 그리고 그 자리에 들어올 때는 어떤 피켓이라든가 어떤 도구를 가져오지 못하게 아마 문에서 사전에 다 차단을 했고 그래서 잘 토론회가 치루어질 줄 알았는데
# 나중에 알고 보니까 이것들은 전교조 선생님들이 아이들을 몰고 오신 거였고
# 그 자리에 토론자로 나와 있던 학생 인권위원회 부위원장님 여성분이 제 옆자리에 앉았기 때문에 느끼는 건데요.
# 갑자기 아이들한테 사인을 보내시는 거 어 꺼내지마 이렇게 하는데 아이들하고 사인이 맞지 않으면서 아이들이 주머니에서 다 헝겁으로 만든 피켓을 가지고 와가지고
# 막 피켓 시위를 하면서 언성을 높이고 정작 발언권을 줘서 학생 (두 명에게)/(2명에게) 이야기 줬을 때
# 그때 들은 입다물고 아무말도 못하다가 다른 의견을 가진 이 학생인권조례가 문제가 많다라고 생각하는 (두 학생의)/(2학생의) 이야기를 들은 후 부터는
# 막 언성을 높이면서 발언권 달라고 하고 또 거기에는 이런 일도 있었어요 학교 애국가 제창이 있었고 국기에 대한 경례가 있었는데
# 애저녁에 일어나 어른들은 일어나는데 일어나지를 않고 끝까지 버티면서 우리는 일어나지 않을 권리가 있다고 하면서 세상에 태극기까지 부정하고
# 네.
# 그 옆에 아이들을 데리고 오신 선생님은 아이들을 보고 일어나지 말라고 하고
# 도대체 선생님들이 과연 어른인가라는 생각이 들 정도로 정말 심각한 상황이었습니다.
# 어 저는 그
# 그날 오셨었나요?
# 아~ 저는 그 자리에 참여를 못했는데요.
# 제가 오히려 들은 바로는
# 들으신 바로는.
# 네 어 그 자리 그러니까 우수 저는 이 토론회가 학생인권조례가 내용에 관해서 저희가 지금 시청자들하고 지금 얘기를 나눠야 되는 상황이잖아요. /(noise)
# 그렇습
# 예예 근데 그런 좀 형식적인 얘기가 굉장히 지금 그 학생들이 순수하냐 순수하지 않냐를 자꾸 물으시고 교사에 대해서 물으시는 게 사실 거기에 참여하신 분들에 대한 굉장히 모독이잖아요.
# 그리고 우리가 사실 그걸 논하기 위한 자리는 아니구요 그리고 실제 그 그때 대표로 참여에서 패널로 참여한 학생들이 뭐 꺼져라 입 닥쳐라 이런 얘기를 /(noise)
# 들은 것도 사실이거든요 그래서 더이상 그거에 대한 논란이 아니라 학생인권조례 내용 개정에 대한
# 전 서울시 교육청에서 제시한 이 학생인권조례 개정안에 대해서 논란이 많았는데요.
# 그렇다면 이번 개정안에서 어떤 내용이 현행안과 다른지 굉장히 궁금합니다 그리고 또 시민들은 또 어떤 반응을 보이는지도 저희들이 한번 알고 싶은데요 먼저 여기서
# 구체적인 개정 내용과 함께 일반 시민들은 논란을 어떻게 보는지 저희가 한번 보고난 후에 (논의 이어가도록 하겠습니다.)/(idiom)
# 최근 서울시 교육청이 서울 학생인권조례 개정안을 입법예고했습니다. /(bgm)
# 학교장이 학칙제정권과 교사의 학생 생활지도권 회복이 이번 개정안의 핵심 내용인데요. /(bgm)
# 개정안을 자세히 살펴보면 먼저 학생 의사에 반해 복장이나 두발 등 용모에 대해 규제하지 못하도록 되어 있는 조항은 /(bgm)
# 교육상 필요한 경우에 한해 학생과 학부모 그리고 교사의 의견을 수렴해서 제 개정안 학칙을 기준으로 용모에 관한 사항을 정할 수 있도록 변경했습니다. /(bgm)
# 또 학생의 동의 없이 소지품을 검사하거나 압수할 수 없도록 한 조항의 경우는 /(bgm)
# 필요한 범위 내에서 소지품을 검사해 학칙을 위반되는 물건의 소지를 제한하도록 하고 소지품 검사는 과도하지 않은 방법으로 하는 것으로 규정했습니다. /(bgm)
# 그러나 일각에선 조항의 내용이 애매하다고 지적합니다. /(bgm)
# 필요한 범위와 과도하지 않은 방법 자체가 포괄적인데다 그 기준을 누가 어떻게 정할 것인지에 대한 규정이 없기 때문인데요. /(bgm)
# 학교장의 판단에 따른다고 할지라도 자의적 해석에 따라 적용 범위가 크게 달라질 수밖에 없다는 것입니다. /(bgm)
# 또한 차별받지 않을 권리를 규정한 (제오조에서는)/(제5조에서는) 임신 또는 출산 항목은 삭제됐고 동성애 관련 표현은 완전히 수정됐습니다. /(bgm)
# 당초 포함됐던 성적지향과 성별정체성이 빠지고 대신 개인 성향이라는 개념으로 바뀌었는데요. /(bgm)
# 이 역시 애매한 기준이라는 지적이 나옵니다. /(bgm)
# 그리고 전반적으로 학생인권에 대한 실행 의지를 강조한 부분의 변화도 눈에 띕니다. /(bgm)
# 먼저 (제삼조)/(제3조) 학생인권 보장 원칙을 살펴보면 /(bgm)
# 현행안은 학생인권을 반드시 보장되어야 하는 기본적인 권리라고 표현하고 있는데요. /(bgm)
# 개정안에는 반드시 보장되어야 하는 이란 표현을 삭제되고 기본적인 권리라고 표현되어 있습니다. /(bgm)
# 또 학교생활에서 최우선적으로 그리고 최대한 보장되어야 한다는 부분은 학교생활에서 보장되어야 한다로 바뀌었습니다. /(bgm)
# 그리고 학생인권과 관련된 실체를 조사하고 정책을 연구하는 학생인권옹호관을 임명하는 방식도 개정안에서는 달라졌습니다. /(bgm)
# 현행안은 학생인권위원회의 동의를 얻도록 제한을 뒀지만 개정안에서는 위원의 동의 조항이 빠지고 교육감이 임명하도록 했습니다. /(bgm)
# 교육감의 인사권이 기존안 보다 크게 강화된 것입니다. /(bgm)
# 교육청은 이번 달안으로 개정안에 대한 의견을 수렴해서 시의회에 서울학생인권조례 개정안을 제출할 방침입니다.
# 네 학생인권조례 개정안이 구체적으로 현행안과 비교해서 어떻게 달라졌는지 좀 살펴봤고요. /(bgm)
# 어 그리고 개정안에 대해서 시민들도 찬성쪽과 반대쪽의 의견이 좀 팽팽하게 아 맞서고 있다라는 것을 볼 수가 있었습니다.
# 어 사실 이 토론 초기에 어 모두 발언에서 이 토론자 분들께서도 개정이 개악이다.
# 어 아니다 개정도 부족하다 아예 폐지해야 한다 이런 말씀을 해주셨거든요.
# 그렇다면 구체적으로 이번 이 개정안에서 어떤 조항들이 문제가 되는지 좀 한번 짚어봤으면 좋겠는데요.
# 어 (누가 먼저 짚어봐주시겠습니까.)/(idiom)
# 네.
# 네 제가
# 조 선생님.
# 얘기하겠습니다 아 아까 말씀드렸듯이 그~ 어
# 헌법과 (유엔)/(UN) 간 아동 권리 협약 그리고 초중등교육법에는 상위법에서 보장하고 있는 학생인권을 학칙으로 제한할 수 있도록 한 점이 가장 후퇴한 점이라고 생각하고요.
# 그리고 차별 금지 조항에서 성 소수자 학생을 제외한 제외시킨 것은 사실 성소수자 학생의 인권보장이 굉장히 치명적인 것이거든요 그런데 그것을 한 것.
# 그리고 소지품 사실 지금 현 인권조례 상황에서도 안전에 문제가 있는 경우에는 소지품 검사를 할 수 있도록 하고 있습니다.
# 그래서 사실은 안전을 위한 경우에는 충분히 그게 기회가 보장됨에도 불구하고 다시 그 것을 소지품 검사의 범위를 넓혀서
# 사실 학생들이 소지품 검사하기 굉장히 자기의 사적인 영역이기 때문에 굉장히 민감한 부분이잖아요.
# 그래서 사춘기 학생들에게 굉장히 어 정신적 충격을 줄 수도 것에 대한 제한 요건을 너무 이렇게 어 벌여놓은 것이 가장 큰 문제라고 생각하고요.
# 저는 이것이 규정 어떠한 개정안의 내용을 떠나서 지금 교사 학생의 관계가 좀 변화하고 좀 새로운 문화를 만들어갈려고 하는 이 시점에서
# 굉장히 찬물을 끼얹고 다시 불필요한 갈등으로 또 학교를 몰아넣는
# 네.
# 개악안이 아닌가 생각합니다.
# 네 지금 (세 가지)/(3가지) 말씀해 주셨는데요.
# 뭐 법체계에서 문제 말씀도 해 주셨고 성소수자를 제외했다라는 말씀도 해 주셨고 또 소지품 검사에 대해서 말씀을 해주셨는데 (여기에 대해서 누가 말씀.)/(idiom)
# 네.
# 어~ 사실 지금 지적하신 부분들이 어~ 개정이 대부분은 저희들은 굉장히 바람직하다 바람직하게 개정이 되어있다 안이 마련됐다라고 생각을 하고 있습니다.
# 학생들의 그 외모 이 사실 복장문제 굉장히 그~ 중요한 문제입니다.
# 이것이 개인의 뭐 그 개성을 표현하는 수단이 되기도 하지만 학생 시기에는
# 그런 복장이나 두발이야 이런 것들이 그 학생들의 심성 또 학습 자세 이런 것들하고 연관이 됩니다.
# 대개의 경우에 이 복장이나 두발 이런 것들이 좀 단정치 못할 경우에 그~ 학습에 어~ 좀 몰입하지 못하고
# 어떤 면에서 학생답지 못한 어떤 일탈 행위들을 하는 어~ 것들이 많이 있습니다.
# 또 학부모들도 그런 것들이 굉장히 많이 걱정이 됩니다.
# 뭐 저희 아이들만 해도 머리 염색하겠다고 하면 저부터가 반대합니다.
# 왜냐 그렇게 할 경우에 혹시 마음이 흐트러져서 공부에 집중하지 못하고 또 혹시 일탈된 행동을 하지 않을까라는 염려가 그 부모로서 다 가지고 있습니다.
# 학교에서 그런 것들을 좀 어 어떤 면에서 학칙을 통해서 적절하게 이렇게 어~ 제재를 가해 주는 주었으면 하는 것이 또 학부모로서의 마음인데
# 인권조례 자체가 그런 것들을 하지 못하도록 만든다면 학부모로서의 그 교육의 권리 자녀들에 대한 어떤 그 복장이나 이런 것들도 관여할 수 없게 만드는
# 이것은 어 교권뿐만 아니라 학부모의 교육권까지 침해하는 부분이라고 생각됩니다.
# 특히 또 두 번째로 성소수자 부분 말씀하셨는데 어~ 이 성소수자들
# 네.
# 동성애를 지칭하는 것인데 이 동성애가 굉장히 사회적으로 문제가 지금 많이 되고 있습니다.
# 어 최근 통계에 따르면은 과거 (십 년에 비해서)/(10년에 비해서) 우리나라에 에이즈 환자가 어 (여덟 배가)/(8배가) 증가했는데요.
# 그중에 청소년 에이즈 환자가 급속도로 증가 하고 있습니다.
# 그리고 에이즈 환자의 (칠십 퍼센트가)/(70퍼센트가) 동성애로 인하여서 어 지금 신규 발생되고 있습니다.
# 지금 우리 사회 이 청소년들이 동성애 때문에 에이즈에 지금 많은 감염이 일어나고 있는 것이 질병관리본부에서 밝힌 통계입니다.
# 이런데 이 성소수자를 권리를 보호해 준다는 미명하에 이 동성애를 정상으로 인정하고 또 마땅히 뭐 보장받을 권리로 이렇게
# 어~ 가르쳐 준다면 이건 굉장히 윤리적인 문제가 있고 또 우리 청소년의 건강을 해치는 문제가 있습니다.
# 또 세 번째로 소지품 검사하는 문제도요.
# 어~ 사실 미국에서 총기를 소지하고 학교에 들어와서 난사하는 그런 비극이 발생되었는데 우리나라라고 그러한 일이 생기지 말라는 법이 없습니다.
# 물론 총기는 없지만 흉기 같은 거 어 그다음에 칼 이런 위험한 물품을 학내에 가지고 들어왔을 때 소지품 검사 이런 제도가 없을 때에 어떻게 학생들 가방을
# 어 열어서 그런 것들을 사전에 예방할 수 있겠습니까.
# 그런 위험성이 있고요.
# 또한 음란물이나 폭력물 이런 것들을 학생들이 소지해서 학교에 가져왔을 때 그걸 어떻게 그거를 막을 수 있겠습니까.
# 또 우리 뭐 여학생들 같은 경우에 화장품이나 또 남자들 같은 경우에도 어떤 그 외모를 위한 어떤 그런 것들을 가져와서 수업 분위기를 해치는 일들이 많습니다.
# 쉬는 시간에 꺼내서 아이들한테 뭐 자랑하고 하면서 그 수업 분위기를 망치게 되는데
# 이러한 것들 뭐 전자게임기기 뭐 이런 것들은 좀 어 학교에 가져오지 못하도록 하는 뭐 그런 부분이 필요하고
# 때에 따라서는 선생님이 소지품 검사를 할 수 있어야 그것이 저는
# 지금 선생님은 아까 그 소지품 검사를 했을 때 뭐 중학교 그런 학생들에게 막 정신적인 충격을 준다고 그렇게 말씀하시는데
# 아이들이 도대체 무엇을 가지고 다니는데 선생님이 소지품 검사를 하면 충격을 받을까요 저는 선생님들이 대표님이 말씀하신 대로
# 선생님이 정말 아이들의 소지품이 어떨 때는 검사할 수 있어야 한다고 생각해요.
# 그래서 아이들이 이 잘못된 것이 아~ 내가 이러면 안된다는 걸 알아야 되는데
# 선생님들이 그런 걸 다 안 하시겠다는 것 아닌가요 한마디로.
# 저는 그 인권이라는 미명하에 그동안 우리나라 국가인권위에서 한 일들도 마찬가지고 뭐 하여튼 뭐 부모의 직업도 교사가 알면 안 된다.
# 하다못해 개인적인 뭐 병도 알면 안 된다 키 몸무게도 알면 안 된다 아이들의 인권을 침해가 된다고 정말 말도 못하게
# 선생님이 아이들에 대해서 만약에 무슨 사고가 벌어졌을 때 선생님들은 아이에 대해서 아는 게 하나도 없어요 진짜예요.
# 어디 뭐 우리 옛날에는 오죽하면 정말 가정방문까지 가서 걔에 대해서 뭘 알아야 무슨 사태가 발생했을 때 해결해 줄수 있는데
# 저는 선생님들이 그동안 이것도 인권 저것도 인권 저것도 인권 이러면서 점점 손을 놨고 결국은 아이들의 소지품도 만약에 분실 도난 사고가 일어나도
# 아 그것은 아이들의 인권을 보호해야 하기 때문에 우리는 손 못 대 그러면 아이들을 도둑으로 기르시는 거예요.
# 선생님들은 편하시겠죠 그냥 이것도 안 해 저것도 안 해 저것도 안 해 그렇지만 아이들은 선생님으로부터 완전히 방치되고
# 선생님의 완전히 무관심에 그냥 그대로 노출되고 아이들은 어디서 보호 받습니까?
# 그 인권위 정말 아이들의 인권을 보호해주는 게 아니라 침해받고 있다는 게 선생님들이 정말 양심을 가지시고
# 선생님들은 내가 과연 교사로서 무엇을 해야 하나를 생각하신다면 함부로 학생인권 얘기 하실 수 없을 것 같습니다.
# 소지 품검사도 필요하다라는 말씀이시구 교육적인 측면에서 지금 (세 가지)/(3가지) 아까 개안에 대해서 말씀해 주
# 그~ 조례를 안보신 것 같아요 기존에 아까 말씀하셨는데 이미 안전을 위해서는 할 수도 있는 경우들이 있습니다 동의를 얻어서 근데 일괄적으로 그냥 무조건
# 그러니까 안전을 위해선 충분히 확보될 수 있는 경우가 있다는 거죠 그러니까 소지품 검사를 할 수 있고요.
# 문제는 이제 지금 분명히 자녀분에 대해서도 함부로 일정 나이가 되면 그걸 열어 보는 것 자체가 당연히 부모라고 하더라도 할 수 없는 영역이라고 한다면
# 그렇게 할 수가 없는 거죠 그러니까 정말 다른 학생의 안전을 위해서라고 하면 할 수 있는 경우가 있다는 것 하나를 말씀드리고요 그다음에 /(noise)
# 성적인 지향하고 동성애는 관계가 없습니다 그거는 어떤 사람은 성적인 지향점이 동성애자일 수도 있고요 어떤 사람은 이성애자일 수 있는 거죠 그런데
# 양자를 차별하지 말라는 의미인 것이고 그러한 표현은 이미 유럽에 있어서도 기본 인권 헌장의 표현이 되어있고
# 우리나라 국가인권위원회 법에 있어서도 각종의 결혼 형식과 아울러서 성적인 지향이라는 표현을 쓰고 있습니다 그런데 지금 아까 말씀하신 중에 보면
# 국가인권위원회조차도 지금 인제
# 문제가 있
# 그리고 그것이 부정 하신다라고 하니까 이게 도대체 그럼 우리 사회는 인권이 도대체 없는 사회인가 이런 생각이 드는 거 하나하고요.
# 그다음에 이제 그거 차별 금지에 그치지 않고 소수자들 학생들을 보장한다라고 하는 점에서는 상당히 세분화된 조항을 두기는 했는데요.
# 거기서 인제 중요한 게 뭐였냐면 그 소수자 중에 성 소수자 학생들도 포함이 되어 있고 거기서 상당히 중요한 것이 어떻게 접근할 건가의 문제인 거예요.
# 그래서 학생들을 어느 정도 비밀성을 보호해주고 신중하게 접근해야 한다라고 하는 것이 기존의 조례안에 있었는데 그런 것이 없어졌다는 거죠 그런 점에서 보면
# 어 우리 사회에서의 특히 동성애자들이 가지고 있는 약자로서의 의미 그리고 어~
# 여러 가지 학교 안에서 집단 괴롭힘에 의해서 또 자살하는 이런 경우들이 일어나고 있는 그런 어떤 상황들을 고려해 보면 /(noise)
# 상당히 중요한 어쨌든 인권적인 부분들이 어 결국 삭제된 부분이 있는 거고요.
# 어 또 하나는 학생들의 어쨌든 이제 참여에 있어서의 일정 정도의 어쨌든 어~ 징계 기록이라고 하는 것들에 의해서는 마치
# 어 대표자로 이렇게 선출될 수 없는 것처럼 하는 식으로 바뀐 부분이 하나 있고요.
# 또 하나는 이제 마지막 하나는 학생인권옹호관 같은 경우에 상당히 독립성 확보되어야 되기 때문에 마치 우리나라 대통령제에서 장관에 대해서도 국회 동의를 얻는 것처럼
# 어 일정 정도 이런 동의를 얻어서 학교 그 교육청 내에 설치되어 있는 인권위원회의 동의를 얻어서 임명하도록 하는 것이지
# 임명 자체에 권한을 침해한 것은 아니거든요 그런 점에서 보면 어~ 지나치게 어떤 교육감의 권한을 강화하고
# 본래 인권옹호관이 해야 될 직무의 독립성을 확보하는 데 있어 필요한 제도적 장치를 무시했다라고 하는 점에서 문제가 있다라고 생각을 합니다.
# 근데 그 성소수자 부분에 있어서는 성소수자의 인권을 침해하자고 주장하는 것은 아닙니다.
# 다만 성소수자의 인권을 보호해 준다는 미명 아래 적극적인 의무의 보호 즉 성소수자들 어 이 동성애라는 것이 정상이라고 가르쳐야 되고 /(noise)
# 어~ 윤리 교과서에 동성애는 정상이다 따라서 동성애를 비정상이라고 그러니까 이게 다 이런 학생인권조례나 국가인권위에 그 조례안에
# 그 성적 지향이라는 부분이 동성애를 옹호 조장하는 쪽으로 작동이 좀 되어 가고 또 그렇게 지금 되고 있습니다.
# 그래서 그러한 부작용을 막기 위해서 그 조항이 삭제되는 거는 바람직하고요.
# 이번에 저 개정안에 또 개인 성향이라고 뭉뚱그려서 거기다가 동성애를 집어넣는데 사실 개인 성향 자체도 지금 문제가 있습니다 이것도 삭제 된다고 저는 생각하는데요.
# 예 이 개인 성향 안에 동성애와 성적 지향 어~ 또 그 트렌스젠더도 개인성향 안에 들어있다고
# (국가인권위원회 법에 대해서 어떻게 생각하십니까.)/(idiom)
# 국가인권위 법도 잘못되어 있죠 왜냐하면 그~ 서구의 서구의 특히 미국 중심으로 한 서구의 동성애를 그 지지하고 옹호하는 그런 것들이
# 마치 어 우리가 따라야 될 어떤 그런 규범 가치 어 가르쳐주는 부분은 굉장히 잘못됐다고 전 세계 (칠십팔 개국이)/(78개국이) 동성애에 대해서 반대하고 있습니다. /(noise)
# 그리고 (십오 개국만)/(15개국만) 동성애에 대해서
# 계속 그걸 조장하고 권장하고 이런 식으로 가고 있는 것이 차별하지 말자는 거
# 차별하지 말자는 것이 적극적 의미로 하면은 그것은 정상이고 그것을 어 마음껏 할 수 있도록
# 네.
# 돌봐 줘야 된다라는 의미까지 확대된다는 지금 국가인권위원회 법이
# 네.
# 그 성적 지향이 그렇게 지금 활용이 되고 있습니다.
# 그것이 잘못됐다고 주장 동성애가 나쁘다고 하는 사람을 처벌하도록 그래서 심지어는 지금 국회 올라온 차별금지법에는 어 동성애를 나쁘다고 표현하는 순간에 (일 년)/(1년) 이하의 징역형
# 그다음에 (천만 원의)/(1000만 원의) 벌금형에 처하도록 하는 조항이 지금 들어가 있는 그런 것들이 지금 우리 사회가 추진되어 있거든요.
# (표현에 대한 얘기도 말씀하셨고요.)/(idiom)
# 어~ 그러니까 지금 어쨌든 기본적으로 인권을 보장해야 되는 법조차 지금 인정하지 못하시는 상황에서 토론을 진행해야되는 상황이 지금 저는
# 너무 이게 좀 정상적인 토론인가 지금 싶기도 하구요 그리고 인권을 보장하는 방안 그러니까 교사들의 인권 때문에 지도 학생 생활지도를 안 하겠다는 것이 아니라
# 어~ 그 인권을 존중하는 방식으로 학교에 생활 문화를 바꿔보겠다는 거거든요.
# 그런데 그거에 대해서 뭔가 좀 잘못 이해를 하고 계신 것 같구요.
# 그리고 자꾸 지금 법 조항이 있는데 그걸 해석하는 것은 해석하는 사람의 몫이잖아요.
# 그런데 차별 금지 조항이 있다는 걸 자꾸 조장의 의미라고 주장하시는 것은 그렇게 해석하시는 분들 사실을 이야기거든요.
# 그래서 그것을 계속 반복 하시는 게 좀 앞뒤가 안 맞는다고 생각합니다.
# 네 지금까지 그 개정안에서 저희가 지금 주요 이슈가 되는 그런 조항들을 몇 가지 지금 같이 (논의를 해 봤는데요.)/(idiom) `
# 사실 이 학생인권조례 개정에 주된 이유는 바로 이 학생 생활지도가 안되고 교권이 침해가 된다는 것이였거든요.
# 저희가 여기에 대해서 좀 어~ 심도 깊게 (논의를 한번 해 봤으면 좋겠습니다.)/(idiom)
# 자료에 의하면 하루 평균에 교권 침해 사례가 (사십 건을)/(40건을) 넘는다고 합니다.
# 학생인권조례 때문에 교실 통제가 불가능하다 이런 말까지 나오고 있는데요.
# 여기에 대해서 좀 저희가 좀 바로 한번 정말 궁금한 게 학교 현장에서 학생 생활 지도를 담당할 수 있는 선생님들은 어떻게 느끼는지에 대해서 알고 싶거든요.
# 아 그런 측면에서 선생님 (두 분)/(2분) 자리하고 계신데 (한번 여쭤보도록 하겠습니다.)/(idiom)
# 먼저 안녕하세요 네 지금 저희가 이~ 그 생활지도가 안 된다 교실 붕괴다 이런 비판들이 굉장히 많은데요 (어떻게 생각하시는지요.)/(idiom)
# 자 학생인권조례로 인해서 일어난 것에 대해서 좀 말씀을 드리고 싶습니다.
# 저 이 그림을 보시면 이게 아시다시피 천칭 저울입니다.
# 사실 교육이라는 것에서 학생인권이 무너졌으니까 학생인권을 세우자고 하고 그러므로 인해서 교권이 무너졌다고 했습니다.
# 이번 개정안은 이것을 바로잡고자 그러면 같이 가는 그러한 것으로 가자고 하는 겁니다.
# 사실은 이 인권이라는 것이 개인의 문제이기도 하지만 교육의 차원에서 보면 결국은 공동체의 일원으로 가야하는 겁니다.
# 왜 학생이 언제나 여기서 토론회에서 저는 참 안타까운 게 그런 겁니다.
# 왜 선생님들이 얼마나 힘들고 아니면 학생들이 얼마나 힘들고 학생들의 인권을 보장받지 못했느냐에 얘기를 하는 거 물론 중요합니다.
# 그러나 더욱더 중요한 것은 과연 우리가 민주 시민으로서의 소양을 중고등학교 때 어떻게 키워가고
# 내가 타인에 대한 배려와 아니면 존경심을 가져야 하는 그러한 소양을 키워주는 것이 바로 인권교육의 지름길이라고 생각을 합니다.
# 그런데 지금 계속 토론 되는게 저도 생방송 한 (오백 분)/(500분) 했습니다만
# 네.
# 항상 그 얘기예요.
# 그러면 이 토론은 아무 의미가 없다는 겁니다.
# 이게 갈등을 조장한다 맞아요 갈등 주장합니다.
# 그런데 이론적인가 하고 현실에서 부딪치는 거하고 엄청나게 다르죠.
# 저도 생활지도부장을 (이 년)/(2년) 하고 있습니다만 진짜 명퇴가 (세 배)/(3배) 급증 했다는 거죠.
# 왜 그 교직을 천직으로 알고 있던 그 많은 분들이 이제 도저히 애들 못 가르치겠어 하고 교단을 떠나야 합니까.
# 그 아픈 사람들의 가슴은 안 세겨지세요.
# 학생들이 오히려 수업현장을 방해하고 그런 학생들을 인권이라는 미명하에 다른 학생의 학습권을 수업권을 보장할 수 없다면
# 네.
# 결코 인권이 될수 없습니다.
# 인권여 가장 근본적인 목표로 돌아가십시오 예.
# 네 이번 그 개정안이 어 그~ 학교에서 지금 말씀하신 여러 가지 이런 문제들을 해결하는 데 (얼마나 기여할수 있다라고 보시는지요.)/(idiom)
# 예 결코 해결을 기여할 수 없습니다.
# 지금 보면 (육 조와 구 조)/(6조와 9조) (십칠 조와 이십 조입니다)/(17조와 20조입니다) 처벌 금지라든지 방과 후 수업 위의 학습권이라든지 집회의 자유라든지
# 또 학교 운영에 참여할 권리가 있습니다.
# 이것은 결코 학생의 인권과 맞닥뜨리는 것이 아닙니다.
# 어떻게 자율학습이라든지 그러한 방과후 수업이라는 것이 학생의 인권과 관련이 되어 있습니까.
# 그리고 집회의 자유라는 것도 보십시오 그 인권이 발효되기 이전부터 학생들이 진짜 불의에 항거했다면 (사일구가)/(4.19가) 일어나지 않습니까.
# 그러한 것들의 개념에 있어서 민주 시민으로서 소양과 그리고 타인에 대한 배려가 중요한 거지.
# 학생이 이만큼 억압 받았으니까 학생의 인권을 키워야 한다.
# 성적 소수자 그런 것도 물론 시대에 따라서 시대적 상황의 카테고리가 어떻게 흘러가느냐에 따라서 당연히 바뀌어질 것입니다.
# 물론 선각자라고 생각할 수도 있겠지만 지금의 입장에서는 그것보다 학생들에게 타인에 대한 배려와 존경 너의 인권도 존중하지만
# 다른 사람과
# 학생인권조례 개정안에
# 예.
# 만약 만약에 실행이 된다고 그러면은 그 지금 말씀하신 교권 침해라든지 이런 (문제들을 해결하는 데 기여할 수 있다고 보시는 거예요?)/(idiom)
# 수가 없는 거죠.
# (그럼 어떻다고.)/(idiom)
# 그러니까 그 아까 지금 제가 얘기했던 (육 조 구 조 십칠 조 이십 조)/(6조 9조 17조 20조) 같은 독소 조항이 버젓이 살아 있잖아요.
# 네.
# 그니까 그러한 것들이 조금 개정이 됐을 뿐이지 아까 제가 보여줬던 이 당연히 폐기가 돼야
# 폐지돼야 된다.
# 그리고 나아가서 포커스를 다시 맞추자는 거죠.
# 학생의 인권이라는 것은 확실히 다른 타인에 대한 배려와 존경심 그리고 같이 가는 공동체 사회에서 내가 민주 시민으로서의 소양을 어떻게 키워갈 것인가
# 그럼으로써 나의 인격을 어떻게 키울 것인가에 대한 깊은 성찰이 있어야 한다라고 생각을 합니다.
# 알겠습니다 조금 더 이따가 (다시 또 얘기 들어보고요.)/(idiom)
# 그럼 이 자리에 (또 다른 의견을 가지신 학교 선생님도 나와 계시는데요.)/(idiom)
# 안녕하세요.
# 안녕하세요.
# 네 지금 (개정에 대해서 반대하시는 입장이시죠.)/(idiom)
# 네.
# 네 한번 (이유를 좀 말씀해 주시겠습니까?)/(idiom)
# 어~ 지금 현재 학교 혼란의 주범이 학생인권조례 때문이라고 하는 부분에 대해서는 전혀 동의할 수가 없습니다.
# 어~ 지금 현재 서울시내 같은 경우도 어~ 중고등학교에서 두발제한 규정을 아직까지도 두고있는 학교가 (팔십 퍼센트가)/(80퍼센트가) 더 되고 있습니다.
# 즉 이 얘기는 무슨 얘기냐 하면은 국감 때 만들었던 학생인권조례가 현장에 있는 학교에서 교칙 개정으로까지 이어지지 않고 있는 상황에서 학교 혼란의 주범이
# 학생인권 때문이라고 하는 부분에 대해서는 전혀 동의할 수 없습니다.
# 어 생활부장을 (이 년째)/(이년째) 맞고 있습니다.
# 아무도 맞지 않으려고 하는 그런 어려운 자리였지만 이것은 교사로서 꼭 맡아야 한다는 어떤 나름의 어떤 사명감이 있었고요.
# 그리고 또 나름 학생인권조례를 어~ 학생 규정으로 한번 바꿔보고 싶었습니다.
# 그래서 저희 학교에서는 그 실험을 한번 해봤습니다.
# 학생인권이 어 적용된 생활규정으로 학생들을 지도했을 때와 그 이후에 어 어떤 식으로 변화가 되나 이렇게 쭉 변화를 한번 봤습니다.
# 그래서 그전에 했던 (이천십이 년도에)/(2012년에) 학교폭력 굉장히 심했었죠.
# 그때도 보면 (이천십이 년도에)/(2012년에) 어 학교폭력의 가해자 수가 (스물세 명이었었는데)/(23명이었었는데) 우리 학교에서요.
# 어~ 작년에는 (아홉 명으로)/(9명으로) 줄었습니다.
# 이 학생생활규정에 서울 학생조례를 충실히 반영한 조항이었습니다.
# 그리고 그다음에 가해자 조치 별도 보면 (이천십이 년도에는)/(2012년도에는) (서른아홉 건이었는데)/(39건이었는데) 작년에는 (열두 건으로)/(12건으로) (오십 퍼센트)/(50퍼센트) 넘게 줄었습니다.
# 이게 무슨 이야기냐면 학생인권조례가 학교폭력을 조장하거나 학교 현장을 파괴하는 주범이 아니라 오히려 학생들로 하여금 주인의식을 발휘해서
# 오히려 학교에서 수업권이나 학교폭력을 줄이는데 큰 도움을 주었다는 사실입니다.
# (이천십이 년도에)/(2012년에) 우리학교에서는 어~ 경찰 순찰차가 상당히 많이 출동했었습니다.
# 그 이유는 수업 시간에 학생들이 어~ 그~ 뭐야 (일일이로)/(112로) 곧바로 신고를 해서 어 선생님들을 신고하는 일이 비일비재했지만
# 작년에는 단 (한 건도)/(1건도) 어 순찰차가 출동하는 일이 없었습니다.
# 네.
# 어~ 그리고 이것은 단지 우리 학교만의 문제가 아니라 여기 보면 어 (이천십이 년도 십삼 년도)/(2012년도 13년도) 어 교육감 성향별 학교폭력 증감률입니다.
# 어 여기 보면 학생인권조례가 있는 진보 교육감 쪽과 학생인권조례가 없는 보수 교육감 쪽에 학교폭력 증감률을 보면
# 어~ 진보 교육감인 경우에는 심의 건수와 가해 학생수 피해 학생 수가 (이십 퍼센트)/(20퍼센트) 넘게 줄었습니다.
# 네.
# 그런데 학생인권조례가 전혀 시행되지 않고 있는 보수 교육감인 경우는 어 심의 건수는 (칠 점 일 퍼센트)/(7.1퍼센트) 줄었지만
# 가해 학생 수는 오히려 (일 점 이 퍼센트가)/(1.2퍼센트가) 늘어나는 그런 상황
# (학생인권조례가 학교폭력에 영향을 주지 않는다 이런 말씀하셨고요.)/(idiom)
# 네 그러면 (다른 학생의 학습권을 좀 침해한다라는 이런 주장도 있거든요.)/(idiom)
# 네.
# 어 뭐 북한군이 남한으로 침략하지 못하는 가장 큰 이유가 중학교 (이 학년)/(2학년) 때문이라고 할 정도로 중학교 (이 학년)/(2학년) 학생들이
# 학교폭력이 굉장히 심하다는 것을 우리 대한민국 사람들은 거의 다 알고 있을 정도입니다.
# 그런데 우리 학교에서는 지금 보면 학교폭력을 뿐만 아니라 어 교권 침해를 비롯한 어떤 선도처분을 받은 학생의 수가
# (일 학년)/(1학년) 학생이 (이 학년분의)/(2학년분의) 배가 됩니다.
# 이게 무슨 이야기냐면 (일 학년은)/(1학년은) (이 학년)/(2학년) 학생보다 여기 표를 보면요 (한 명이)/(1명이) 더 많습니다 재학생수가 그런데 학급 수는 오히려 줄었어요.
# 이 얘기는 무슨 얘기냐면은 (한 학급의)/(1학급의) 학생 수가 (이 학년보다)/(2학년보다) (다섯 명)/(5명) 내지 (여섯 명이)/(6명이) 많다는 사실입니다.
# 지금 무슨 이야기냐면 요즘 조류 독감도 여러 가지 얘기도 있는데 밀집된 주거환경이 결국 질병과 폭력을 수반하게 됩니다.
# 지금 학생들도 어떤 규칙으로서 학생들을 옥죄는 일이 아니라 학생들로 하여금 (오이시디)/(OECD) 상위권에 맞는 학급 당 학생 수 (이십 명)/(20명)
# 이것을 목표로 해서 어떤 교권이나 어떤 학습권을 보장하는 측면으로 나가야지
# (오히려 다른 측면에서 교육 여건이 개선이 필요하다 라는 말씀하셨고요.)/(idiom)
# 네 감사합니다 지금 (플로어에서)/(floor에서) (두 분)/(2분) 선생님들께서 말씀을 주셨는데 먼저 그~
# 어 우리 김 아까도 말씀하신 것 중에 (한 가지가)/(11가지가) 교실 통제불능의 주된 원인이 학생인권조례 때문이라는 어떤 직접적인 인과관계는 없다 하시면서 이렇게 또 자료도 보여주셨는
# 저한테 말씀하시지만 이 선생님이 말씀하신 저는 제 친구 중에 선생님이 참 많습니다.
# 그런데 이번에도 정말 중학교 사회 선생님 아이가 명퇴를 하면서 더이상 학교에 있을 수가 없다.
# 또 고등학생 친구 그 선생도 작년에 명퇴를 했습니다.
# 너 같은 아이는 학교에 남아있어야 해 근데 아 도저히 있을 수가 없어 그리고 열심히 하는 거를 권장하지도 않고 정말
# 이 진짜 학교에 있는 게 고통스러워 라고 말할 정도로 지금 그게 꼭 학생인권조례 때문인지는 모르지만 아이들이 굉장히 통제할 수 있는 수단을 선생님들 자체가 뺏겼다고 생각하는 거예요.
# 그런데 교사로서 정말 아이들을 제대로 가르치고 싶은데 뺏겼을 때 굉장히 무기력하게 느낀다는 거예요.
# 무기력하고 과연 내가 이런 상태에서 교사를 할 수 있을까 하고 싶지 않다.
# 아이 이쯤에서 그만두자라고 진짜 정말 경기도에서 명퇴가 제일 많았지 않습니까.
# 결코 조례하고 무관하다고 말할 수 없어요.
# 선생님들에게 힘을 실어드리고 선생님들에게 학교 자유를 줘서 학교의 구성원들끼리 학교의 규칙을 정하고 주인의식을 가지고 할 수 있도록 해야지.
# 왜 정부에서 전체 그 학교에서 진짜 물감을 머리에 물들이던 뭘 하든지 그 학교에서 정하면 됩니다 저는 우리 아들을 그런 학교에서 길렀기 때문에
# 그렇게 (일 년)/(1년) (이 년)/(2년) 지나다 보니까 전부 아이들이 전부 염색했다가 한 (일 년)/(1년) 지나니까 자기 머릿결이 다 나빠지니까 그 학교의 규칙은 그대로 다
# 머리에 염색을 해도 되는데도 파마를 해도 되는데도 아이들이 지금 하나도 안 합니다 우리 아이 후배 아이들을 보면.
# 학교마다 사정이 다 다르고 그 지역의 구성원들의 생각이 다르고 소득 수준도 차이 있을 수 있고 생각도 다른데
# 왜 이런 인권조례라는 거를 상위법의 역할을 하고 세상 어디에도 없는 거를 가지고 다 똑같이 하도록 하는 게 과연 다양성을 주장하고 막 아이들에게 인권을 줘야 한다는
# 이런 정말 전교조를 비롯한 이쪽 생각들이 도대체 무슨 생각을 가지고 이렇게 인권조례에 목을 매시는지
# 특히 법학자들이 왜 거기에 그렇게 앞장서가지고 그냥 학생인권조례가 없으면 아이들의 인권이 마치 지켜지지 않는 것처럼 얼마든지 아이들 인권 지켜 줘야 됩니다.
# 그렇지만단위 학교는 뭡니까 그 학교 교장교사는 뭐예요?
# 네.
# 그분들이 결정할 수도 있고 우리 학부모들도 참여해서 거기에서 우리가 우리 아이들은 정말 학교 다닐 때는 교복을 어느 정도 무릎까지는 좀 입었으면 좋겠어 얘들아 그래다오
# 하고 아이들한테 하고 그런 것이 하나도 손댈 수 없도록 학교 교칙이 아무 무의미하게 인권조례 때문에 다 손을 놓을 수 밖에 없는 상황이 되는 그런 인권조례
# 네.
# 좀 제발 좀 손 좀 놔 주십시오.
# (두 분이)/(2분이) 다 하실 말씀이 있으실 것 같으세요 먼저 법학자에 대한 얘기도 잠깐 짚어주셨는데 네 (한번 하시죠.)/(idiom)
# 지금 말씀하신 것이 어느 정도 공통점을 찾을 수 있는 부분이 있다고 생각합니다 그러니까 학교 교실의 붕괴 원인은 다양하죠.
# 그 중에 하나라고 한다면 뭐 모르겠죠 그러면 어떤 것인지에 대한 고민들을 우리가 같이 해야 되는 문제인 거고요.
# 지금 자녀분 말씀을 하시면서도 기본적으로 학생들에게 판단권을 주었더니 학생들에게 머 머리를 길러라 아니면 파마를 해라 이런 게 아니잖아요 그러니까 기본적으로 그러한 판단은
# 학생들에게 맡기면 학생들이 스스로의 규율에 의해서 할 수도 있고 그중에 어떤 학생은 아 나는 나는 어찌됐든 간에 내 개성에 자유가 있으니까 그렇게 하겠다라고 말할 수 있는 거라는 거죠.
# 그것들을 인정해주자 하는 겁니다 그러면 퍼머라는 것이 문제가 된다라고 한다면 초등학생 유치원생들은 또 하잖아요.
# 그거와의 어떤 관계도맞지 않
# 그렇게 멋대로 어떤 규칙도 없이 어떻게 학교가 유지가 됩니까.
# 공동체에도 물론 질서는 필요하죠 그래서 수업을 방해한다라고 하는 점도 이해를 해 보면
# 분명히 그 학생의 폭력적인 행위를 하게 된다라고 한다면 그 부분을 일정 정도는 법에 의해서 처벌을 받아야 될 경우도 있을 거고요.
# 법의 처벌을 받지는 않지만 학교의 징계 절차에 의해서 받아야 되는 경우도 있을 거고요 .
# 그렇지 않은 경우도 있습니다 이건 죄가 아닌 얘긴는 무조건 인권이라는 이름으로 모든 걸 다 감싸주자는게 아니고 적절히 나눠서 판단해준다 해줘야 된다는 거예요 그런데 문제는 뭐냐 하면
# 네.
# 인권이 무엇이고 교권이 무엇인지에 대한 우리가 합의가 없는 거예요 그렇다라고 한다면
# 그것에 대한 얘기를 가지고 풀어나가면 되실 문제인 거지 지금 말씀을 학부모님은 자신이 가지고 있는 기준이 결국은 인권의 모든 것인냥 이렇게 말씀을 하고 계시니까 그렇지 않고
# 다양한 기준을 가지고 우리가 한번 적어도 국제적인 인권 기준과 헌법이 얘기하고 있는 것 만큼은 최저한도의 기준으로 굉장히 정말 우리가 얘기를 하고
# 네 (이번에 선생님 말씀 좀 더 들어보겠습니다.)/(idiom)
# 네 그리고 아까 이제 교사 학생 학부모가 같이 정했으면 좋겠다 이렇게 말씀하셨는데요.
# 학생인권조례야말로 참여권이 가장 구체적으로 보장돼 있거든요 그래서 학생들이 스스로 참여하고 자취를 이뤄낼 수 있는 방법에 대해서 굉장히 구체적으로 보장하고 있고요.
# 그래서 그런 어 같이 의논했으면 좋겠다라는 것을 우리가 학생인권조례가 굉장히 도움이 된다는 사실을 좀 알려 드리고 싶고요. /(noise)
# 그리고 사실 그 학교별로 정한다는 게 어 학교의 자율성을 이렇게 신장시키는 것 맞지만
# 어떤 최소한의 인권의 가이드라인도 없는 상황에서 사실 자의적으로 결정되는 경우가 되게 많거든요. /(noise)
# 그러니까 학교별로 천차만별이라는 게 사실 어느 지역 어느 학교 있느냐에 따라 자기 기본적으로 보장받아야 될 인권의 내용과 폭이 전혀 달라지는거죠. /(noise)
# 그럼 학생들이 인권을 전혀 서로 다른 것으로 이해 하게 된다는 겁니다 그래서 학생인권조례에서는 획일화하자는 뜻이 아니라 학생들의 다양성을 충분히 보장하고
# 서로 어쨌든 대한민국의 학생으로 태어났다면 이 정도 인권을 보장 봤다는 최소한의 가이드라인을 주고 있는 것이거든요.
# 그래서 오히려 다양성을 보장하는 예 그런 조례라는 점을 말씀드리고 싶습니다.
# 저는 지금 동의하기가 좀 어렵습니다 왜냐하면 학생인권조례를 보면 시시콜콜하게 별거별거를 다 너 구속을 합니다.
# 심지어는 소위 말했던 성 소수자까지 다 배려하는 굉장히 우리 그 사회에서 아직 논의가 안 됐던 부분입니다 동성애에 대한 부분은.
# 그런 것 까지 앞서가면서 그 인권조례에다 집어넣었거든요.
# 사실 이 법라는 것은 그 사회에 있어서 최소화하는 것을 제한하도록 하는 것이 원칙이라고 생각됩니다.
# 우리 법학자님께서 계시니까 시시콜콜한 것까지 다 법으로 정하고 조례로 정하고 법령으로 정하는 것은 사회적 피해가 크죠.
# 이것 때문에 인권 때문에 이런 법령을 만들고 조례를 만드는 건 과도하다고 생각되고요.
# 만약에 그랬다면 교권을 위해서는 교권보호법을 만들어야 되겠고 또한 학습 학부모 학습 교육관을 위해서는 학부모 원을 하는 조례를 또 만들어야 되고
# 그러면 계속 조례를 만들면서 그때그때 이렇게 한다면 우리 사회가 얼마나 참 회피해야 되겠습니까.
# 어 우리 대표님 말씀하신 대로 학생의 인권에 대한 부분들은 학칙에 담아서 또 저는 우리 교장선생님이나 교사 선생님들이 이제는 인권 의식이 많이 높아져서
# 조례 없이도 충분히 학칙에 그러한 인권을 보장할 수 있는 내용들을 담을 수 있다고 생각됩니다.
# 네 지금
# 세밀화 시켜서 서울시 전체 학교에 동일하게 무언가를 주입하려고 하는 그런 시도
# 하셨는데요 지금 저희가 지금 이제 학생인권조례 개정이 어~ 과연 이 교권 침해에 어떤 영향을 미치느냐 여기에 대해서 지금 (선생님들한테 얘기를 들었는데요.)/(idiom)
# 궁금한게 사실 당사자인 학생들이나 또 학부모님들께서는 (여기에 대해서 어떻게 생각하는지 좀 굉장히 궁금합니다.)/(idiom)
# 어 이 자리에 지금 학생과 학부모님 자리 하고 계시는데요 말씀 들어보고 저희가 지금 (논의도 계속 이어가도록 하겠습니다.)/(idiom)
# 네 이번 개정안에 사실 학생들의 의견이 반영되지 못했다는 비판의 목소리가 많은데요 먼저 (학생 의견부터 한번 들어보겠습니다.)/(idiom)
# 네 안녕하세요.
# 네 안녕하새요.
# 네 (학생인권조례 개정에 대해서 어떤 입장이신지요.)/(idiom)
# 네.
# 저는 (학생인권조례에 대해서 다소 찬성하는 바입니다.)/(idiom)
# 다소 찬성이다 네.
# 하지만 더 나아가서는 (학생인권조례는 폐지되어야 한다고 생각합니다.)/(idiom) `
# (근거를 좀 짧게 말씀해 주시죠.)/(idiom)
# 왜냐하면 저는 이전에 서울시 교육청에서 주관하는 토론회에 참석했었는데 거기서도 학생인 아 학생참여단의 만행을 보게 되었습니다.
# 그들은 학생인권조례를 만들고 홍보하는데 있어서 큰일을 하였는데 그들은
# 애국가도 부르지 않았고 국기에 대한 경례도 하지 않았고 그리고 심지어 그 자리에서 일어나지도 않았습니다.
# 그리고 다른 의견을 가진 사람들에겐 폭언을 하였고 욕설을 하였고 그리고 폭행까지 하는 것을 저는 보았습니다.
# 네 그것도 있겠지만 또 학생인권조례 그 개정에 대해서 찬성하는 그 (근거를 조금 더 구체적으로 말씀해 주시면 좋겠는데요.)/(idiom)
# 네.
# 학생들이요.
# 네.
# 것을 만들었잖아요 학생참여단이 주체해서 그것을 만들었잖아요.
# 네.
# 이건 시작부터 잘못됐습니다 그들은 국가관도 없으며
# 네.
# 개인 인격도 파괴되었어요 .
# 조금 있다 그러면 좀 말씀을 들어 볼까요 옆에 있는 학생 얘기를 들어보고요 먼저 네 옆에 지금 다른 학생도 지금 찬성하는 학생도 있는데요.
# (찬성 하는걸로 알고있는데 근거 좀 말씀 부탁드리겠습니다.)/(idiom)
# 저는 (저도 또한 학생인권조례가 폐지되어야 한다고 생각하는데요.)/(idiom)
# 그 문제점에 대해 얘기하자면 먼저 차별받지 않을 권리라는 조항에는 임신 출산의자유 사상의 자유 성적 지향에 자유 등의 항목이 포함되어 있었습니다. /(noise)
# 이것을 개정안 이후에는 가족 형태의 자유와 또 개인성향의 자유로 바꿨다고 하지만 그 개인 성향이라는 말에는
# 임신 출산의 자유 성적 지향에 자유 또 사상의 자유 모두 포함될 수 있다고 생각합니다.
# 사상의 자유가 만약에 있다면 우리가 지금 광화문에 가서 @이름3 만세를 외쳐도 그거 우리가 보고만 있어야 된다는 것 아닙니까.
# 또 학교에서 개인 성향의 자유가 있다고 가르친다면 우리 학생들에게는 충분히 동성애를 조장하고 퍼트릴 위험이 있습니다.
# 아까 반대 선생님께서 그것은 각자의 해결 그 각자 해석하는 사람들의 의견이라고 생각 말을 하셨는데
# 우리 학생들이 아직 인격이 덜 성숙된 우리 학생일수록 이 현실에서 반영되어져 가는 대다수 사람들의 의견 또한 반드시 반영해야 된다고 생각합니다.
# 만약 학교에서 학교 화장실이나 그런 데서 남자끼리 또 여자끼리 애정 행각을 벌인다면 학교에서는 또 선생님들은 우리들은 그걸 보고만 있어야 합니까.
# 대다수의 국민들이 거의 (팔십 퍼센트에)/(80 퍼센트에) 육박하는 국민들이 동성애를 반대하고 있는데
# 이러한 독소 조항들을 인권학생들의 인권조례라고 넣는 것은 학생들의 인권을 오히려 침해하는 거라고 생각합니다.
# 네 학교이므로 학생이므로 네 좀 신중한 접근이 필요하다는 얘기였군 네 괜찮습니까 네 좋습니다 그러면
# 어 이번 그 개정안에 지금까지 찬성하는 학생의 목소리를 들어봤고요.
# 그러면 개정을 반대하는 목소리를 좀 들어보겠습니다 먼저 대일외국어고 어 예 네 그 (반대하는 이유 좀 말씀해 주실까요?)/(idiom)
# 네.
# 네 먼저 저는 원래 여기 절차상의 문제 개정안에는 절차상의 문제를 짚기 위해 나왔는데
# 네.
# 지금 계속 학생참여단 얘기를 하시니까 제가 안 드릴 수가 없네요.
# 즉 지금 말씀하시는 거 보면 저는 지금 종북 좌파에다가 국가관도 없고 그다음에 어르신들을 향한 공경도 없는 그런 아이네요.
# 저도 그 개정안 토론회에 참여를 했습니다.
# 참여를 했었는데 지금 아주 교묘하게 빼서 얘기 하시는데 그때 당시 참여했던 초등학교 (육 학년)/(6학년) 중학교 (일 학년)/(1학년) 이런 어린 학생들한테까지
# 어르신들이 와가지고 막 닥쳐라 욕하 닥쳐라 이러면서 막 욕하고 있는데
# 그런 분위기에서 학생들이 어떻게 그 학생 (두 명이)/(2명이) 말을 할 수 있었으며
# 그런 분위기에서 어떻게 왜 학생들이 피켓을 들고 시위를 할 수밖에 없었는지 그것을 생각해 보시라는 거죠.
# 그게 초등학생들이 와 있는데 그런 분위기에 욕을 하시는 분들이 지금 인권이 과잉이다 이러면서 욕을 하고 있습니다 이제는 제가 지금 좌파 소리까지 듣는데 제가 이건 좀 불쾌한거 같아요.
# 국가관이 없다든지 이런 말은 좀 삼가주셨으면 좋겠고요.
# 네 개정안 자체에 절차상의 문제를 이제 얘기를 하자면 이제 학생인권조례는 엄연히 지금 시행 중인 법적 효력을 가지고 있는 조례입니다.
# 그런데 이번 개정안에 내놓은 절차에서 교육청 측은 조례상에 명시된 (제삼십칠조 사심삼 조에)/(제 37조 43조에) 명시되어 있는 학생 참여단의 의견수렴
# 그리고 학생인권위원회 인권 영향 평가라는 절차를 무시한 채 일을 진행했어요.
# 게다가 처음에는 즉석 안건 형식으로 학생 참여단과의 논의를 거쳤다 이런 허위보도까지 냈는데 이것에 대해서 해명을 해드리자면 콘서트라는 이름으로 저희가 행사를 가진 건 맞습니다.
# 하지만 그거는 학생들의 학교생활 전반에 대한 얘기를 하는 자리였고 인권에 대한 얘기가 (한 번)/(1번) 나온 적이 있었어요.
# 교육감이 일방적으로 소지품 검사가 그거 필요하지 않겠냐 이렇게 얘기를 했었어요.
# 근데 그거에 대해서 학생들의 의견을 들어보거나 아니면 저희 참여단 내부에서 따로 의결을 하거나 이런 적은 없습니다.
# 그러니까 저희가 보기에는 그렇습니다.
# 학생들의 의견의 듣거나 아니면 학생인권위원회를 거치게 되면 절차가 복잡하게 되고 반대하는 목소리가 분명히 나오니까
# 일단 무조건 개정안을 내겠다고 입법예고부터 하고 보고
# 그러니까 행정편의적인 그런 절차를 밟는 것이 아닌지 (제 생각은 그렇습니다.)/(idiom)
# 네 (개정 절차에 학생의 의견이 더 반영되었어야 된다라는 말씀이셨고요.)/(idiom)
# 그렇죠 원래 조례상에 따르면 학생 참여단들 그러니까 학생참여단들과도 얘기를 하게 되어 있고
# 학생인권위원회와도 당연히 논의를 거치게 되어 있는데
# 네.
# 조례에 보면 학생인권위원회가 권고하고 중단이나 수정을 권고하면 교육감은 네.
# 네 그럼 옆자리에 또 그 청소년 인권단체인 아수나로 회원인 에 나오셨는데요 안녕하세요.
# 안녕하세요.
# (반대 입장을 이유 좀 말씀해 주시겠습니까.)/(idiom)
# 아 네 그동안 학생인권조례가 서울에서 시행된 지 (이 년이)/(이년이) 지났습니다 그런데 아직도 사실 학교 현장에서 학생인권조례가 제대로 잘 지켜지고 있다고 보기는 좀 어려운 것 같습니다.
# 아직도 대부분의 학교에서 두발 규제나 뭐 강제적인 종교수업 체벌 등의 인권침해가 자주 일어나고 있습니다.
# 뒤로는 학생인권조례가 폐지됐다는 거짓 소문도 돌면서 학생인권 침해는 더 자주 일어나게 되었습니다.
# 저 학생인권 조례 개정이 정말 필요하다면 최소한 적어도 제대로 시행이라도 된 채 개정이 돼야 하지 않나 싶은 생각이 있고요.
# 또
# 네 .
# 방금 전에 학생인권조례에서 삭제된 내용이 임신 또는 출산의 자유라고 얘기를 하셨는데 사실
# 그거는 임신 차별 임신 또는 출산으로 차별받지 않을 권리입니다 조례에도 제대로 읽지 않고 오신 것 같아서 굉장히 불쾌하구요.
# 네 (지금 조례 좀 한번 시행 한번 해보자라는 이런 얘기였고요.)/(idiom)
# 학생인권조례 그러면 저희가 좀 시간상 먼저 그러면 계속해서 (지금 학부모님 얘기를 좀 짧게 한번 들어보도록 하겠습니다.)/(idiom)
# 이번에 그 먼저 부모님이신데요 (학생인권조례 어떻게 생각하시는지요.)/(idiom)
# 네 안녕하십니까.
# 네.
# 아 일단 저는 학생 참여단이 있다는 건 지금 에 들어서 알고 있는데 학부모 참여단도 있습니까?
# 제가 학부모로서 예 아까 학교에 주체든 학생과 교사 학부모 또 재단 여러 등등이 있는데
# 예 이런 것들이 정해질 때 학부모 참여단은 없는걸로 제가 지금 알고 있는데 이런 법을 정할 때
# 네 (의견 좀 간단하게 말씀.)/(idiom)
# 누구보다도 인권을 중요하는 게 바로 부모 아니겠습니까 학생이 학생 이전에 자녀입니다.
# 그렇다면 그 자녀의 인권을 부모보다도 누가 더 중요시 생각하겠습니까 그래서 정말 이 법을 먼저 제정하신 분들이 우리 학생들의
# 행복과 건전한 성 윤리관을 배울 수 있는 그러한 권리를 생각하고 법을 제정하신 건지 먼저 묻고 싶고요.
# 저는 이번 개정안에서 어 성적 지향과 성별 정체성 그것이 삭제된 것은 어 너무나 환영하는데 그것이 개인 성향으로 바뀐 것에 대해서 의문이 있습니다.
# 법에 그런 모호한 단어가 있어도 되는 건지 어 개인 성향이라는 걸로 귀에 걸면 귀걸이 코에 걸면 코걸이 라는
# 알겠습니다 개정에 찬성을 하시는데 오히려 좀 표현 애매한 표현도 고쳐 줘야 된다.
# 반드시 수정돼야 된다고 합니다.
# 감사합니다 그러면 (다른 의견도 한번 들어보겠어요.)/(idiom)
# 네 안녕하
# 네 (어떻게 생각하시는지요 반대하는 걸로 알고 있는데요.)/(idiom)
# 일단 반대를 하는데
# 네.
# 사회적으로도 굉장히 학생들이 약자이잖아요 약자들의 인권을 보호하는 것을 시시콜콜하게
# 법으로까지 정해야 되는 이 사회라는 게 일단 우리 아이들에게 좀 너무 미안한 것 같습니다 지금 이야기를 듣다보니.
# 네 사실 법이 적용되기 위해서는 어떤 거든 다 기한이 필요한데요.
# 특히 인권이라는 것과 관련해서는 적용되기는 매우 어려운 여러 가지 좀 조건들이 있을 거라고 봅니다.
# 근데 지금 (이 년도)/(2년도) 사실은 좀 (이 년)/(2년) 안되죠.
# 근데 그 사이에 학생들과 교사와 학부모들에게 인권이 무엇인지 그리고 인권 학생인권조례가 어떤 내용인지에 대한 교육도 사실 제대로 진행되지 않고 있거든요.
# 조금 더 홍보가 필요하고 교육이 필요하다는라는 말씀이신데요 감사합니다.
# 그러면 여기서 저희가 이어서 (한 번)/(1번) 더 마저 (시청자 전화 연결까지 한번 해보도록 해보겠습니다.)/(idiom)
# 안녕하세요.
# (학생인권조례 개정에 대해서 어떻게 생각하시는지요.)/(idiom)
# 네 교육적인 측면에서 우려의 말씀을 주셨고요.
# (그럼 전화 (한 통)/(1통) 더 받아 보겠습니다.)/(idiom)
# 안녕하세요.
# 네 지금까지 아 객석에서 또 그리고 전화를 통해서요.
# 어 (학생인권조례 개정에 대한 어 반대의 입장 또 찬성의 입장에 대해서 좀 저희들이 한번 좀 들어봤습니다.)/(idiom)
# 어 시간이 저희들이 드 이번 토론 시간이 많이 남지 못해서요 마지막으로 네 어 이번 (학생인권조례 개정안에 대해서 어떻게 생각하시는지)/(idiom)
# 포함을 해서 짧게 (마무리 말씀을 한번 부탁드리겠습니다.)/(idiom)
# 각 분당 한 (일 분도)/(1분도) 채 못남은 것 같은데요.
# 아 죄송하구여 먼저
# 지금 다양한 생각을 가지고 있는 학생들이 발표를 하셨습니다 그래서 표현의 자유와 사상의 자유를 인정하자는 거죠.
# 학교에서 배워야 할 것은 그러한 인권 존중 속에서 서로 다른 생각을 가지고 있다는 이유로 배척하는게 아니고 함께 모아서 인권이 무엇인지 민주주의에 대한 생각을 함께
# 나눠 보자라고 하는 것이 사실은 인권조례에 출발점입니다 그래서 서로가 서로의 인권을 존중 해주는 것이 인권조례이기 때문에
# 오히려 이런 지금 개악안과 같은 것들을 어 결국은 전혀 관계가 없는 동성애나 성적인 것으로 자꾸 몰고 가는 것 자체가 오히려
# 이런 다양한 생각을 가진 학생들이 건전하게 합리적 토론을 통해서 서로 의견을 교환할 수 있는 기회들을 박탈하고 어른들의 생각으로 재단하는 결과가 된다라고 하는 점에서
# 이 개악안은 어 철회가 되어야 한다라고 생각을 합니다.
# 예 아까 방원중학교 선생님 뭐 학교 통계자료를 가지고 하셨는데 과연 그것이 인권조례를 잘 지켰기 때문에 그럴까라는데 저는 의구심을 갖습니다.
# 오히려 선생님이 정말 열심으로 학생들을 관심을 갖고 잘 지도했기 때문에 일어난 일이 아닌가 싶습니다.
# 이와 같이 저는 인권조례가 없더라도 선생님 (한 분이)/(1분이) 정말 사명감을 가지고 열심히 학생들의 인권을 위해서 학교의 여러 가지 문제에 대해서 앞장선다면 다 해결될 것이라고 생각됩니다.
# 그런 의미에서 학생인권조례에 이러고 만들어서 사회적 갈등 유발하고 여러 가지 문제들을 일으키는 것보다는
# 학칙에 담아서 학교 안에서 스스로 문제 해결할 수 있도록 하는 것 또 넓은 의미의 최소한의 어떤 인권이 필요하다면
# 인권 선언문 아니면 인권 헌장 이런 정도로 한번 하는 것이 어떨까 이걸 조례로 만들으니까요 이게
# 네.
# 법이 돼 가지고 굉장히 구속력이 생기고 많은 사람들에게 부담을 주고 갈등을 유발합니다.
# 학부모 교육권까지도 이제 법을 또 제정해야 되지 않을까 이런 생각이 드는데 오히려 좀 폐지하는 게 낫다고 생각됩니다.
# (마지막까지 말씀해 주셨구요.)/(idiom)
# 예 저는 저런 방원중학교 같은 사례가 전국의 학교에 퍼지기 위해서라도 저는 학생인권 조례가 꼭 필요하다고 생각되구요.
# 오늘 학생인권조례 개정에 찬성하시는 분들을 보니 오히려 정말 더 학생인권조례가 필요하고 제대로 된 인권교육이 필요하겠다 왜냐하면 학생인권조례에 대한 오해가 너무 많으셔서요.
# 예 학생인권조례가 그래서 더 필요하다는 생각을 했고요.
# 네.
# 그리고 학생인권에 침해하는 교권이라는 건 저는 없다고 생각합니다.
# 학생 인권을 어 그리고 교권을 침해하는 학생인권이라는 것도 없다고 생각합니다.
# 학생인권이 보장되는 학교문화 속에서 교사의 인권이나 교권도 보장되는 것이고요.
# 그리고 지금 이게 입법예고가 (십이월 삼십 일에)/(12월 30일에) 됐는데요 사실 다 방학에 들어간 다음이었거든요.
# 제대로된 현장 의견 수렴을 의지를 가지고 지금 개정안을 한 것인지 아니면 졸속적으로 진행하고 있는 것인지 교육청의 어떤 인권보장의 책무를 다시 한번 묻고 싶습니다.
# 네 감사합니다.
# 네 전 이번 학생 조례안의 진짜 학생인권위원회 학생인권교육센터 학생인권영향 평가
# 또 연도별 시행계획 그리고 또 공청회 같은 것을 다 거치고 학생인권 해설서를 만들어서 모든 학생에게 다 나눠줘야 되고 거기에 들어 있는데
# 유치원 학생까지 해설서를 그러니까 인권 교육을 시키게 되어 있습니다.
# 도대체 유치원 아이들이 한글도 못 읽는 아이들한테 그런 책을 만들어서 배포를 하겠다는 게 아직도 그게 담겨져있습니다.
# 저는 도대체 이런 엄청난 예산을 왜 인권을 보장하는 건 정말 선언이나 헌장으로 충분히 가능한데
# 왜 이런 많은 예산을 여기다 쓰려고 하지 우리가 한정된 예산에서 인권이라는 이름하에 정말 필요없는 교육에 시간도 할애해야 되고
# 이런 금액까지도 쓴다면 이런 인권조례가 하나도 이번에 이런 것을 개정되지 않았어요.
# 전 수도 없이 그것을 문제 제기했고 계속 숙제를 충실하게 내서 했음에도 불구하고 전혀 고쳐지지 않는 인권조례안은
# 저는 정말 교육적인 낭비라고 생각하고 누구를 위한 확실히 이것은 의도한 바가 있는 사람들이 만들어진 조례이기 때문에 절대로 이건 폐기되어야 된다고 생각하고요.
# 우리 어린 아이들에게 권리 주장을 너무나 많이 가리키면 안됩니다.
# 네.
# 권리 주장전에 의무와 책임감 그리고 어린아이들을 진짜 좀 힘들지만 참고 이겨야 되는 것이 교육이라는 것을 어른들이 가르쳐주는 기회가 됐으면 좋겠습니다.
# 이것으로 네 오늘 (토론 마치겠습니다)/(idiom) 출연해 주신 토론자 여러분 그리고 함께해 주신 모든 분들께 감사드립니다.
# 네 학생인권과 교권은 서로 대립되는 것은 아닐 것입니다. /(bgm)
# 둘 다 소홀히 할 수 없을뿐더러 어느 한쪽이 과도하게 강조돼 다른 쪽 권리를 침해하는 일이 있어서는 안 될 것입니다. /(bgm)
# 모두가 우리 교육을 제대로 하고 아이를 올바로 키우기 위한 것이니 만큼 무엇이 가장 합당한 방향인지 더욱 더 진지한 고민이 필요한 시기인것 같습니다. /(bgm)
# 생방송 (이비에스)/(EBS) 교육 대토론 다음주에 뵙겠습니다 감사합니다. /(bgm)
# ----------------------------------------
# File: /mnt/a/maxseats/(주의-원본)주요 영역별 회의 음성인식 데이터/002.주요_영역별_회의_음성인식_데이터/01.데이터/unzipped_files/SRBEJ21000083.json
#
# 네 저희 영화감독의 첫 번째 주제인 @이름1 감독에 대해서 한번 논의를 해보고자 하는데요
# 뭐~ 마블 쪽에선 마블 시네마틱 유니버스라는 게 있듯이 @이름1 감독은 컨저링 유니버스라고 따로 공포물의 대가로 알려져 있는데
# 이런 @이름1 감독이 대해서 한번 첫 번째 발화자님부터 이야기해 주셨으면 합니다.
# 네 저는 우선 @이름1 감독 하면은 공포 영화의 거장이라고 생각을 하는데요 이제 유명한 공포 영화 쏘우
# 막 컨저링 인씨디어스 애나벨 등 여러 유명한 공포 영화를 제작을 했어요 @이름1 감독이
# 쏘우나 인씨디어스 컨저링 모두 뭔가 한정된 공간을 이용해서 공포를 표현한 작품들인데 특히 인씨디어스나 컨저링을 보면은
# 저희가 가장 친숙한 집이라는 공간에서 벌어지는 일들을 담은 작품인데요 그런 친숙한 공간 속에서도 우리가 보지 못했던 낯선 부분들
# 가려진 부분들 구석진 벽이나 침대 밑 그림자 지하실 등등의 요소를 잘 이용해서 공포감을 불러일으킨 영화에요.
# 현재는 공포 영화에 쩜프 스퀘어 기법이라고 관람객들을 깜짝 놀라게 하는 기법이 굉장히 흔하게 자리하고 있지만
# 사실 이전까지는 그러한 공포 기법은 자주 쓰이진 않았고 @이름1 감독이 이러한 방식의 선두 주자라고 할 수 있을 만큼
# @이름1의 공포 영화는 굉장히 영향력이 컸어요 그~ 공포 영화는 뭔가 가족 영화나 히어로 영화 같 햐 히어로 영화와는 달리 뭔가
# 큰 흥행이 힘든 장르라고 생각하거든요 아무래도 장르 자체가 호불호가 갈리기 때문에 이제 뭔가 마블 영화처럼
# 뭔가 막 그렇게 뭔가 흥행이 쉬운 타입의 장르는 마블 유니버스 이렇게 확장해 해 나가는 것이 쉽지만
# 이렇게 호불호가 갈리는 공포 영화라는 장르를 들고도 컨저링 유니버스까지 이끌어나가며 세계가를 확장하고 흥행하는 데 성공했다는 데에서
# 굉장히 의의가 있고 공포 영화에 한 획을 그었다고 생각합니다 다른 분들은 어떻게 생각하시나요?
# 네 @이름1은 이제 중국계 호주인 출신 영화감독인데요 분노의 질주 더 쎄븐이 전 세계에서 무려 (십오억 일천만 달러가)/(15억 1천만 달러가) 넘는
# 대박을 거둬들이면서 아시아계 출신 감독들에서 영화 흥행 (일 위)/(1위) 기록을 가지고 있다고 해요.
# 어~ 공포 영화에 국한되지 않고 정말 많은 플모 필모그래피를 가지고 있는데요 정말 놀랍게도 저는 쏘우 (일만)/(1만) 어릴 적에 학교에서 틀어줘서 본 게 전부였습니다.
# (디씨)/(DC) 코믹스 씨리즈를 좋아하지 않아서 아 세계적으로 히트친 아쿠아맨도 보지 않았습니다 근데도 이 감독에 대해서는 많이 들어봤어요.
# 어 앞서 말했듯이 대표적인 작품들이 쏘우 컨저링 씨리즈 애나벨 씨리즈 분노의 질주 아쿠아맨 등이 있는데 자신의 능력을 공포 영화뿐만 아니라
# 히어로 무비나 액션 영화에서도 마음껏 펼쳐낸 정말 능력 있는 감독입니다 또한 인씨디어스 씨리즈에서는 (일)/(1) (이 편)/(2편) 이후 감독을 다른 사람으로 교체하고
# 제작 및 투자를 해서 계속해서 성공시키면서 프랜차이즈를 성공적으로 관리하는 유능한 제작자로서의 면모도 보여주고 있습니다.
# 개인적으로는 공포 영화나 스릴러 액션 영화를 선호하지 않는 편이라서 오히려 이 영화감독의 작품이 나왔다는 정보를 접하면은 우선 피하곤 합니다.
# 이름값을 톡톡히 하는 감독이니까요 그래서 저는 영화 작품에 집중하기보다는 @이름1이라는 감독에 대해서 얘기를 해보려고 합니다.
# 어 중국계 호주인으로 말레이시아 화교 집안에서 태어나 호주로 이민을 갔다고 해요.
# 로열멜버른공과대학교에서 영화제작과를 다니면서 동료인 @이름2를 만나서 (이천삼 년에)/(2003년에) 첫 작품으로 쏘우를 만들기 시작했습니다.
# (이천사 년에)/(2004년에) 첫 장편 영화인 쏘우를 이제 올리면서 전 세계적으로 태 대히트를 치면서 성공적인 입봉을 마쳤습니다.
# 이때 그의 나이가 (스물여섯)/(26) 때라고 해요 @이름1의 공포 영화는 어 싸이코나 살인마 등 현실적인 캐릭터보다는 귀신 들린 인형이나 폴터가이스트
# 퇴마 의식 등 주로 초자연 현상을 다룹니다 실제로 컨저링 씨리즈의 주인공 워렌 부부가 수집한 컬렉션 중에서는
# 귀신과 악령에 관한 물건이 수두룩하다고 해요 이에 대해서 감독은 이렇게 말을 말했습니다.
# 아시다시피 전 동양인입니다 말레이시아는 한국이나 일본 중국과 마찬가지로 귀신이나 유령에 관한 이야기가 많습니다.
# 어렸을 때부터 듣고 자라다 보니 자연스럽게 그쪽으로 관심이 많이 갔습니다 어 또한 그는 귀신의 존재를 믿는다고도 말했습니다.
# 음 공포 영화의 대가로서 대기업의 상업 영화인 아쿠아맨의 감독이 정해 감독으로 정해진 것에 대해서는 대작들의 메가폰을 잡는다고 해서
# 크게 달라질 것은 없다고 말했습니다 커리어를 확장할 수 있다는 면에서는 기도가 된다고 정말 강심장의 면모도 보였습니다 그리고 분노의 질주를 찍을 때는
# 오히려 공포 영화에 대한 향수를 느꼈다고 하는데요 블록버스터의 액션은 길이가 굉장히 길고 찍기가 어려운 반면에
# 공포 영화 속의 액션은 아주 짧지만 관객들에게 긴 여운을 줄 수 있기 때문이라고 말했습니다.
# @이름1 감독은 감독인 자신이 무서워야 관객도 똑같이 받아들일 거라는 생각으로 늘 장면을 찍을 때 고민을 굉장히 많이 한다고 합니다.
# 이것을 일종의 보편성이라고 생각하고 이를 조금 더 확장시켜서 보면 공포나 코미디는 오히려 비슷할 거라고 말했습니다.
# 공포나 웃음은 모두 인간의 대표적인 본능이기 때문에 그런 반응이 즉각적으로 나올 영화를 제작하는 게 자신의 꿈이라고 말했습니다.
# 어 세 번째 발화자님은 이 감독에 대해서 어떻게 생각하시는지 궁금합니다.
# 네 앞선 발화자님들의 얘기 잘 들었습니다 어~ 네 저도 오늘 주제를 이제 받고 나서 찾아보면서 이제 생각한 게
# 헐리우드에서 아시안 감독들이 굉장히 성공하기 힘든데 정말 많은 흥해 흥행작 흥행작들을 만들고 또 대형 영화사에서 영화 제작에
# 영화 제작을 할 때 이런 많은 러브콜을 받는 상황만 받는 감독이라는 것을 이제 보고 나서 그만큼 연출법이나 각본 각색을 쓰는 능력이
# 탁월하고 이제 인정받고 있다라는 생각이 들었습니다 엄
# 제가 이거를 조사하면서 컨저링 유니버스라는 게 따로 있다라는 것을 발견을 했어요 원래는 몰랐는데 저도 원래는 공포 영화 같은 걸 좋아하지 않아서
# 잘 몰랐는데 네 이게 마블의 마블 시네마틱 유니버스가 있듯이 공포 영화에도 이런 탄탄한 세계관이 있고 이것을 컨저링 유니버스라고 한다고 하더라구요
# 그래서 이 @이름1 감독이 엄 히어로 영화를 본 것이 씨네마틱 유니버스를 기획한 계기라고 합니다.
# 그래서 앞선 (이 번)/(2번) 발화자님께서 공포 영화를 거의 안 보셨다고 해서 제가 이 컨저링 유니버스에 대해서 한번 소개를 드려보고 싶습니다.
# 네 컨저링 유니버스는 우선 뭐 컨저 이 (이천십삼 년에)/(2013년에) 개봉한 컨저링을 시작으로 해서 뭐 애나벨 컨저링 투 뭐 더 넌 요로나의 저주
# 어 뭐 컨저링 쓰리 같은 같은 세계관을 공유하는 공포 영화들로 구성이 되어 있는데요 어 만약 이 영화를 보신다면은 순서는
# 우선 워렌 부부 이 퇴마사 부부가 등장하는 메인 스토리 라인인 컨저링 시리즈를 시작으로 해서 엄 네 어떤 그 발락이라고 하는
# 악마 수녀가 나오는 이야기 그리고 뭐 컨 뭐~ @웃음 인형
# 악령 들린 인형이 나오는 뭐 애나멜 이 씨리즈로 보시면 된다고들 하더라고요 엄 그리고 저는 이 @이름1의 컨저링 씨리즈 영화들을 보면서 생각했던 점이
# 이전에는 미국 공포 영화는 정말 재미가 없다라는 생각을 가지고 있었거든요 어 너무 좀 너무 어~
# 너무 쫌 신박한 게 없다고 해야 되나 변화도 없고 신박한 것도 없고 어~ 좀 속된 말로 말하자면은 뭐 굳이
# 왜 집안에 들어가서 불을 키면 되지 불을 키는 장면이 안 나오고 들어가서 안 될 거 같은데 왜 굳이 들어가고 이런 좀
# 너무 좀 뻔한 장면이 되게 많은 영화라고 생각을 했어서 미국 공포 영화는 잘 보지 않았었는데요 그런데 이제 컨저링 씨리즈 같은 경우에는
# 어~ 귀신이 나오지 않는데 그러니까 귀신이 처음부터 명확하게 나오는데
# 또 귀신의 장면은 나오지 않고 그리고 또 어떤 공포스러운 분위기나 긴장감을 유도하는 할 때 그 내추럴하게 흔들리는 카메라 기법이라던가 이런 것들을 통해서
# 어 귀신이 나오지 않고 뭔가 깜짝 놀래키지도 않는데 되게 긴장감을 유발하고 흥미감을 유발하는 거 같더라고요 그래서 어~
# 저는 이제 공포 영화를 못 보지만 그럼에도 불구하고 이렇게 뭐 팝콘 통을 부여잡는다던가 옷으로 이렇게 가리면서까지 쫌 흥미롭게 영화를 많이 봤던 것 같습니다.
# 네 그러면 이제 (일 번)/(1번) 발화자님은 이런 컨저링 씨리즈 외 혹시 @이름1 감독의 어떤 영화를 본 경험이 있는지 궁금합니다.
# 네 저는 컨저링 씨리즈 외에도 그 @이름1이 뭔가 기존에는 공포 영화만 주로 하다가 (디씨)/(DC) 유니버스 쪽으로 넘어가서 이제 메가폰을 잡은
# 히어로물 아쿠아맨이라는 영화를 봤었는데요 이제 뭔가 히어로물 하면은 아무래도 밝고 굉장히 희망차고 그런 얘기가
# 대부분이기 때문에 @이름1 감독이 이런 작품을 한다고 하면서 약간 의아함도 느끼고 되게 의외라고 생각을 했었어요 근데
# 이제 아무래도 히어로 무비다 보니까 밝고 대중적인 분위기인 건 맞는데 뭔가 다른 영화들에 비해서 쫌 더 무겁게 이끌어나가는
# 이제 아쿠아맨의 장면을 보다 보면 아쿠아맨이 그 해양 생물 크리처 괴물들한테 쫓기는 장면이 있는데 그 장면이
# 어두운 바다 속에서 순간 번개가 치면서 바다가 확 환해지는데 그 주의를 다 괴물이 둘러싸고 있는 장면이 있어요 근데 이제 그것도 약간 공포 영화처럼 굉장히
# 공포스럽게 연출을 해 가지고 아 이러한 장면은 확실히 @이름1 감독답다 이렇게 생각한 적이 있었고 뭔가
# 대중성을 노렸 대중성을 노려서 빠른 템포로 진행한다기보다는 뭔가 음~
# 연출 자신이 좋아하는 연출이나 그러고 시나미를 뽑아내기 위한 (@미장센에)/(@mise-en-scene에) 집중한 것 같아서 뭔가 그게 다른 영화들과의 차이점 같아서 좋다는 생각을 했었구요
# 이제 최근에는 최근에 무산되긴 했지만 원래 @이름1 감독이 제가 아까 말씀드렸던 아쿠아맨에 등장했던 트렌치라는 괴물을 주인공으로 내세운
# 더 트렌치라는 (@스핀오프)/(@spin-off) 영화를 이제 공포 영화 장르로 제작할 예정이었는데 이거는 이제 사정이 안 돼서 무산되었지만
# 아마 이런 영화도 보면은 굉장히 재밌었을 것 같다고 생각을 했습니다 이제 뭔가 @이름1 감독은 연출이 인상 깊은 감독 중에 (한 명인)/(1명인) 거 같은데
# 아까 앞에 분들이 말씀해주셨듯이 뭔가 흔들리는 카메라 기법이라든가 그런 거를 자주 사용하는데 이제 @이름1 감독은 촬영할 때
# 관람객들이 보는 거를 그니까 배우가 보는 것들을 관람객이 그대로 볼 수 있도록 하는 것을 추구한다고 해요 그래서 예를 들어 배우가 어두운 방 안을 이렇게
# 긴 복도를 걸어가는 장면을 촬영한다면 실제로 배우 바짝 뒤 뒤에 붙어서 걸어간다던지 그런 식으로 배우들이
# 바라보는 장면을 관람객들이 그대로 바라보는 것처럼 내 마치 내가 겪는 일인 것처럼 그렇게 느낄 수 있는 연출을 자주 사용한다고 해서
# 어~ 굉장히 인상 깊었던 것 중에 하나입니다 혹시 다른 분들은 이러한 @이름1 감독의 다른 인상 깊은 점들이 있으셨을까요?
# 네 저는 어 감 작품들 중에서 유일하게 본 게 쏘우 원이거든요 근데 이것도 쫌 어릴 때 봐서 기억이 안 나는데
# 굉장히 그 스릴 넘치는 그 연출과 아 뭔가 잔인한 영화인데도 아 뭔가
# 좀 스토리가 있고 연출법이 좀 신선해서 기억에 남았었어요 근데 쏘우 투를 아 몇 년 후에 다시 봤던 거 같은데
# 아 그거는 인제 감독이 바뀌'어서 그런지 그 특유의 쏘우 원과 같은 특유의 맛이 없더라고요 그래서 그 이후부터는 뭔가
# 오락 영화로 쫌 추락한 거 같아서 쫌 (한 번도)/(1번도) 보지는 않았습니다 그리고 뭐 컨저링이나 애나벨도
# 이거 굉장히 제 기억에 광고를 많이 했던 걸로 기억하거든요 여기저기서 그 애나벨 인형이 굉장히 많이 나오고 또
# 또 이게 씨리즈가 있잖아요 그 씨리즈 따라서 우리나라도 굉장히 흥행이 많이 했던 걸로 기억하는데 저는 정말 이런 영화를 못 보고
# 이 @이름1 감독 특유의 약간 동양적인 요소가 섞인 연출법이 저에게 너무나 공포스럽게 다가오기 때문에
# 저는 (한 번도)/(1번도) 본 아 그 (한 번도)/(1번도) 본 게 없고 아마 앞으로도 보지 않을 거 같애요 이 감독이 이 감독의 작품이 개봉한다고 하면은
# 아쿠아맨처럼 이런 대기업인 오락 영화 말고는 볼 보고 싶지 않습니다 너무나 공포스럽기 때문에
# 근데 또 제가 @이름1 감독을 검색을 하다가 이제 세계적으로 유명한 동양계 감독들을 쪼끔 찾아봤는데요
# 어~ 혹시 라이프 오브 파이를 보셨는지 모르겠는데 색 계랑 같은 감독이구요
# 대만 출신의 @이름3 감독이 또 세계적으로 또 유명하잖아요
# 어~ 베를린 영화제랑 베네치아 영화잔에 영화제에서 최고상을 각각 수상하구 아카데미 시상식에서도 감독상을 (두 번)/(2번) 수상하셨다고 해요.
# 혹시 세 번째 발화자님은 라이프 오브 파이나 뭐 브로크백 마운틴 이런 @이름3 감독님의 영화를 보신 게 있는지 궁금합니다.
# 어~ 네 질문 감사합니다 어~ 저도 그 두 영화에 대해서 이름은 굉장히 많이 들어봤는데
# 네 그중에서 저는 라이프 오브 파이를 어~ 예전에 개봉했을 때 영화관에서 본 기억이 있습니다 음~ 그런데 제가
# 조끔 바다 공포증 같은 게 있는데 그 영화가 그렇게 바다가 많이 나오는지 몰랐어요 그래서 이제 그거를 보는데 이제
# 그런 어두운 바다 장면이 그 영화가 거의 (삼 분의 이)/(3분의 2) 아니 거의 대다수가 바다 위에서 찍는 장면들이 나오는 거 같은데
# 이제 검은 바다나 좀 짙은 바다 색이 나올 때는 좀 심장이 두근거려서 네 영화에 좀 집중을 하지 못했습니다 네 그런데 이제 가장
# 쫌 인상 깊었던 장면 중의 하나는 어~ 맞는지는 모르겠지만 어떤
# 어 밤이 되면 이케 물에 가득 차는데 그 물이 쫌 독성 물질이 가득 찬 뭐 물이었나요?
# 그런 게 있고 이제 그것을 피해서 나무 위에서 나무 위에 이제 파이와 파이가 그 호랑이 맞죠 그 호랑이와 이제 주인공 남자애가
# 이제 그 아름다운 풍경을 보는 장면이 있었던 거 같은데 그 장면이 쫌 굉장히 네 씬이 되게 아름다웠던 것으로 기억하고 있습니다.
# 네 네 그렇구요 네 그렇습니다 암 그리고 그냥 앞서서 (일 번)/(1번) 발화자님께서 아쿠아맨을 얘기하셔 가지고
# 저도 그거 그 영화를 본 입장에서 쪼끔 추가적으로 어 의견을 덧붙이자면 네 저도 그~ 앞서서 말씀하신 그 크리처라는 바다 괴물이
# 폭죽 같 주인공들이 폭죽 같은 걸 들고 바다로 뛰어드는 그 장면 그리 그래서 그 주인공들을 따라서 모여드는 씬이 그 영화에서 게장 가장 하이라이트 씬이었다고 생각을 해요.
# 왜냐면 엄 저는 평소에 좀 마블 유니버스를 굉장히 좋아하는데 그게 이제 화려한 액션이나
# 히어로물들이 이제 나오는 그런 좀 좀 그런 재밌는 내용 그런 거 땜에 좋아하는데 (디씨)/(DC) 영화 같은 경우에는 좀 우울하면서도 너무 어둡고
# 너무 뻔하고 좀 재미없다라는 인식이 좀 많았어서 잘 보지 않았었습니다 그런데 이제 친구가 이 아쿠아맨이 너무 재밌다고 재미있을 거 같다고 해서 같이 봤었는데
# 어~ 네 생각보다 되게 재밌더라고요 특히 방금 말했던 그 씬 그 씬이 되게 인상적이었고 그런데 이제 아무래도
# 내용 전체가 좀 다소 가볍고 작위적이지 않았나라는 생각을 해 보았습니다 너무 쫌 보면서도 아 이거 이렇게 진행될 거 같은데 하면 그렇게 진행되고
# 대사 같은 것도 쪼끔 뻔하기도 하고 너무 좀 사랑 얘기 같은 게 갑자기 뜬금없이 튀어나오기도 하고 악역이 쫌 너무 또 비중이 적지 않았나
# 하는 생각도 있었어서 쫌 이런 연출 같은 것은 정말 아름다웠지만 내용이나 각색적인 부분에서는 좀 실망감이
# 컸었었고요 네 그리고 또 이 아쿠아맨도 라이프 오브 파이처럼 바다 안에서의 내용이 굉장히 많은데요 그래서 영화를 보기 전에
# 어 물속에서 진행되기 때문에 수중에서 촬영한 것처럼 보여야 되는데 이런 바닷속에서의 머리카락의 표현이라던가 뭐 표정 대사를 치는 표현 등을 어떻게 표현을 할까?
# 쫌 되게 어색하지 않을까 하는 좀 우려가 컸었는데요 영화를 실제로 보니까 아 정말 바다 안에서
# 생활하는 누군가를 찍은 것처럼 생동감이 있어서 너무 좋았습니다 그래서 또 알아보니까 이 @이름1 감독이 평소에 실제 세계에서 표현할 수 있는 결과물이 더 조
# 더 좋게 나온다는 신념을 가진 사람이라고 하더라고요 그래서 이제 수중 장면도 지상에서 모두 촬영을 했고
# (@블루스크린)/(@blue screen) (@블루스크린을)/(@blue screen을) 이용해서 뭐 (씨지)/(CG) 작업이 들어가기도 했지만 실제 세트에서 작업을 하고 물탱크에 집어넣는 작업을 여러 날에 걸쳐서 진행함으로써
# 제 실제 세트와 디지털화를 동시에 모두 사용하는 네 이런 촬영 기법을 써서 쪼금 더 생동감 넘치는 영화 표현을 할 수 있었던 것 같습니다.
# 네 엄 이상입니다.
# 네 저희 세 번째 발화자분까지 이야기 많이 들어 봤는데요
# 검 제가 이제 @이름1 감독의 이제 따른 관점에서 질문드려보자면 이제 @이름1 감독 같은 경우에 이제 영화에 자주 등장하는 배우가 있잖아요?
# 뭐~ 대표적으로 뭐 인씨디어스 같은 경우에는 뭐 @이름4라든지
# 그~ 뭐 컨저링 씨리즈라는 워렌 부부로 이제 출연하는 뭐 그~ 아 기는 배우 이름이 기억이 안 나는데
# 어~ 저도 영화를 찾아봐야 돼서요 잠시만요 음 여기 있네요.
# 뭐 컨저링 씨리즈에서 이제 거의 모든 씨리즈에 다 출연했죠 컨저링 씨리즈 주인공이라고 할 만한 배우인
# 그 @이름5 @이름5이라든지 요런 @이름5도 사실 @이름1 감독에 의해서 이제 그 이름이 알려진 배우기도 한데 이런 감독과
# 배우와의 관계가 이제 이렇게 서로 이끌어주는 이런 관계인데 혹시 뭐
# 그런 감독이나 배우의 관계에 대해서 혹시 여러분은 어떻게 생각하는지 아니면 이런 감독과 배우 말고 뭐 따른
# 배우와 감독이 이제 서로 공생하면서 이끌어주는 관계가 뭔가 무엇이 있을지 한번 들어보고 싶은데요 그러면 (첫 번째 발화자님부터 얘기해 주세요.)/(idiom)
# 네 우선 컨저링 씨리즈 그 계속 출연해주신 @이름5 배우분 얘기해 주셨는데
# 이 배우가 컨저링 씨리즈뿐만 아니라 @이름1과 함께 그거 아쿠아맨에서도 출현을 했었거든요
# 어쨌든 @이름1과 @이름5이라는 배우는 이제 (네 개의)/(4개의) 작품을 이미 같이했기 때문에 뭔가 어쨌든 신뢰 관계를 바탕으로 이루어져 있는
# 감독과 배우 사이라고 볼 수 있는 것 같아요 아무래도 이렇게 배우와 감독 사이에 신뢰가 있으면은 더 좋은 작품으로 연출 될 수 있지 않으까?
# 그런 식으로 생각이 드는데 이제 저는
# 뭔가 컨저링 씨리즈로 이제 이름을 알렸지만 아쿠아맨으로 새로운 뭔가 도전을 하는 것도 굉장히
# 의미 있다고 생각을 드는데 그래서 뭔가 아쿠아맨이 마냥 밝고 활기차기보다는
# 기존의 다른 영화에 비해서는 쪼금 어두운 느낌을 낼 수 있지 않았나 하는 생각도 들어요 저는 개인적으로 아쿠아맨이 어쨌든 뭔가
# 이야기 구조가 굉장히 단순하고 그냥 출생의 비밀만을 다룬다 약간 신화적이다 이런 비판을 받기도 했지만
# 뭔가 아쿠아맨은 쪼금 그런 신화적인 단순한 이야기를 넘어서 이제 그 바닷속 아틀란티스 완전 순혈주의 그러구
# 다른 혼혈들은 배척하는 그런 아틀란티스의 나라를 아틀란티스의 나라를 새로 뭔가 새롭게 건국하고 그다음에 대화로 화합을 이루고
# 그러한 뭔가 쫌 커다란 상징적인 (@메타포를)/(@metaphor를) 보여준다고 생각을 했거든요 은 뭔가 이러한 메세지를 전달하는데
# 그러한 배우와 감독의 관계도 쪼금은 영향을 끼치지 않았나라고 생각을 했습니다 음 다른 분들은 어떻게 생각하시나요?
# 에 저는 이 감독의 영화를 많이 안 봐서 그 컨저링 씨리즈에 계속 출연하시는 그 배우분들이 누군지도 잘 모르겠고 @웃음
# 그래서 다른 감독을 감독과 배우 관계를 한번 말씀드릴려고 하는데요 어 모두
# 다들 알고 계실 법한 @이름6 감독님과 @이름7 배우님의 관계입니다 저는 어릴 때부터 굉장히 어릴 때 한
# 중학교 때부터 @이름7 배우님의 굉장한 팬이었어요 그 반칙왕을 보고서 그 젊었던 그 모습에 한눈에 반해 가지고
# @이름6 님이 결혼을 했다는 사실에 굉장히 슬퍼하곤 했는데 그 어릴 때부터 쭉 쭉 봐왔는데
# @이름6 감독님이랑 굉장히 많은 작업을 계속해서 해 나가더라구요 모두들 아실법한데 살인의 추억이랑 또 괴물이랑
# 설국열차 또 최근에는 기생충까지 아마 둘의 인연이 굉장히 깊은 거 같아요 영화를 촬영하는 방식에 있어서
# 서로 생각이 잘 맞는 거 같고 그래서 아마 @이름6 감독님의 작품이 나온다 하면은 쫌 대중들은 자연스럽게
# @이름7를 제일 먼저 떠올리지 않을까 이런 생각도 하고 근데 이렇게 마음이 잘 맞는 감독과 배우가
# 여러 작품을 출연한다는 거는 오히려 마이너스가 될 수도 있다고 생각하는데 그리고 또 굉장한 감독과 굉장한 배후가 만나면은
# 아무래도 자기 복제가 없기 때문에 오히려 관객들에게 더 더 강한 기대감을 유발할 수도 있고
# 또 결과물에 있어서도 굉장히 만족스러운 결과물이 나온다고 생각을 합니다 어~ 실제로
# @이름6 감독과 @이름7 배우님은 사석에서도 굉장히 친한데요 음~ 첫 첫 만남에 관한 이야기는 아마 쫌
# 많은 분들이 알고 계실 거 같아요 @이름7 님이 그 무명 배우일 때 오디션을 계속 보러 다녔는데 자꾸
# 오디션에서 떨어져서 굉장히 위축되었던 시절이 있었대요 근데 @이름6 감독의 작품에 오디션을 보러 갔었고 또 결과를 기다리는데
# 그때 당시에 삐삐를 사용했었죠 그 삐삐에 장문의 음성이 녹음이 돼 있었대요.
# 다른 감독들은 그 전에 그러지 않았고 떨어지면 그냥 연락도 안 주고 잠수 타고 그런 건데 @이름6 감독님은 처음으로
# 어 이번 작품은 뭐 이런 이러한 이유 때문에 같이 작업을 못 할 것 같지만 다음번에는 꼭 뵙고 싶다고 이런 식으로 정성을 다해서 녹음을 남겨 놓았다고 해요.
# 그거를 보고서 굉장히 인상 깊게 받아들였고 그거를 계기로 두 번째 영화인 살인의 추억에 출연하게 출연을 결정했다고 합니다.
# 이렇게 @이름7 배우님은 @이름6 감독의 (@페르소나로써)/(@persona로써) 쫌 여러 작품을 함께했는데요
# 어~ 세 번째 발화자님은 이런 감독과 쫌 감독 하면 딱 떠오르는 배우들 이런 관계를 어떻게 생각하시는지 궁금합니다.
# 아 네 질문 감사합니다 저는 그러면은 앞선 이제 @이름1 감독의 이런 그 감독과 배우들의
# 배우들의 이런 지속적인 영화 제작 네 그거에 대한 저 제 생각을 한번 말해 보겠습니다 저도 컨저링이나
# 인씨디어스 씨리즈 씨리즈들을 많이 봤는데요 이 안에서 이제 말씀하신 자 이름은 기억이 잘 안 나지 않지만 자주 이제 출연하는 메인 부부인
# 워렌 부부와 그다음에 인씨디어스의 애기 네 이런 것들을 보면서 어 저는 이러한 게 드라마의 씨즌제와 쪼끔 유사하다는 생각을 했습니다.
# 저희도 드라마 씨즌데를 많이 보는데 이런 씨즌제의 장점이 아무래도 같은 배우 같은 감독이 한 작품을 이끌어가다 보니까
# 어 작 관객 입장에서 작품에 몰입감이나 집중도가 올라가고 또 음~ 또 이제 제작자 입장에서는 더욱더 만족스러운 결과물을 만들어낼 수 있다고 생각합니다.
# 또한 이렇게 엄 이렇게 감독 이렇게 배우와 감독 어~ 그리고 한 컨텐츠가
# ...
# 그렇게 하기 위해서 그 패러디를 제작하는 그 사람들도 냉철한 의식을 갖고 사회의 어떤 문제를 바라봐야 하고 그것들을 받아들이는 수용자들 또한 어떠한 감정에 치우치지 않고 냉철하고 객관적인
# 이성으로 받아들일 때 더 좋은 그리고 훌륭한 인터넷 문화로 장착 정착할 수 있을 거라고 생각합니다.
# 네 토론자
# 인터넷 패러디 선정성은 부인할 수는 없습니다 하지만 오히려 이 선정성이 선정성 또는 폭력성 때문에 우리가 더 강렬하고
# 또 머릿속에 남는 걸 수도 있습니다 왜 그러냐면 우리 뇌는 시각적인 거를 더 저장을 잘하니까요 그렇기 때문에 그리고 이 이
# 선정성과 폭력성 때문에 빚어지는 일들도 많지만 오히려 이런 것 때문에 그런 것에 장점이 있듯이 이 패러디도 만드는 것에 대해서 기술력이 필요합니다 그냥 이 잘라 붙이는 것이 아니라
# 이것도 어떤 어떤 기술이 필요하고 어떤 프로그램이 필요합니다 그래서 이 제작자들에게 무조건 비판만 할 것이 아니고 제작자들에게 정보통신부에서
# 일정량의 어~ 지원비를 준다든가 이런 식으로 해서 패러디를 산업으로 개발하는 것도 괜찮을 것 같습니다.
# 네 다양한 대책들 (잘 들었습니다)/(idiom) 오늘 청소년 원탁토론 시간에는 인터넷 패러디를 관해서 열띤 (토론을 벌여봤는데요.)/(idiom)
# 지금 이 시간에도 인터넷에는 수많은 인터넷 패러디가 생기고 있을 것입니다.
# 어~ 본래 인터넷 패러디가 갖고 있는 순수한 목적과 기능을 잘 살릴 수 있는 어~ 우리 사회에 일침을 가할 수 있는 인터넷 패러디가 생기길 바라는 마음입니다.
# 네 인터넷 문화의 주역은 우리 청소년들입니다 인터넷 저질문화가 확산되지 않도록 인터넷 패러디를 감시하고 제재하는 역할 또한 우리 청소년들이 해야 할 일이라는 걸 생각하면서 (오늘 토론을 마무리하겠습니다.)/(idiom)
# 예 토론자 여러분들 수고 많으셨고요 예 각자 인사 나눌까요?
# 수고하셨습니다 예 청소년 원탁토론은 언제나 여러분께 활짝 열려 있습니다 참여하시고 싶은 분들은요 여기 아래 나가는 주소로 연락 주시구요. /(bgm)
# 저희는 다음 주에 더 알찬 주제로 다시 찾아 뵙겠습니다. /(bgm)
# 청소년 원탁토론 다음주 이 시간에 다시 뵙겠습니다 안녕히 계세요. /(bgm)
# 아 정말 열심히 하고 싶었는데 막상 그렇게 안 따라줘서 너무 아쉽고 다시 하라면 더 할 더 잘할 수 있을 것 같고 /(bgm)
# 어~ (()) 말하고 싶은 건 여기 나오는 데 도움 준 내 친구들 설문조사해 준 우리 반 친구들이랑 (이 학년)/(2학년) 전교 학생들
# 그리고 또 우리 가족들 그리고 마지막으로 우리 서대전여고 독서토론부 럭셔리 동아리 버팀목 화이팅 @웃음 /(bgm)
# 저 아까 그 엘레강스한 학교에서 그 왔던 입니다 저 그렇게 잘 못한 거 같은데요. /(bgm)
# 여하튼 여기까지 보시면 굉장히 감사하고요 어~ 그리고 음 저하고 저 도와주셨던 선생님 선생님 그리고 비록 편집되셨지만 그래도 열심히 했으니까 감사하고요. /(bgm)
# 그리고 편집을 막지 못해서 미안하다 날 용서해라. /(bgm)
# 어 이것을 본 사람들도 어떤 인터넷 패러디에 대해서 어떠한 문제에 대해서 좀 더 많은 생각해 볼 수 있는 좋은 시간 됐을 거라고 생각합니다. /(bgm)
# 어~ 정말 함께 저희 부족한데도 계속 이끌어 준 뭐 작가님 피디님 뭐 엠씨들 그리고 여러 스탭분들두요 너무 수고하셨고요 어 이렇게 좋은 경험 만들게 해 주셔서 너무 감사합니다. /(bgm)
# 끝나서 쫌 홀가분하고 씁쓸하기도 하고 네 다음번엔 열심히 하고 앞으로 열심히 하겠습니다. /(bgm)
# 아 우선 여기 나온다고 많이 응원해 준 친구 선생님 가족한테 못해서 너무 죄송하고요 (()) 선정 (십 대)/(10대) 명문곤데 제가 막 이렇게 추락시킨 것 같아서 너무 죄송하구요. /(bgm)
# 다음에 더 열심히 (()) 열심히 하겠습니다.
# 어~ 저는 이렇게 출연하게 되어서 굉장한 무한한 영광이고요 말을 잘 못해서 조금 찔리는데 어쨌든 우리 (열여섯 명)/(16명) 남은 인천과학고 (삼 학년)/(3학년) 드림팀 드림 드림 화이팅 /(bgm)
# ----------------------------------------
# File: /mnt/a/maxseats/(주의-원본)주요 영역별 회의 음성인식 데이터/002.주요_영역별_회의_음성인식_데이터/01.데이터/unzipped_files/SRBEG21000666.json
#
# (()) 작년도 장애인거주시설 (오십 인)/(50인) 이상 생활지도원 교대인력 채용이
# 네 어~ 총 (팔 개소에)/(8개소에) 당초에는 (백이십오 명을)/(125명을) 채용할 계획이었습니다만 (사십구 명)/(49명) 채용을 했습니다.
# 이건 지난번 의회 때도 저기 말씀해 주셨는데 (사십구 명)/(49명) (사십구 명)/(49명)
# (사십)/(40)
# (백이십오 명)/(125명) 채용 계획이었습니다만 (사십구 명을)/(49명을) 채용 완료하고 현재도 채용은 진행되고 있습니다 (구 명)/(9명) 네네.
# 예예 (사십구 명인데)/(49명인데) 실제로 (사십구 명도)/(49명도) 어~ 이직이 그 안에 있었으면은 실제로는 (사십구 명이)/(49명이) 아닐 수도 있죠.
# 들어왔다 나갈 수도 있으니까 지금 채용된 숫자만 (사십구 명으로)/(49명으로) 산출하신 거지.
# 실제로 그게 고용이 유지되고 있는 것까지 확인하신 건 아니죠?
# 뭐 그게 중요한 건 아니니까 그게 중요한 건 아니니까 어쨌든 (사십구 명이)/(49명이) 채용됐습니다 예상보다 훨씬 적게 채용이 됐는데 그러면 왜 이렇게 적게 채용이 됐는지 실제로 교대인력이
# 어~ 필요한 거고 그것을 아까 말씀하신 게 애초에는 (백칠십이 명분으로)/(172명분으로) 산출했지만 (백이십오 명을)/(125명을) 채용할 계획이었다 그러는데
# 훨씬 못 미치는 (사십구 명)/(49명) 정도가 채용이 됐어요.
# 이제 중간에 이직자 빼고 이직자를 이제 뭐 거기에 근거 저기 어 포함시키지 않고 (사십구 명이)/(49명이) 어쨌든 채용이 됐는데
# 이렇게 필요 인력이 다 채용되지 못한 이유가 뭐죠?
# 지난 의회 때도 답변을 드린 바와 같이 이제 이 신규 채용 기준이 기본적으로 (이 호봉을)/(2호봉을) 기준으로 하고 있고 특히 저희 그 거주시설 중에
# 저기 강원도나 경기도 이렇게 조금 거리가 먼 이런 곳에 이제 근무를 해야 되는 그런 근무 여건이 좀 어려운 점 이런 것들이 현장에서는
# 그~ 채용에 좀 어려움으로 겪고 있다 이렇게 알고 있습니다.
# 어~ 보건복지에서 기준하고 있는 (이 호봉의)/(2호봉의) 그 문제 때문에
# 개정 건의를 하는데 이제 그 부분은 어 보건복지부에서는 별도 그 개정할 생각은 없는 것으로 그렇게 하고 있고
# 어 필요하다면 시 자체적으로 판단해서 해라 이 정도 의견을 네 주고 있습니다.
# 그거 때문에 질의를 드리는 거거든요 어쨌든 보건복지부는 (이 호봉의)/(2호봉의) 기준을 어~ 완화할 생각이 없으시고 그래서 그것 때문에 낮은 임금 때문에 이제 그 교대인력이 채용을 못하고 있는 거잖아요.
# 그렇다 그러면 어~ 뭐 법적인 그~ 어~ 인원을 채워야 되는 것도 맞지만 지금 그렇게 현장에서 되고 있지 않은 상황에서
# 가장 큰 피해는 그 안에 있는 장애인분들이라고 생각하거든요.
# 그렇다 그러면 지금 말씀하신 것처럼 뭐~ 우리가 많은 다른 부분에서도 서울형 뭐 뭐뭐뭐 서울형 뭐뭐뭐 이런 거 많이 하시잖아요.
# 그럼 실제로 이 어~ 교대인력을 채용해야 된다 그러면 그 (이 호봉으로)/(2호봉으로) 만약에 음
# 뭐 응모를 안 한다 그러면 그것을 채용할 수 있는 조건으로 서울시가 이렇게 불용하면서 안 쓰는 게 무슨 의미가 있습니까 어차피 책정된 금액이라고 한다 그러면
# 그것이 운영될 수 있도록 어 불용되지 않도록 그리고 그 인원이 채용이 돼서 실질적으로 장애인들에게 혜택이 갈 수 있도록 해야 되는 게 마땅하지 않나요?
# 이제 위원님께서 사실은 이 예산도 뭐 위원님께서 챙겨서 넣어 주셨고요.
# 어~ 이제 그 부분도 어 저희가 이제 내부적으로 검토는 합니다만 어 서울시가 그렇게 했을 경우에 이제 타 시도에 이제 또 교대근무 인력
# 그~ 채용과 좀 엉켜서 약간 현장에서는 또 혼란이 올 수 있다 또 이런 의견도 있습니다.
# 현장에서의 혼란이라는 건 타 시도의 문제지 우리 서울시 안에서의 혼란이 아니잖아요.
# 이제 강원도에도 있고 경기도에도 있고 이러기 때문에요 사실은 이제 어 어~ 어쨌든 현장 의견을 들어보면 또 그런 의견도 있어서 조금 더 심도 있는 검토가 필요할 것으로 보입니다.
# 그 현장의 인력이 현장의 의견이라는 게 뭔지 잘 모르겠습니다만 제가 볼 때는 서울시하고 그~ 보건복지부하고 기싸움 같애요.
# 이거를 서울시 어 호봉을 내려야 채용 인력이 오는데 그거를 안 하겠다고 하는 보건복지부나 분명히 우리는 돈도 있고 예산도 책정돼 있는데
# 어~ 그 기준을 그 완화시키지 않고 서울 그 보건복지부가 바뀔 때까지 우리는 안 하겠다라고 버티기 하는 거나 두 기관이
# 기싸움하는 거지 실질적으로 예산도 손에 받아들고 있으면서 그것이 실행되도록 애쓰지 않았다라는 거는 저는 서울시가 좀
# 음 적극적인 행정을 하지 않았다는 것으로 저는 판단이 되거든요.
# 우리가 다른 부분에서는 얼마나 많은 서울형 사업들을 실시하고 있습니까 하다못해 키움 이것도 서울형으로 지금 하고 있잖아요.
# 그런데 이것만은 아니어야 된다는 생각은 저는 이해하기가 좀 어렵고요.
# 작년은 그렇다고 치고요.
# 작년에 뭐 제가 그 감추경 할 때도 문제 지적을 했기 때문에 작년 이게 결산 이제 작년 예산에 대한 그 결산 검사를 하고 있는 거 아닙니까?
# 작년은 그렇다고 치고 그럼 올해도 마찬가지 그~ (이 호봉으로)/(2호봉으로) 어~ 그~ 채용을 기준을 정해서 하고 있나요?
# 네 현재는 그렇게 하고 있습니다.
# 그러면 올해도 채용 올해 채용은 그러면 어떻습니까 올해 채용도 마찬가지입니까?
# 불용이 예상됩니까?
# (())
# 저희 과장이 좀 상세하게 답변 올리겠습니다.
# 예 장애인복지정책과장 @이름1입니다.
# 어~ 말씀 주셨듯이 금년에도 어~ 장애인거주시설 생활지도원 채용에 어려움이 있을 것으로 그렇게 보여집니다.
# 저희가 보건복지부에 채용 기준 완화를 요청을 했는데요.
# 보건복지부는 이제 기재부에서 채용 기준 완화를 수용하지 않는 상황에서 어려우니 시비로 충당할 것을 이제 현재 권고를 하고 있습니다.
# 그래서 이제 지속적으로 하반기에도 어려움이 있다 하면 저희들이 이제 시비로써 호봉을 좀 더 조정하는 방안에 대해서
# 어~ 검토를 하고자 합니다 다만 어 다른 시도에서 어~ 저희 시만 호봉을 높게 책정할 경우에는 어~
# 특히 이제 경기도 인천 같은 경우 어~ 그 시에 어~ 생활지도원 채용에 어려움이 있다.
# 그래서 시도 보조를 좀 맞춰 달라 이런 요청이 있습니다.
# 저는 그거는 어쨌든 보건복지부가 움직이면은 정말 음 좋은데요.
# 그리고 그래야 마땅하다고 생각하는데 이렇게 복지부동으로 안 하겠다 그러면 선도적인 어떤 역할도 필요하다고 생각이 들구요.
# 그러면 올해 (삼십사억 원이)/(34억 원이) 책정이 돼 있잖아요.
# 예 그거는 이제 뭐 (유월)/(6월) (칠월부터)/(7월부터) 이것도 그~ 어~ 채용에서 쓰일 예정인 거죠?
# 예 그렇습니다.
# 그러면 그전에 올해 전반기에 (오십 인)/(50인) 이상 시설은 지출하신 거예요?
# 예 현재 (사십일 명)/(41명) 채용하는 부분 아에 지출을 했고요.
# 어 (칠십육 명)/(76명) 이제 채용 명수가 남아 있는데 계속 독려를 하고 있는 상황입니다.
# 그럼 올해는 채용을 채용된 게 없네요?
# 아 올해 그니까 작년서부터 올해까지 전체 따지면 (사십일 명이고요.)/(41명이고요.)
# 어~ 작년에 채용 인원이 좀 적었고 금년에 거의 다 채용된 걸로 저희는 그렇게 확인하고 있습니다.
# (사십육)/(46) (사십구 명이라고)/(49명이라고) 말씀하신 부분은 작년과 올해를 합해서 말씀하신 거예요?
# 이게 작년 결산인데 그렇게 말씀해 주시면 안 되는데 어쨌든 작년 결산을 기준으로 해서 지금 말씀드린 건데 예 그건 알겠고요.
# 그러면 (삼십사억 원에)/(34억 원에) 대해서 어~ 이렇게 또 채용이 안 되면 말씀하신 것처럼 호봉을 좀 조정을 해서라도
# 채용을 유인해서 어~ 쓰일 수 있도록 하겠다 이렇게 답변 주신 걸로 제가 이해해도 되나요?
# 어~ 하반기에 그런 어려움이 있을 것으로 예상이 돼서 일단 검토를 하고요.
# 그 과정에서 위원님들께 또 설명드리고 또 자문을 구하도록 하겠습니다.
# 네 어쨌든 이게 이제 법적으로 강제적으로 하는 사항인데 어~ 작년에도 엄청난 불용이 돼 있고 올해도 (삼십사억 원에)/(34억 원에) 대해서
# 작년과 같은 불용이 생긴다 그러면 그건 좀 여러 부분 여러 부분에서 좀 불행한 부분인 거 같애요 그래서
# 우려를 하고 있고요 예 현장에도 어려움이 어 있다고 파악을 하고 있습니다.
# 적극적으로 쓰일 수 있도록 좀 노력해 주시고요.
# 그냥 (일 분)/(1분) (이 분)/(2분) 정도만 더 얘기해도 되겠습니까?
# 네 그렇게 하십시오.
# 이거는 짤막한 거고 작년에도 지적했던 부분인데 그냥 국장님 의견을 한번 듣고자 합니다.
# 그~ 서울시 산하 공공기관의 당연직이사의 이사회 참여율이 저조하다라고 아마 그 결산 검사에서도
# 작년에도 지적이 됐고 올해도 또 (이천이십 년도)/(2020년도) 운영에 대해서 그 지적이 또 있어요.
# 그리고 제가 작년에도 (이천십구 년에)/(2019년에) 대해서 똑같은 지적을 했던 거 같은데 지금 또 똑같은 결과가 나와 있는 상황이거든요.
# 지금 복지정책과를 보면 어~ 어~ 그~ 사회서비스원의 경우에 그~
# 복지 재정 이제 당연직으로 들어와야 되는 재정기획관이 (한 번도)/(1번도) 참여를 안 했고요.
# 그리고 복지재단의 경우에는 겨우 이제 그~ (사십 퍼센트)/(40퍼센트) 정도 이제 참여하는 걸로 나와 있습니다.
# 그~ 이게 이렇게 매번 결산검사에서 지적을 받고 어~ 또 실제적으로 이렇게 참여를 안 할 거면
# 당연직 이사로 하지 않든지 아니면 이사를 했을 때는 당연하게 참여하든지 뭐 (두 가지여야)/(2가지여야) 될 거 같은데 이렇게 걸어만 놓고 지금 참여하지 않는
# 이 실적을 보이고 매번 결산검사에서 지적을 받고 이게 또 개선이 안 되고 하는 부분에 대해서 실장님의 생각은 어떠신지 예 답변을 부탁드리겠습니다.
# 네 사실 당연직이사로 시 산하 모든 투자출연기관에 해당 해당 그~ 실국장과 소 업무의 실국장과
# 그다음에 재정기획관이 당연직으로 참여하도록 어~ 되어 있습니다만은 이제 재정기획관이 워낙 그~ (스물일곱 개)/(27개) 이제 산하 투자출연기관이다 보니까
# 어~ 이제 특별히 민감한 사안이 아니고는 아마 특별히 가서 이사회에 뭐 거부권을 행사하거나 의견을 내야 되겠다 하면 상황이 아니면
# 저희가 이제 사전 협의해서 돌아가는 사항들은 어~ 좀 이렇게 처리를 하고 있는데요 위원님 말씀대로 사실은 당연직 이사들이 꼼꼼하게 이사회에 참석해서
# 그~ 투자출연기관의 전체적인 이사회 결정사항들에 대해서 좀 모니터링하고 의견을 피력할 필요는 있다고 봅니다 지속적으로 참여를 독려하도록 하겠습니다.
# 아 예 음~ 제가 이제 다른 거는 그렇고 사회서비스원 같은 경우에는 처음 지금 운영하고 있는 거잖아요 그리고 지적도 많이 받았고
# 문제가 있다라고 지적했고 예산 사용이나 여러 가지 부분에서도 문제가 많은 부분인데 어~ 그~ 사회서비스원은 (한 번도)/(1번도) 참여를 안 했다는 거죠 재정기획관이
# 그러면 이거는 어떤 의미를 갖는지 잘 모르겠고 그래서 지금 뭐 실장님 말씀하셨지만 아마 올해도 작년과 똑같은 답변을 들은 거 같고요.
# 내년에도 똑같은 지적이 될 거 같애요 그래서 이걸 뭐 구조적으로 이렇게 뭐 결산 검사에서 맨날 지적받지 않는 방법이 뭘까를 강구해서
# 재정기획관이 못 오면 대리로 공기업 공기업 담당관이 투자출연기관을 총괄하는 과장입니다.
# 대리참석하는 것으로 지금 진행 중에 있습니다.
# 예예 알겠습니다 네 이상입니다.
# 네 @이름2 위원님 수고하셨습니다.
# 다음은 @이름3 위원님 (질의해 주십시오.)/(idiom)
# 예 노숙인 지원사업 관련해가지고 좀 들여다보겠습니다 음~
# 그 노숙인들 관련해서 노숙인 의료지원비용이 있습니다.
# 어~ 원래 당초 예산에 비해서 작년에 예산이 삭감됐었죠.
# 네 원래 예산보다도 삭감돼서 예산 현액이 (오십억)/(50억) 정도로 어~ 결정되었었고요.
# 근데 집행률을 보니까 지출액 봐서 보니까 (팔십칠 퍼센트로)/(87퍼센트로) 나와 있습니다.
# 삭감된 예산에서도 집행률이 (팔십칠 퍼센트인데요.)/(87퍼센트인데요.)
# 어~ 이거와 관련해서 이 노숙인 등이 의료지원을 받기 위해서는 어~ 기준이 좀 있습니다.
# 그~ 노숙인 (일종)/(1종) 의료급여 내지 서울시 의료지원비를 받아야 되는 기준이 있는데 이것도 한 공공병원 중심으로 지정된 노숙인 진료시설에서만 이용이 가능하죠.
# 네 근데 작년에 이렇게 집행률이 낮아지는 이유에 대해서 한번 설명을 좀 해 주시겠어요?
# 어 말씀하신 대로 사실 (칠십칠 개의)/(77개의) 그~ 병원과 약국 뭐 어~ 그렇게 의료시설을 이제 지정해서
# 그 기관을 노숙인들이 이제 전담으로 이용할 수 있도록 이렇게 지금 현재 국가가 하고 있는 시스템입니다 그래서 어~ 그 노숙인분들이 일단 코로나 관련해서
# 사실 조금 그 병원 이용률이 좀 적었고요.
# 그리고 특히 이제 작년 어~ (시월쯤에는)/(10월쯤에는) 코로나 전담병원으로 저희 동부병원이나 이런 병원 등이 좀 지정이 되면서 어~
# 노숙인분들 진료받을 수 있는 여건이 조금 안 좋아진 부분도 예 있습니다.
# 그래서 저희가 그~ 일단 중앙정부의 진료기관을 특정해서 운영하는 것에 대해서 좀 개선 건의를 지속적으로 해 오고 있고요.
# 특히 어~ 이제 자치구하고 협력해서 그~ 추가로 노숙인 진료 병원을 지정하는 노력을 지금 기울이고 있고
# 그래서 (한 군데)/(1군데) 홍익병원을 추가로 지정을 했고요 현재도 (두 군데)/(2군데) 지금 협의 중에 있다는 말씀을 드립니다.
# 예 이게 코로나라는 초유의 사태 안에서 어찌 보면 가장 또 열악한 환경에 계신 분들이 더 열악한 환경에 놓여지게 되는 상황이었던 거 같고 특히나
# 그~ 지정병원 자체가 이제 전담병원으로다가 변형되면서 이분들이 가실 곳이 없어서 그리고 지정병원에서 진료를 거부당하고 하니까 뭐
# 몇 가지 사례가 있더라고요 그~ 엠뷸런스로다가 병상 병원 전전하다가 심정지로 사망하신 사례도 있었고 동상으로 발목절단 우려가 있는 환자가
# 노숙인 진료시설에 입원하고자 했으나 입원하지 못해서 종교기관에서 운영하는 민간구호병원에 입원해야 됐고 뭐 등등 이런 사례들이 좀 보여지고 있는데
# 우리가 노숙인 진료시설이라고 서울시가 운영하고 있는 곳이 전담 전담병원으로 변 뭐죠 바꾸면서 이것에 대한 대책을 마련하지 않은 상태에서 이것을 그냥 내버려
# 대책이 뭐 부족하게 마련하지 않다기보다는 부족하게 하고 결국은 이렇게 예산으로서 그 현상이 확인되게끔 한다는 건 대단히 행정으로서 무책임한 행위라고 저는 보여지거든요.
# 근데 그~ 사실상 그 전담병원 구체가 어찌 보면 한정적인 역할을 할 수밖에 없었다 이렇게 보여지고 그 서울시 의료지원 지침에 보면
# 천재지변 재난 기타 불가피한 상황 등 진료 의료시설에서 진료 수술 등이 곤란한 경우에는 일반 의료기관에서 진료 가능하도록 해야 한다 이런 얘기가 있어요.
# 근데 이런 것과 관련해서 용역 이거 인권위 용역보고서도 제가 봤는데 그 이 집행사례 아까와 같은 그런 기타 여하의 사례가 발생할
# 경우에 노숙인시설 실무자가 서울시에 증빙서류를 제출하고 허가 구하고 뭐 막 이런 방식으로 해서 간신히 그분들한테 지원되고 이런 방식으로 지금까지 또 여전히 하고 있다는 거죠.
# 그래서 거꾸로 된 행정 아닌가 이건 좀 그러기 때문에 결국 예산 집행률이 지금 (구십 퍼센트도)/(90퍼센트도) 안 나오는 퍼센테이지로다가 그것이 결과로서 확인되고 있는 거다 아까
# 노숙인들의 의료가 줄어들었다라고 설명하시는 건 사실은 맞지 않다 지금 이런 상황에서 훨씬 더 제한적이 놓여져 있는 환경도 좋아지지 않은 상태에서 의료 의료에 대한 요구가 줄어들 수는 없는 환경이었을 터인데
# 그렇다면 결국은 이들이 갈 수 있는 곳이나 지원받을 수 있는 상황이 만들어지지 않았던 것이 더 심각해졌다라고 우리는 평가할 수밖에 없지 않나라는 것들이 지금 예산의 집행 결과로서 나타난다고 저는 보는데요 실장님은 어떻게 보세요?
# 네 그런 부분도 있고요.
# 저희 일반인들도 의료급여비가 조금 절약됐다는 어~ 그런 상황에 비춰볼 때는 저희가 이제 노숙인분들도 마스크를 계속 쓰게 하시고 이러다 보니까
# 조금 그런 바이러스 감염으로 인한 뭐 감기랄지 약간 이런 부분들은 좀 적지 않았을까 그런 부분도 있고요.
# 예 근데 결론적으로는 사실 노숙인을 전담병원 지정해서 운영하는 부분은 현장에서는 굉장히 어~ 어려운 부분이 많이 있습니다 그래서 그 부분을 좀 폐지하도록
# 지속적으로 건의하고 어~ 그리고 저희가 이제 그~ 한의사가 있는 그 지원센터의 (한 곳과)/(1곳과)
# 그다음에 서울역 무료진료소를 또 이제 따로 운영하는 게 그런 노숙인 진료 공백이 있는 거에 대해서 일단 응급시스템으로 하고 있어서 그런 부분들 보완하면서 지속적인 제도 개선과
# 그리고 이런 부분들 좀 보완해 나가야 되지 않을까 싶습니다.
# 그니까 예산에 대한 고민도 있어야겠지만 그 민간병원이나 노숙인 진료시설 비지정 공공병원들 같은 경우를 조금 더 발굴하거나
# 이분들이 진료를 받을 수 있도록 이용절차나 아니면 병원 측의 진료비 정산 방식이나 이런 것들에 대해서 함께 병행해서 좀 이 집행 예산을 갖다가
# 제대로 활용할 수 있도록 이렇게 불용이 남지 않도록 하는 노력들이 대단히 필요하겠다는 생각을 좀 하고요.
# 이게 예산을 삭감한 상태에서도 (육억 원이나)/(6억 원이나) 남았다는 건 대단히 문제적이라 봅니다 특히나 이렇게 어~ 열악한 상태에 놓여져 있는 분들한테
# (일 원)/(1원) 일품 뭐 하나라도 되게 중요한 사업이기 때문에 그리고 이때 이 (사 차)/(4차) 추경에서 전용을 하셨잖아요 그 예산을 갖다가 저쪽 그 노숙인
# 뭐였죠 어~ 여기 나와 있던 건데 노숙인 프로그램 운영으로다가 전용을 하여서 저희가
# 어~ 쓰기로 했는데 결과적으로 그 집행률이 보니까 (이십팔 점 육 퍼센트가)/(28.6퍼센트가) 나왔단 말이에요.
# 이렇게 의료비 지원까지 삭감하면서 저희가 만들어낸 그 노숙인 프로그램 운영에 대해서
# 그게 아마 이제 그~ @이름4 위원님께서도 어~ 신경 써 주셔서 저희가 노숙인 어~ 지난해가 (이십 년)/(20년) 정책 뭐 집행한 지 (이십 년이어서)/(20년이어서)
# 국제 컨퍼런스를 계획하고 있다가 코로나가 심해지면서 그걸 취소하게 됐습니다 그래서 그걸 좀 못 썼던 거고요.
# 예 그니까 이게 (사 차)/(4차) 추경이라면 작년에 봤을 때는 하반기에 접해 들었을 텐데도 예산의 사용이나 아니면 그 상황에 대한 판단이나 이런 것들이
# 얼마나 안이했나 라는 것들을 좀 보여주는 상황이라고 저는 판단을 하고요.
# 어~ 모든 이제 추경과 관련해서 특히 이제 올해도 또 추경을 지금 앞두고 있는데 얼마나 불요불급한 부분에 있는가라는 것들이 정말 제대로 저기 평가되고 집행되어야 되겠다라는 생각을 다시 한번 하게 됩니다.
# 더불어 (이천십구 년에)/(2019년에) 노숙인 등의 복지 및 자립지원에 관한 법률 개정하여서 여성 거리노숙인들에게 보건 위생용품 지원하게 되어 있는데요.
# 이것과 관련해서도 제가 예산이 전혀 지금 저희 서울시에서 (이천이십 년)/(2020년) 때까지는 예산을 반영하다가 (이천이십일 년에는)/(2021년에는) 예산을 전혀 배정을 하지 않았어요.
# 그니까 (이천이십 년이)/(2020년이) 예산 배정 첫 해이기도 한데 지금 보니까 이게 후원물품으로 거의 어~ 집행을 하고 있는 상태이더라고요.
# 내용을 확인 혹시 하신 바가 있으십니까?
# 그~ 위원님께서 관심 가져 주셔서 저도 이거 챙겨봤습니다 근데 현재로서는 여성 노숙인이 한 (팔백십구 명)/(819명) 정도 되는데요.
# 대부분 어~ 시설이나 어~ 주거 프로그램을 이용하시고 그리고 이제 거리 노숙인이 한 육십오 분 정도 되십니다 근데 어~ (이천십구 년부터)/(2019년부터) 일단 보건 위생용품은 지원을 하고 있고
# 이제 올해 예산에 펀성을 안 한 것은 그~ 후원물품으로 이미 너무 이제 확보가 충분히 되어 있어서 관리 운영비를 활용해서 일단
# 그~ 가능하다 왜냐하면 대부분 시설에 계신 분들이고 또 거리 노숙인 분들은 우리 여기 다시서기 지원센터를 통해서 이제 어~ 보건 위생용품을 챙겨드릴 수 있기 때문에
# 어~ 그래서 별도 예산은 편성하지 않고 지금 각 센터별 관리운영비에서 충분히 사용할 수 있도록 지금 되어 있고 현재는
# 후원물품이 충분히 비치되어 있다 이 정도로 예 하고 있습니다.
# 후원에 기대서 어떻게 보면 후원에 대해 어~ 해주시는 것들이 많기 때문에 서울시가 예산 지원에 대해서는 지금 신경을 안 쓰고 있는 상황이긴 한데요.
# 저한테 주셨던 자료에 의하면 지금 수량이 개수로 나와 있어요 근데 이게 개수가 (오천백 개)/(5100개) (사천)/(4000) 몇 개 이렇게 나와 있는데 이 개수라는 것이 (일 인당)/(1인당) 몇 개 이렇게 환산되는 건 아니죠?
# 그냥 생리용품 개수라고 하면 정말로 (한 개를)/(1개를) 얘기하는 걸까요 아니면 (한 팩을)/(1팩을) 얘기하는 거 단위를 말씀해 주시겠어요?
# 정확하게
# (()) 하나
# 정확하게 말씀해 주세요.
# 개입니까?
# 그 (한 개라고)/(1개라고) 합니다.
# 그 (한 개의)/(1개의) 표현이 뭔가요 일회용 딱 맞지요?
# 그러면 그것이 (오천백 개라고)/(5100개라고) 수량이 되어 있고 배부가 (사천칠십 개라고)/(4070개라고) 하면 (일 인당)/(1인당) 사용하는 뭐 개수가 (일 일)/(1일) (일 일)/(1일) 몇 개 정도 될 거라고 여성들 뭐 대부분 감을 잡으실 것이고
# (한 회에)/(1회에) 몇 개 정도가 필요하다는 것도 보여지실 거고 이게 (한 달)/(1달) (한 달)/(1달) 단위로 필요한 개수입니다.
# 여기서 (오천)/(5000) 몇백 개 뭐 이렇게 말하고 있지만 이게 개수로 나누면 (일 인당)/(1인당) (일 인)/(1인) 뭐 (다섯 개)/(5개) (일 일당)/(1일당) (다섯 개만)/(5개만) 쓴다 그래도 (이백이십이 회분)/(222회분) 그것을 갖다 (열두 개로)/(12개로) 나눠 이렇게 해 보면
# 그렇게 많은 숫자가 아니라는 걸 확인할 수 있어요.
# 이게 충분하다고 아까 말씀하셨는데 이것이 정말로 충분한지에 대해서 누가 평가할지는 잘 모르겠습니다만 개수로 환산해 보시면 서울시 예산이 분명히 필요하다는 것들이 보여질 겁니다.
# 그리고 지난번에 그~ 여성 거리홈리스 관리해서 그 코로나 집단 발발하자 그 (이천이십일 년도)/(2021년도) 초에 그~ 서울역 일시보호소 내에서 여성
# 응급보호방을 감염의심자를 위한 임시격리시설로 운영하는 바람에 거기서 또 여성홈리스분들이 나오게 됐잖아요.
# 뭐 그런 등등의 이제 사례들을 보았을 때 요 법안이 만들어진 이후에 저희가 보건위생용품 지원과 관련해서 민간에만 맡겨 놓을 일은 아니다라는 것들을 좀 확인해 주셨으면 좋겠고
# 이거는 어~ 조금 더 관심 가지고 보시면 달라질 거라고 좀 생각을 해서요.
# (한 번)/(1번) 더 체크 현장 얘기 이야기를 다시 한번 이 아까 그 기준과 맞춰서 (한 번)/(1번) 더 확인해 주시고 저한테 별도 보고를 좀 해 주셨으면 좋겠습니다.
# 제가 현장 챙겨보겠습니다 네네.
# 네 @이름3 위원님 수고하셨습니다.
# 다음 @이름4 위원님 (질의해 주십시오.)/(idiom)
# 어~ 네 @이름4 위원입니다.
# 이거 지금 이제 결산서 (삼백오십팔 페이지를)/(358페이지를) 보면 어~ 복지정책실 복지정책과
# 성인지예산 집행결과가 나오거든요.
# 그거에 대해서 좀 실장님이 구체적으로 좀 보고를 좀 해 주세요.
# 네 사실 성인지예산은 저희 복지정책실 (일곱 개)/(7개) 과에 이제 그~ 성인지적인 측면에서 조금
# 균형감을 가지고 사업을 추진하라 이런 차원에서 성인지예산 사업을 지정을 하고 있고요.
# 복지정책과는 그 지역사회서비스투자사업하고 가사간병방문관리사지원사업 저소득시민부가급여지원사업 지역사회서비스청년사업단 (네 개)/(4개) 사업을 이제 성인지
# 예산 사업으로 지정을 했고 그 사업이 당초 그~ 뭐 성평등 효과를 좀 제고시키는 데 기여를 했느냐 이런 부분이 지금 이제 평가가 된 겁니다 근데 일부
# 지역사회서비스청년사업단은 어~ 여성 수혜 비중이 오히려 (칠십팔 프로다)/(78프로다) 그래서 이 성인지가
# 이게 정확한 데이터입니까 데이터가 이거 정확한 거예요 네.
# 한쪽 성비가 (칠십 프로를)/(70프로를) 넘지 않도록 되어 있는데 그 부분 그 부분에 대해서 좀 부족했다 이런 평가가 나온 겁니다.
# 그러면은 금년도도 또 똑같은 이런 식으로 그냥 하실 거예요?
# 이제 올해는 어~ 올해도 똑같이 사업을 그 동국대 산학협력단이 이 사업을 하고 있고요.
# 이제 이런 부분 해서 그 신청 받아가지고 저희가 온라인으로 그~ 체력증진 관련된 사업들을 이제 청년 대상으로 하고 있는데요.
# 어~
# 그러면 청년 대상 대상이라 하니까 나이는 딱 뭐 정해져 있나요?
# 네네 (십팔 세부터)/(18세부터) (삼십구)/(39) (십팔 세부터)/(18세부터) (삼십구 세까지요.)/(39세까지요.)
# (십팔 세부터)/(18세부터) (삼십구 세까지)/(39세까지) 그러면 그 이후의 나이는 해당이 없고요?
# 네 그렇습니다.
# 일단 (칠십 프로를)/(70프로를) 넘지 않도록 어~ 이번에는 어떻게 보면 그 여성 참가자를 좀 제한하는 식으로 해야 될 거 같습니다.
# 여성 참가자가 (칠십팔 퍼센트다)/(78퍼센트다) 이 말씀이잖아요 네.
# 그러면 이게 뭐 특별한 다른 또 방법은 없네요?
# 네.
# 하여튼 이쪽에 좀 신경 써 주시고 그다음에 (삼백칠십사 페이지)/(374페이지) 음 가사간병방문관리사 지원 그 일반회계 건도
# 이것도 좀 보니까 뭐 두리뭉실하게 그냥 지나가는데 이거 좀 구체적으로 설명을 좀 해 주세요.
# (삼백칠십사 페이지)/(374페이지) 이게 뭐 시간당 단가가 (만 사천 원)/(만 4000원) 정도고 뭐
# 이게 지금 (이천십구 년)/(2019년) 기준이거든요.
# 그 더 인상이 안 되는지 시간도 더 지금 (이십사 시간에서)/(24시간에서) (이십칠 시간으로)/(27시간으로) 늘어나는데 이거 저 구체적인 내용을 좀 설명을 해 주세요.
# 국가사업인가 시 (()) 아 이게 이제 국비보조사업이고요.
# 국가가 (오십 프로)/(50프로) 그다음에 시가 (오십 프로)/(50프로) 지원하는 사업입니다.
# 일단 그~ 가사간병이 필요한 저소득 취약계층한테 바우처 이용권을 어~ 발급을 해서 그분이 이제 어~
# 요양보호사들을 통해서 서비스를 받는 거고요.
# 어~ 월 (이십사 시간이나)/(24시간이나) (이십칠 시간)/(27시간) 어~ 그다음에 이제 병원에 입원해 계셨다가 퇴원하신 분들은 (사십 시간까지)/(40시간까지) 어~
# 근데 여기 지금 보면은 (일 회)/(1회) 방문 시에 최소 (두 시간)/(2시간) 이상으로 하는 게 원칙인데 시간이 조금 부족하지 않나요?
# (두 시간)/(2시간) 정도 가지고는 시간이 더 늘어나면 예산도 더 이제 늘어나겠지만은 근데 이거 시간도 시간 수당도
# 이게 만 시간당 (만 사천 원인데요.)/(14000원인데요.)
# 이게 (이천십구 년)/(2019년) 기준이거든요.
# 그게 이제 매년 올라갑니다 그래서 (이천)/(2000)
# (이천이십 년)/(2020년) (이십)/(20)
# (만 사천팔백 원이고요.)/(만 4800원이고요.)
# (팔백 원)/(800원) 올라갔어요 (이 년)/(2년) 만에?
# 예 지난해는 (만 사천오백 원이었습니다.)/(14500원이었습니다.)
# 그럼 (이천십구 년)/(2019년) (만 사천 원이고)/(14000원이고) 그럼 (오백 원)/(500원) 뭐 (삼백 원)/(300원) 이렇게 올라가나요 이거 좀 너무 액수가 적은 거 아니에요?
# 그건 이제 국가가 좀 정하는 부분이 있어서
# 국가에서 기준이 그렇다 이 말씀이죠 기준이 이게 좀 너무 액수가 좀 적은데요.
# 그래서 이제 (이십사 시간)/(24시간) 또는 (이십칠 시간만)/(27시간만) 그거 해도 어~ 그분들이 혜택받는 걸 느낄 수 있나요 대상자가?
# 네 이용 인원이 전체 (오백팔 명입니다)/(508명입니다) 그래서 일단 어~ 이걸로 긴급한 가사간병방문 지원은 받고 만약 네네 이 부분이
# 지속적인 어떤 도움이 필요한 경우에는 저희 (()) 예 돌봄 이제 노인맞춤돌봄으로 들어오시든지 뭐 이렇게 좀
# 그 현재로서는 예산에 비해서 이 정도 수준밖에 못 한다 이 말씀이죠?
# 현재 어쨌든 이 정책 설계가 이렇게 되어 있는 상황입니다 예예.
# 이것도 좀 본 위원이 생각할 때는 조금 미흡한데 네 알겠습니다.
# 네 @이름4 위원님 수고하셨습니다 다음은 @이름5 위원님 (질의해 주십시오.)/(idiom)
# 네 (추가 질의하실 위원님 계십니까?)/(idiom)
# @이름2 위원님 예 @이름3 위원님 (추가 질의하실 내용 없으십니까?)/(idiom)
# 어 네 지금 사실은 우리 결산이 작년에 이제 코로나라는 좀 특수한 상황이 있다 보니 솔직히 좀 뒤죽박죽이에요.
# ----------------------------------------

# %%
# 정규 표현식을 사용하여 패턴을 제거하는 코드에요. 전처리를 위한 테스트에요
# (()), /(), /(...), 개별적으로 등장하는 (, ) 패턴을 제거해요.
import os
import json
import random
import re

# JSON 파일들이 저장된 기본 디렉토리
base_dir = "/mnt/a/maxseats/(주의-원본)주요 영역별 회의 음성인식 데이터"


# 정규 표현식을 사용하여 패턴 제거
def remove_patterns(text):
    text = re.sub(r'/\([^\)]+\)', '', text)  # /( *) 패턴 제거, /(...) 형식 제거
    text = re.sub(r'[()]', '', text)         # 개별적으로 등장하는 ( 및 ) 제거
    return text.strip()


# 모든 JSON 파일 경로를 리스트에 저장
json_files = []
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".json"):
            json_files.append(os.path.join(root, file))

# 무작위로 10개의 JSON 파일 선택
random_files = random.sample(json_files, 10)

# 선택된 JSON 파일들에서 'form' 값을 출력
for json_file in random_files:
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        print(f"File: {json_file}\n")
        for utterance in data.get('utterance', []):
            target = utterance.get('form', '')
            print(target)
            print("-> ", remove_patterns(target), "\n")
            if not remove_patterns(target):
                print("비어 있습니다~")
        print('-' * 40)
# Out:
# File: /mnt/a/maxseats/(주의-원본)주요 영역별 회의 음성인식 데이터/002.주요_영역별_회의_음성인식_데이터/01.데이터/unzipped_files/DGBDF21000184.json
#
# 산책하듯이 가볍게 역사를 걷는 시간
# ->  산책하듯이 가볍게 역사를 걷는 시간
#
# 네 번째 시간인가요
# ->  네 번째 시간인가요
#
# 네 네 번째 파트입니다 네에
# ->  네 네 번째 파트입니다 네에
#
# 댓글 다음 댓글 가볼게요 이제 제 차례죠
# ->  댓글 다음 댓글 가볼게요 이제 제 차례죠
#
# 네
# ->  네
#
# 자 출발 비디오라면님 무 무슨 뜻이죠 뭐 출발 비디오 여행이랑 라면 좋아하시는 분인가봐요 자 읽어드릴 오잇 두 분 케미가 넘나 좋네요 남자 분이 오히려 차분하시고 여자분 드립이 빵빵 터집니다
# ->  자 출발 비디오라면님 무 무슨 뜻이죠 뭐 출발 비디오 여행이랑 라면 좋아하시는 분인가봐요 자 읽어드릴 오잇 두 분 케미가 넘나 좋네요 남자 분이 오히려 차분하시고 여자분 드립이 빵빵 터집니다
#
# 근데 두 분 무슨 사이신지
# ->  근데 두 분 무슨 사이신지
#
# 이거 약간 변강쇠 느낌이에요
# ->  이거 약간 변강쇠 느낌이에요
#
# 다 알잖아요
# ->  다 알잖아요
#
# 네
# ->  네
#
# 네 사실은 뭐 점이다
# ->  네 사실은 뭐 점이다
#
# 네
# ->  네
#
# 제가 다 듣고 있는데
# ->  제가 다 듣고 있는데
#
# 전 몰랐거든요 네 아까 뒤에뀨님이
# ->  전 몰랐거든요 네 아까 뒤에뀨님이
#
# 네
# ->  네
#
# 어 찍었어요 아 출발비디오라면 @이름5이다
# ->  어 찍었어요 아 출발비디오라면 @이름5이다
#
# 음 어떤 근거로 이렇게
# ->  음 어떤 근거로 이렇게
#
# 성향이 출발 비디오 여행 좋아하고 라면도 좋아한다고 얘기했다
# ->  성향이 출발 비디오 여행 좋아하고 라면도 좋아한다고 얘기했다
#
# 어떻게 그렇게 속속들이 아는 거죠 무슨 사생활을
# ->  어떻게 그렇게 속속들이 아는 거죠 무슨 사생활을
#
# 무슨 사 사이인지 두 분 무슨 사이신지
# ->  무슨 사 사이인지 두 분 무슨 사이신지
#
# 왜 왜 그러지
# ->  왜 왜 그러지
#
# 그냥 그럴 수 있죠
# ->  그냥 그럴 수 있죠
#
# 이 사실 제가 이제 (십일월)/(11월) (십구 일이면은)/(29일이면은) 아직 이 방송에 참여할지 몰랐던 때였구요 예에 너무 좋아하는 형과 누나가 또 하니까
# ->  이 사실 제가 이제 십일월 십구 일이면은 아직 이 방송에 참여할지 몰랐던 때였구요 예에 너무 좋아하는 형과 누나가 또 하니까
#
# 음
# ->  음
#
# 듣다가 이제 가입을 했는데 말씀하신 대로 출발비디오 여행을 굉장히 좋아합니다 근데 제가 제일 좋아하는 이 일요일에 성스러운 의식이 있어요
# ->  듣다가 이제 가입을 했는데 말씀하신 대로 출발비디오 여행을 굉장히 좋아합니다 근데 제가 제일 좋아하는 이 일요일에 성스러운 의식이 있어요
#
# 아 뭔가요 아침에 일어나서
# ->  아 뭔가요 아침에 일어나서
#
# (열두 시)/(12시) (이십 분에)/(20분에)
# ->  열두 시 이십 분에
#
# 네
# ->  네
#
# 출발 비디오 여행을 감상하면서 라면을 딱 끓여서 먹는 겁니다
# ->  출발 비디오 여행을 감상하면서 라면을 딱 끓여서 먹는 겁니다
#
# 크 밥 말아서 뚝딱 그게 나오고 있네요 그죠 영화대 영화 으아
# ->  크 밥 말아서 뚝딱 그게 나오고 있네요 그죠 영화대 영화 으아
#
# 보면서 먹고 나면은 그게 정말 일요일 같아요
# ->  보면서 먹고 나면은 그게 정말 일요일 같아요
#
# 슈퍼 그레잇이네요
# ->  슈퍼 그레잇이네요
#
# 슈퍼 그레잇
# ->  슈퍼 그레잇
#
# 야
# ->  야
#
# 그 또 그 여자분들이 빵빵 터집니다 라고 쓰셨는데
# ->  그 또 그 여자분들이 빵빵 터집니다 라고 쓰셨는데
#
# 예
# ->  예
#
# 무슨 드립이 가장 웃겼었어요 우리 윤영 드립 중에
# ->  무슨 드립이 가장 웃겼었어요 우리 윤영 드립 중에
#
# 어 일단은 챕터 소개할 때
# ->  어 일단은 챕터 소개할 때
#
# 어
# ->  어
#
# 약간 좀 기계와 목소리 된 거니까 아까 말씀하신 알렉산드로스
# ->  약간 좀 기계와 목소리 된 거니까 아까 말씀하신 알렉산드로스
#
# 아 이런 거 때
# ->  아 이런 거 때
#
# 와 듣는데 혹시 뭐 나 먹었나 마리화나 좀 있나요 이거 제정신으 놀랍게도 저도 이렇게 같이 생방을 해보니까 이 모든 게 제정신에서
# ->  와 듣는데 혹시 뭐 나 먹었나 마리화나 좀 있나요 이거 제정신으 놀랍게도 저도 이렇게 같이 생방을 해보니까 이 모든 게 제정신에서
#
# 정말 대단합니다
# ->  정말 대단합니다
#
# 항상 듣는 얘기라서 술 마셨냐
# ->  항상 듣는 얘기라서 술 마셨냐
#
# 지금 닉네임이 재미있는데 우리 둘 닉네임도 한번 풀어주면 좋을 것 같아요
# ->  지금 닉네임이 재미있는데 우리 둘 닉네임도 한번 풀어주면 좋을 것 같아요
#
# 이담 파르크 씨부터 먼저
# ->  이담 파르크 씨부터 먼저
#
# 그는 이제 제 본명이
# ->  그는 이제 제 본명이
#
# 네
# ->  네
#
# 박이다입니다 팔팔이잖아요 약간 라틴어 식으로 읽으면 이단 파르크
# ->  박이다입니다 팔팔이잖아요 약간 라틴어 식으로 읽으면 이단 파르크
#
# 아 잘 지었네요 잘 지었어
# ->  아 잘 지었네요 잘 지었어
#
# 멋있죠
# ->  멋있죠
#
# 예 뭐 있어 보여요 되게 예 저는
# ->  예 뭐 있어 보여요 되게 예 저는
#
# 저는 그래서 이단 파크 라고 적구요
# ->  저는 그래서 이단 파크 라고 적구요
#
# 그렇군요
# ->  그렇군요
#
# (())
# ->
#
# 비어 있습니다~
# 스타크래프트 뭐지 테란 황제 테란 이런 거 이런 거죠 아이 뭐냐면은 황제 타마린이 페루지역에 살고 있네
# ->  스타크래프트 뭐지 테란 황제 테란 이런 거 이런 거죠 아이 뭐냐면은 황제 타마린이 페루지역에 살고 있네
#
# 네 뭐라고요
# ->  네 뭐라고요
#
# 그 지역 원숭이 이름이 원숭이 이름이에요
# ->  그 지역 원숭이 이름이 원숭이 이름이에요
#
# 원숭이의 종이에요 종
# ->  원숭이의 종이에요 종
#
# 종이에요 종 제가 이걸 한 이유는
# ->  종이에요 종 제가 이걸 한 이유는
#
# 네
# ->  네
#
# 음
# ->  음
#
# 모든 닉네임이 다 막혀가지고
# ->  모든 닉네임이 다 막혀가지고
#
# 으음
# ->  으음
#
# 하 뭐 모아지 하고 싶은데 이제 딱 티비에
# ->  하 뭐 모아지 하고 싶은데 이제 딱 티비에
#
# 네
# ->  네
#
# 그 뭐였지
# ->  그 뭐였지
#
# 동물의 세계 이런 거
# ->  동물의 세계 이런 거
#
# 동물의 세계가 아니라
# ->  동물의 세계가 아니라
#
# 내셔널 아
# ->  내셔널 아
#
# 세테기 세테기에 페루 특집이 나오더라구요 거기 페루 여행 가신 그 여행 작가님이 막 오 수염이 있어요 그게 사실 너무 인상적이어서 그게 딱 밑에 딱 뜨더라고요 저 원숭이가
# ->  세테기 세테기에 페루 특집이 나오더라구요 거기 페루 여행 가신 그 여행 작가님이 막 오 수염이 있어요 그게 사실 너무 인상적이어서 그게 딱 밑에 딱 뜨더라고요 저 원숭이가
#
# 네
# ->  네
#
# 황제 타마린이라는
# ->  황제 타마린이라는
#
# 그 본인하고 공통점을 보이고 수염 있는 거예요
# ->  그 본인하고 공통점을 보이고 수염 있는 거예요
#
# 없죠 그냥 그냥 한 거에요 눈에 딱 보여서 그냥 한 거죠 그 자리에서 없더라고 이 아이디가 그래서 어 근데 이거 이후로 황제 타마린이라는 닉네임을 자주 사용해요
# ->  없죠 그냥 그냥 한 거에요 눈에 딱 보여서 그냥 한 거죠 그 자리에서 없더라고 이 아이디가 그래서 어 근데 이거 이후로 황제 타마린이라는 닉네임을 자주 사용해요
#
# 진짜요
# ->  진짜요
#
# 네
# ->  네
#
# 아 그 방송이 구했네요 윤형을
# ->  아 그 방송이 구했네요 윤형을
#
# 어 네 네
# ->  어 네 네
#
# 처음에 이 닉네임 봤을 때
# ->  처음에 이 닉네임 봤을 때
#
# 네
# ->  네
#
# 저 역사 전공자잖아요
# ->  저 역사 전공자잖아요
#
# 아 네 네
# ->  아 네 네
#
# 내가 모르는 헝 파벌이 몇 세였군요
# ->  내가 모르는 헝 파벌이 몇 세였군요
#
# 원송이였어요 아주 귀엽게 생겼어요 이게 수염이 나가지고
# ->  원송이였어요 아주 귀엽게 생겼어요 이게 수염이 나가지고
#
# 속은 느낌 나네
# ->  속은 느낌 나네
#
# 네 아니 푸 출발 비디오 라면 뻔히 우리 둘 관계 아시면서
# ->  네 아니 푸 출발 비디오 라면 뻔히 우리 둘 관계 아시면서
#
# 네
# ->  네
#
# 두 분 무슨 사이신지 이렇게 하항 이 시끼 진짜 항상
# ->  두 분 무슨 사이신지 이렇게 하항 이 시끼 진짜 항상
#
# 원래 그 항상 조심해야 돼요
# ->  원래 그 항상 조심해야 돼요
#
# 아 그럼요
# ->  아 그럼요
#
# 음 가까이 만나는 사람일수록 그런 게 이제 혹시나 내가 뭘 방송을 빙자해서 뭔가 꿈틀고 있지 않나
# ->  음 가까이 만나는 사람일수록 그런 게 이제 혹시나 내가 뭘 방송을 빙자해서 뭔가 꿈틀고 있지 않나
#
# 아주 많이 납니다 아니랍니다 네
# ->  아주 많이 납니다 아니랍니다 네
#
# 전혀 아니라는 거 아시잖아요 딱 보니까
# ->  전혀 아니라는 거 아시잖아요 딱 보니까
#
# 본인이 가까운 사이에 좀 이렇게 흥부의 정을 많이 느끼는 것 아니에요
# ->  본인이 가까운 사이에 좀 이렇게 흥부의 정을 많이 느끼는 것 아니에요
#
# 난 알지롱
# ->  난 알지롱
#
# 아마 한때 추억이었구요
# ->  아마 한때 추억이었구요
#
# 페스트 페스트 더 페스트 야 예 넘하네 그다음에
# ->  페스트 페스트 더 페스트 야 예 넘하네 그다음에
#
# 누 누구 타이밍이죠 어 여기 여기 @이름6이 할 차례 할지는
# ->  누 누구 타이밍이죠 어 여기 여기 @이름6이 할 차례 할지는
#
# 나 했는데 아까
# ->  나 했는데 아까
#
# 제가 할까요 네 어 진진진팔님이 징기스칸 노래 진짜 있는 건가요 아 이거 아마 우리 징기스칸 방송하시고 나서 달아주신 것 같아요
# ->  제가 할까요 네 어 진진진팔님이 징기스칸 노래 진짜 있는 건가요 아 이거 아마 우리 징기스칸 방송하시고 나서 달아주신 것 같아요
#
# 이분이 유명하죠
# ->  이분이 유명하죠
#
# 불러봐요 하 깐 나나나나나나 나 (()) /(bgm)
# ->  불러봐요 하 깐 나나나나나나 나
#
# (()) 이 마성의 노래였잖습니까 모두가 모두가 징기스칸이라는 노랫말을 아는데 그 뒤로 몰라요
# ->  이 마성의 노래였잖습니까 모두가 모두가 징기스칸이라는 노랫말을 아는데 그 뒤로 몰라요
#
# 맞어 맞어 맞어
# ->  맞어 맞어 맞어
#
# 나나나 나나나 나나나 나나나나 /(noise)
# ->  나나나 나나나 나나나 나나나나
#
# 어 입냄새 아 이 라디오를 많이 들으시면 이 노래가 가끔 나옵니다
# ->  어 입냄새 아 이 라디오를 많이 들으시면 이 노래가 가끔 나옵니다
#
# 어 맞아 맞아 맞아 나와요 나와요 나와요 예 왜 이분 사실 저희
# ->  어 맞아 맞아 맞아 나와요 나와요 나와요 예 왜 이분 사실 저희
#
# 짠 멤버 (())
# ->  짠 멤버
#
# 이분이
# ->  이분이
#
# 네
# ->  네
#
# 되게 언어의 굉장히 재능 있으신 분이라서 중국어도 잘하시고
# ->  되게 언어의 굉장히 재능 있으신 분이라서 중국어도 잘하시고
#
# 아 정말요
# ->  아 정말요
#
# 영어는 기본이고
# ->  영어는 기본이고
#
# 기본이고
# ->  기본이고
#
# 요즘 또 러시아
# ->  요즘 또 러시아
#
# 러시아어 알면서 그래
# ->  러시아어 알면서 그래
#
# 유명 반도체 회사에서도 아주 멋진 누님
# ->  유명 반도체 회사에서도 아주 멋진 누님
#
# 재밌다고 해주셔서 또 이렇게 댓글을 여러 개 달아주셔서 너무 감사하더라고요
# ->  재밌다고 해주셔서 또 이렇게 댓글을 여러 개 달아주셔서 너무 감사하더라고요
#
# 또 실은 대학에서 중문과 전공하셨대요 중문과 우리가 중국인물들 올리니까
# ->  또 실은 대학에서 중문과 전공하셨대요 중문과 우리가 중국인물들 올리니까
#
# 네
# ->  네
#
# 아주 그냥 관심을 많이 보이시더라고요
# ->  아주 그냥 관심을 많이 보이시더라고요
#
# 그 이후에도 상황극 대박입니다라고 올리셨구
# ->  그 이후에도 상황극 대박입니다라고 올리셨구
#
# 어떤 상황극이 있었어요
# ->  어떤 상황극이 있었어요
#
# 칸 아닌가
# ->  칸 아닌가
#
# 징기스칸 맞아요 징기스칸이라고 이복 형제들을 싸우는 장면 했었거든요
# ->  징기스칸 맞아요 징기스칸이라고 이복 형제들을 싸우는 장면 했었거든요
#
# 그래서 같은 날에 올려주셨네요그래서
# ->  그래서 같은 날에 올려주셨네요그래서
#
# 음
# ->  음
#
# 그리고 아마 들으시면서 올리셨나봐요 또 쑨원 넘나 기대되는 것 아껴두고 내일 들을 거예요
# ->  그리고 아마 들으시면서 올리셨나봐요 또 쑨원 넘나 기대되는 것 아껴두고 내일 들을 거예요
#
# 하트 너무 좋아요
# ->  하트 너무 좋아요
#
# 어 그러네요 하트 하트 너무 너무 좋죠
# ->  어 그러네요 하트 하트 너무 너무 좋죠
#
# 저한테 보낸 거겠죠 네
# ->  저한테 보낸 거겠죠 네
#
# 쑨원편도 재미있었어요 대만에서 중산공원 갔던 기억이 떠오르네요 추억추억
# ->  쑨원편도 재미있었어요 대만에서 중산공원 갔던 기억이 떠오르네요 추억추억
#
# 아 이분 대학교 때 교환학생을 대만에 가셨다고
# ->  아 이분 대학교 때 교환학생을 대만에 가셨다고
#
# 아 예 맞아요
# ->  아 예 맞아요
#
# 중산공원
# ->  중산공원
#
# 네
# ->  네
#
# 그 저희가 이렇게 방송할 때도 여행과 관련된 에피소드를 푸는 것도 좋은 것 같아요
# ->  그 저희가 이렇게 방송할 때도 여행과 관련된 에피소드를 푸는 것도 좋은 것 같아요
#
# 아 좋죠 저번에 그때 우리 윤형도 바티카에서
# ->  아 좋죠 저번에 그때 우리 윤형도 바티카에서
#
# 그 재미는 없었는데 어쨌든 그런 건 풀면 좀 재미있고
# ->  그 재미는 없었는데 어쨌든 그런 건 풀면 좀 재미있고
#
# 개그맨도 아닌데 우리
# ->  개그맨도 아닌데 우리
#
# 네네네네네네 네
# ->  네네네네네네 네
#
# 좋아요
# ->  좋아요
#
# 진진진팔님이 너무 이렇게 또 들으면서 잘 올려주셔가지고 감사합니다
# ->  진진진팔님이 너무 이렇게 또 들으면서 잘 올려주셔가지고 감사합니다
#
# 네 감사합니다 고마워요
# ->  네 감사합니다 고마워요
#
# 네 계속 들어주세요 언니
# ->  네 계속 들어주세요 언니
#
# 올라가세요
# ->  올라가세요
#
# 네
# ->  네
#
# 어 다음은 이제 아 또 한 분은 지금 거북아
# ->  어 다음은 이제 아 또 한 분은 지금 거북아
#
# 거북아 네
# ->  거북아 네
#
# 닉네임은 팥 (일칠일이님인데요)/(1712님인데요)
# ->  닉네임은 팥 일칠일이님인데요
#
# 팥 팥방 관계자인가요 진짜 그런 것 같아요 뒤에 네 자리가 음 (일칠하나하나)/(1711) 팟빵 내선번호 (일칠일일 번)/(1711번)
# ->  팥 팥방 관계자인가요 진짜 그런 것 같아요 뒤에 네 자리가 음 일칠하나하나 팟빵 내선번호 일칠일일 번
#
# 내선번호
# ->  내선번호
#
# 내선번
# ->  내선번
#
# 그래서 이 골목상권 살리기 이런 거 있죠 아 침 튀겼어 이씨
# ->  그래서 이 골목상권 살리기 이런 거 있죠 아 침 튀겼어 이씨
#
# 방송 살리기 쉽지 않네요
# ->  방송 살리기 쉽지 않네요
#
# 어 그래서 (()) @이름1씨 같은 마음으로 여 와가지고 댓글 달아주고 후원도 해주시고 그러는게 아닌가
# ->  어 그래서  @이름1씨 같은 마음으로 여 와가지고 댓글 달아주고 후원도 해주시고 그러는게 아닌가
#
# (오천원)/(5000원) 후원 궁금한게 있는데 후원금은 어떤 분이 관리를 하는 거죠
# ->  오천원 후원 궁금한게 있는데 후원금은 어떤 분이 관리를 하는 거죠
#
# 제가 관리하고 있습니다
# ->  제가 관리하고 있습니다
#
# 근데 그 지금 뺄 수가 없지 않을까
# ->  근데 그 지금 뺄 수가 없지 않을까
#
# 제가 정확히는 모르겠는데 (오만 원인가)/(5만 원인가) 돼야 뺄수 있는 걸로 알고 있는데 이제 (오만 원)/(5만 원) 차면 저희 회식할 때
# ->  제가 정확히는 모르겠는데 오만 원인가 돼야 뺄수 있는 걸로 알고 있는데 이제 오만 원 차면 저희 회식할 때
#
# (사 만원)/(4만 원) 더 필요합니다
# ->  사 만원 더 필요합니다
#
# 아 자 댓글 많습니다
# ->  아 자 댓글 많습니다
#
# 네 어 빨리 가볼까요 네 숫자 @전화번호1님이 올려주셨습니다 정말 유쾌한 방송이네요 즐겁게 배우고 갑니다 꾸준히 올려 주세요 아주 굉장히 젠틀하게 올려주셨네요
# ->  네 어 빨리 가볼까요 네 숫자 @전화번호1님이 올려주셨습니다 정말 유쾌한 방송이네요 즐겁게 배우고 갑니다 꾸준히 올려 주세요 아주 굉장히 젠틀하게 올려주셨네요
#
# 되게 뭐 딱 세 문장이지만 정말 이런 거 힘이 됩니다
# ->  되게 뭐 딱 세 문장이지만 정말 이런 거 힘이 됩니다
#
# 네 그쵸 꾸준히 올려달라는 말
# ->  네 그쵸 꾸준히 올려달라는 말
#
# 네 그리고 재밌게 보고 싶다라는 거잖아요 유쾌하다는 말이 또 좋지 않습니까
# ->  네 그리고 재밌게 보고 싶다라는 거잖아요 유쾌하다는 말이 또 좋지 않습니까
#
# 그쵸 그리고 또 배우고 간다는 건 참 보람있네요
# ->  그쵸 그리고 또 배우고 간다는 건 참 보람있네요
#
# 실은 제가 다른 역사 방송들을 살짝 좀 보는데요
# ->  실은 제가 다른 역사 방송들을 살짝 좀 보는데요
#
# 네네네
# ->  네네네
#
# 댓글에 유쾌하단 말 잘 달립니다
# ->  댓글에 유쾌하단 말 잘 달립니다
#
# 아 그래요 아
# ->  아 그래요 아
#
# 자부심 가져도 됩니다
# ->  자부심 가져도 됩니다
#
# 우리 그냥 재미 하나로 먹고 사는데
# ->  우리 그냥 재미 하나로 먹고 사는데
#
# 좋습니다
# ->  좋습니다
#
# 웃겨 네 감사합니다 네
# ->  웃겨 네 감사합니다 네
#
# 다음 댓글 제가 할게요 네 자 치토스님
# ->  다음 댓글 제가 할게요 네 자 치토스님
#
# 네
# ->  네
#
# 자 과자 좋아하시나봐요 아 맛있네요
# ->  자 과자 좋아하시나봐요 아 맛있네요
#
# 그 치토스가 이 치토스에요
# ->  그 치토스가 이 치토스에요
#
# 자 어엇 드디어 세 이야기가 올라왔네요 감사합니다
# ->  자 어엇 드디어 세 이야기가 올라왔네요 감사합니다
#
# @이름2씨 성대모사
# ->  @이름2씨 성대모사
#
# 어 이분
# ->  어 이분
#
# 네
# ->  네
#
# 오늘 이렇게 소리 소문 없이 세 이야기를 계속 기다렸었다는 게 너무 감사합니다 어 저희 방송 치토스랑 뭐 치토스 먹으면서 들으시면 재미있을 거예요
# ->  오늘 이렇게 소리 소문 없이 세 이야기를 계속 기다렸었다는 게 너무 감사합니다 어 저희 방송 치토스랑 뭐 치토스 먹으면서 들으시면 재미있을 거예요
#
# 저는 개인적으로 매콤한 맛 좋아합니다 매콤함
# ->  저는 개인적으로 매콤한 맛 좋아합니다 매콤함
#
# 아 네
# ->  아 네
#
# 저는 바베큐맛
# ->  저는 바베큐맛
#
# 바베큐맛이요 어떤 맛 좋아하세요
# ->  바베큐맛이요 어떤 맛 좋아하세요
#
# 기 기억이 안 나요 그냥 빨간색 먹었던 거 같은데
# ->  기 기억이 안 나요 그냥 빨간색 먹었던 거 같은데
#
# 빨간색이면
# ->  빨간색이면
#
# 바베큐
# ->  바베큐
#
# 바베큐맛에요 아 바베큐 맛
# ->  바베큐맛에요 아 바베큐 맛
#
# 옛날에 또 화이트 치토스 있었어요 화이트
# ->  옛날에 또 화이트 치토스 있었어요 화이트
#
# 그것도 먹었던 것 같아요 저
# ->  그것도 먹었던 것 같아요 저
#
# 많이 좀 그리워요 그게
# ->  많이 좀 그리워요 그게
#
# 어 치즈 맛나고 그랬던 거죠
# ->  어 치즈 맛나고 그랬던 거죠
#
# 맞아요 맞아요 느끼한데 지금은 (()) 생각나죠
# ->  맞아요 맞아요 느끼한데 지금은  생각나죠
#
# 저희는 방학 때 제 추억 중의 하나가 중학교 때 방학 때 만화책 한 (열 권)/(10권) 정도 빌려요
# ->  저희는 방학 때 제 추억 중의 하나가 중학교 때 방학 때 만화책 한 열 권 정도 빌려요
#
# 네
# ->  네
#
# 친오빠가 있었거든요 그럼 그날 밤새는 거야 그래서 그 날은 저희 오빠 되게 민주적인 사람이어서 저 저랑 이제 컴퓨터를 나눠서 해야 됐거든요 근데 한다니까
# ->  친오빠가 있었거든요 그럼 그날 밤새는 거야 그래서 그 날은 저희 오빠 되게 민주적인 사람이어서 저 저랑 이제 컴퓨터를 나눠서 해야 됐거든요 근데 한다니까
#
# (두 시간은)/(2시간은) 누가 컴퓨터 하면 저는 (두 시간도)/(2시간도) 만화책을 읽는 거예요
# ->  두 시간은 누가 컴퓨터 하면 저는 두 시간도 만화책을 읽는 거예요
#
# 아 이게 되는 구나 이게
# ->  아 이게 되는 구나 이게
#
# 어 그러면 이제 새벽 (두 시에)/(2시에) 체인지해 자 이제 온라인 게임하고 (두 시간)/(2시간) 동안 오빠가 만화책 읽고
# ->  어 그러면 이제 새벽 두 시에 체인지해 자 이제 온라인 게임하고 두 시간 동안 오빠가 만화책 읽고
#
# 근데 그 키보드와 만화책에 과자 부스러기가 많이 묻어있네요
# ->  근데 그 키보드와 만화책에 과자 부스러기가 많이 묻어있네요
#
# 아 그럼요 그럼요 그러니까 과자도 이제
# ->  아 그럼요 그럼요 그러니까 과자도 이제
#
# 네
# ->  네
#
# 사장님 포카칩 (한 봉)/(1봉) 이 이 포카칩 (한 봉지)/(1봉지) 양파맛 꼭 양파 양파 맛과 그다음에 빠삐코 하나
# ->  사장님 포카칩 한 봉 이 이 포카칩 한 봉지 양파맛 꼭 양파 양파 맛과 그다음에 빠삐코 하나
#
# 빠삐코
# ->  빠삐코
#
# 빠삐꼬 하나 사서 단짠단짠 하면서 그게 되게 추억이네요 에어컨 딱 틀어놓고
# ->  빠삐꼬 하나 사서 단짠단짠 하면서 그게 되게 추억이네요 에어컨 딱 틀어놓고
#
# 야 어우
# ->  야 어우
#
# 밤새서 놀았죠
# ->  밤새서 놀았죠
#
# 몇 시에 주무시는 거예요 (())
# ->  몇 시에 주무시는 거예요
#
# 잠을 안 잤죠 아침에 이제 동이 트면 잤죠 이제
# ->  잠을 안 잤죠 아침에 이제 동이 트면 잤죠 이제
#
# 시험 기간 끝나고
# ->  시험 기간 끝나고
#
# 예 그렇죠
# ->  예 그렇죠
#
# 시험 기간 끝나고 홍형은 뭐 어떻게 보냈어요 전교 (이 등이라고)/(2등이라고) 들었는데 네 우와
# ->  시험 기간 끝나고 홍형은 뭐 어떻게 보냈어요 전교 이 등이라고 들었는데 네 우와
#
# 저도 시험 끝나면 일단은 늦게 자는 게 좋죠 저는 이제 또 비슷해요 영화 틀어놓고 영화를 좋아했거든요 네 한때는 지금 @이름3씨처럼
# ->  저도 시험 끝나면 일단은 늦게 자는 게 좋죠 저는 이제 또 비슷해요 영화 틀어놓고 영화를 좋아했거든요 네 한때는 지금 @이름3씨처럼
#
# 영화 리뷰어가 되고 싶었는데
# ->  영화 리뷰어가 되고 싶었는데
#
# 인생 영화 하나만 추천해 주세요
# ->  인생 영화 하나만 추천해 주세요
#
# 아 너무 많은데
# ->  아 너무 많은데
#
# 네 딱 하나만 그냥 새 생각나는 거
# ->  네 딱 하나만 그냥 새 생각나는 거
#
# 음 뭘 해야 될까요 저는 근데 음 단순합니다 유치할 수도 있는데 (()) 영화로 정말 빠지게 하는 거는 러브 액츄얼리 작품 명작이죠
# ->  음 뭘 해야 될까요 저는 근데 음 단순합니다 유치할 수도 있는데  영화로 정말 빠지게 하는 거는 러브 액츄얼리 작품 명작이죠
#
# 크
# ->  크
#
# 어우 그 명작이죠
# ->  어우 그 명작이죠
#
# 그 영화에서 키라애틀리가 나왔는데 굉장히 좋아했었고 그리고 어릴 때는 이제 예 /(noise)
# ->  그 영화에서 키라애틀리가 나왔는데 굉장히 좋아했었고 그리고 어릴 때는 이제 예
#
# 아니아니 계속해서
# ->  아니아니 계속해서
#
# 계속해서 할 게요 그 영화를 처음 봤을 때는 키이라 나이틀리를 보였는데 몇 번 해볼수록 다양한 인물들의 사랑이
# ->  계속해서 할 게요 그 영화를 처음 봤을 때는 키이라 나이틀리를 보였는데 몇 번 해볼수록 다양한 인물들의 사랑이
#
# 아니 그러면 영화를 보면서 시험 후유증을
# ->  아니 그러면 영화를 보면서 시험 후유증을
#
# 영화를 뭐 밤새서 두세 편 봤죠
# ->  영화를 뭐 밤새서 두세 편 봤죠
#
# 음
# ->  음
#
# @상호명1 이런 데다가 리뷰 쓰고 조용히
# ->  @상호명1 이런 데다가 리뷰 쓰고 조용히
#
# 아 추억의 @상호명1 아유
# ->  아 추억의 @상호명1 아유
#
# 깨알같이 @이름5 자랑을 하자면 글을 정말 잘 씁니다
# ->  깨알같이 @이름5 자랑을 하자면 글을 정말 잘 씁니다
#
# 아 아닙니다 아닙니다
# ->  아 아닙니다 아닙니다
#
# 진짜 문학적이에요
# ->  진짜 문학적이에요
#
# 말도 잘하고 아주 똑똑해요 네
# ->  말도 잘하고 아주 똑똑해요 네
#
# 코도 궁금하네요
# ->  코도 궁금하네요
#
# 코가 가지만 합니다
# ->  코가 가지만 합니다
#
# (()) 방학 때
# ->  방학 때
#
# 아 저 실은
# ->  아 저 실은
#
# 학교 방학 때
# ->  학교 방학 때
#
# 저는 검정고시 출신여가지고 지금도 백수나 메일이 방학입니다
# ->  저는 검정고시 출신여가지고 지금도 백수나 메일이 방학입니다
#
# 네 (()) 네 이 정도 하고 넘어가겠습니다
# ->  네  네 이 정도 하고 넘어가겠습니다
#
# 자
# ->  자
#
# 그다음에 써니 싸이니 누가
# ->  그다음에 써니 싸이니 누가
#
# 나 저거 했고요 (())
# ->  나 저거 했고요
#
# 써니 샤이니 이분은 일단은 닉네임이 약간 에스엠 연습생 느낌이에요
# ->  써니 샤이니 이분은 일단은 닉네임이 약간 에스엠 연습생 느낌이에요
#
# 소녀시대
# ->  소녀시대
#
# 조카분 샤이니 아 이게 그렇죠 우리 요번에 좀 안타까운 일이 있었던 그 하지만 저희 때는 정말 잘나갔던 그분이니까 그래서 너무 좋은 닉네임이네요 밝고 화창 합니다
# ->  조카분 샤이니 아 이게 그렇죠 우리 요번에 좀 안타까운 일이 있었던 그 하지만 저희 때는 정말 잘나갔던 그분이니까 그래서 너무 좋은 닉네임이네요 밝고 화창 합니다
#
# 네네
# ->  네네
#
# 자 너무 재미있어요 어 제제
# ->  자 너무 재미있어요 어 제제
#
# 서 선이 이름이 선희 아닐까 선희
# ->  서 선이 이름이 선희 아닐까 선희
#
# 아 선니
# ->  아 선니
#
# 써니
# ->  써니
#
# 네 죄송해요 읽어주세요
# ->  네 죄송해요 읽어주세요
#
# 그 이름을 가진 분들 별명이 댓글을 읽어보겠습니다
# ->  그 이름을 가진 분들 별명이 댓글을 읽어보겠습니다
#
# 네
# ->  네
#
# 너무 재미있어요 두 분 케미가 잘 맞는 것 같아요 유익하고 정겨운 방송 잘 듣고 있답니다 두 분 멋져요
# ->  너무 재미있어요 두 분 케미가 잘 맞는 것 같아요 유익하고 정겨운 방송 잘 듣고 있답니다 두 분 멋져요
#
# 어 감사합니다 아직 @이름5이 끼기 전이니까
# ->  어 감사합니다 아직 @이름5이 끼기 전이니까
#
# 아 그렇군요
# ->  아 그렇군요
#
# 그 지금 뭐 댓글 종합하자면 케미 잘 맞다 유익하다 유쾌하다 어 정말 칭찬 많이 받았습니다 좋습니다
# ->  그 지금 뭐 댓글 종합하자면 케미 잘 맞다 유익하다 유쾌하다 어 정말 칭찬 많이 받았습니다 좋습니다
#
# 감사합니다 네
# ->  감사합니다 네
#
# 그 저 음 두 분의 케미는 제 생각에도
# ->  그 저 음 두 분의 케미는 제 생각에도
#
# 네네
# ->  네네
#
# 너무 좋은 것 같아요 저도 이제 청취자였던 때가 있잖아요 사실 이런 어떤 조합에 낀다고 와서 제가 너무 두렵고
# ->  너무 좋은 것 같아요 저도 이제 청취자였던 때가 있잖아요 사실 이런 어떤 조합에 낀다고 와서 제가 너무 두렵고
#
# 무슨 소리하시는 건지 내가 껴주는 거지 뭐 약간 이런
# ->  무슨 소리하시는 건지 내가 껴주는 거지 뭐 약간 이런
#
# 할 것도 없는데 한번도 감사하다는 말씀
# ->  할 것도 없는데 한번도 감사하다는 말씀
#
# 무슨 소리 하시네
# ->  무슨 소리 하시네
#
# 좋아요 자
# ->  좋아요 자
#
# 네
# ->  네
#
# 올라갈게요 우리 윤영 차례죠 와 이 분은
# ->  올라갈게요 우리 윤영 차례죠 와 이 분은
#
# 네 @이름4씨가 댓글을 달아주셨는데요 안녕하세요 정말 재미있게 듣고 있어요 듣다가 빵빵 터져요 크크 저 이 채널 왜 이제 안 거죠 지식 나눠주셔서 감사합니다
# ->  네 @이름4씨가 댓글을 달아주셨는데요 안녕하세요 정말 재미있게 듣고 있어요 듣다가 빵빵 터져요 크크 저 이 채널 왜 이제 안 거죠 지식 나눠주셔서 감사합니다
#
# 앞으로도 힘내시고 기대할게요 하트 이렇게 달아주셨네요 제가 이 댓글을 딱 보고 어 @이름4 @이름4
# ->  앞으로도 힘내시고 기대할게요 하트 이렇게 달아주셨네요 제가 이 댓글을 딱 보고 어 @이름4 @이름4
#
# 오늘 왜 그러세요
# ->  오늘 왜 그러세요
#
# 제가 이 이름 봤거든요 제가 @상호명2에서만 봤는데 방송을 봤어요 그때도 역사 채널이어서 관심이 어 뭐지 하고 클릭해서 들었는데 재밌더라구요 그래서
# ->  제가 이 이름 봤거든요 제가 @상호명2에서만 봤는데 방송을 봤어요 그때도 역사 채널이어서 관심이 어 뭐지 하고 클릭해서 들었는데 재밌더라구요 그래서
#
# 어 그래서 그때 제가 제가 인상 깊었는데 딱 이 닉네임을 보고 어 설마 그분이신가 해서
# ->  어 그래서 그때 제가 제가 인상 깊었는데 딱 이 닉네임을 보고 어 설마 그분이신가 해서
#
# 헉 맞아요 부족한데 잘 봐주셔서 감사해요
# ->  헉 맞아요 부족한데 잘 봐주셔서 감사해요
#
# 진짜요
# ->  진짜요
#
# 이분이 @상호명2 팔로어가 (칠만 명이)/(7만 명이) 넘으세요
# ->  이분이 @상호명2 팔로어가 칠만 명이 넘으세요
#
# (칠만이요)/(7만이요)
# ->  칠만이요
#
# 그 역사로 방송을 하시는데 역사뿐만 아니라 시사문제 가지고도 이렇게 방송 많이 하시는데 정말 아름다우시고 네 아름다우시고 굉장히 되게 (()) 영광이었죠 그래서 기분이 되게 좋았어요
# ->  그 역사로 방송을 하시는데 역사뿐만 아니라 시사문제 가지고도 이렇게 방송 많이 하시는데 정말 아름다우시고 네 아름다우시고 굉장히 되게  영광이었죠 그래서 기분이 되게 좋았어요
#
# 어 어쩌다 여기까지 누추한 곳에
# ->  어 어쩌다 여기까지 누추한 곳에
#
# 그니까 누추한 곳에 (()) 어 네
# ->  그니까 누추한 곳에  어 네
#
# 까 정말 영상이 러블리하게 예뻐가지고 프랑스 대혁명 뭐 뭐야 (팔십칠 년)/(87년) 그것도 하시고 어 아주 진짜
# ->  까 정말 영상이 러블리하게 예뻐가지고 프랑스 대혁명 뭐 뭐야 팔십칠 년 그것도 하시고 어 아주 진짜
#
# 네
# ->  네
#
# 좋은 콘텐츠 많이 하시더라고요 너무
# ->  좋은 콘텐츠 많이 하시더라고요 너무
#
# 어 영광이네요 되게 게다가 그 하트를
# ->  어 영광이네요 되게 게다가 그 하트를
#
# 네네 색깔이 있는 하트
# ->  네네 색깔이 있는 하트
#
# 이거 이제 약간 커플들끼리 톡 할때가 많이 꽉찮 걸로 했다는 거는 저희 방송이 아마 만족스럽다는 거잖아요
# ->  이거 이제 약간 커플들끼리 톡 할때가 많이 꽉찮 걸로 했다는 거는 저희 방송이 아마 만족스럽다는 거잖아요
#
# 그렇죠 그렇죠 아 @이름4님 감사합니다 저희도 한번 가서 댓글 테러 한번 해드려야죠 좋은 테러를 해드려야죠
# ->  그렇죠 그렇죠 아 @이름4님 감사합니다 저희도 한번 가서 댓글 테러 한번 해드려야죠 좋은 테러를 해드려야죠
#
# 아 그쵸 그쵸 예
# ->  아 그쵸 그쵸 예
#
# 그래서 한번 댓글을 한번 저희도 한번 다뤄보겠습니다 자 마지막 댓글까지 왔는데요 누가 읽어 주실까요
# ->  그래서 한번 댓글을 한번 저희도 한번 다뤄보겠습니다 자 마지막 댓글까지 왔는데요 누가 읽어 주실까요
#
# 누 누구 차례죠
# ->  누 누구 차례죠
#
# 저는 읽었으니까요 (())
# ->  저는 읽었으니까요
#
# 자 마티 @전화번호2님 네 자 엄청 웃겨요 유익하고 재미있네요 계속 꾸준히 올려 주세요 라고 하셨나요
# ->  자 마티 @전화번호2님 네 자 엄청 웃겨요 유익하고 재미있네요 계속 꾸준히 올려 주세요 라고 하셨나요
#
# 저도 좋은 댓글이 올라왔네요
# ->  저도 좋은 댓글이 올라왔네요
#
# 네
# ->  네
#
# 암
# ->  암
#
# 아마 (이월)/(2월) (십칠 일)/(17일) 생이신 것 같아요 그죠
# ->  아마 이월 십칠 일 생이신 것 같아요 그죠
#
# 맞아요
# ->  맞아요
#
# 빠른 생일이시네요 그 유익하다는 말보다는 웃겨요 이게 또 더 기분이 좋더라고요
# ->  빠른 생일이시네요 그 유익하다는 말보다는 웃겨요 이게 또 더 기분이 좋더라고요
#
# 사실 제가 아는 그 동생 (이월)/(2월) (십칠 일)/(17일) 생 맞구요
# ->  사실 제가 아는 그 동생 이월 십칠 일 생 맞구요
#
# 네네네
# ->  네네네
#
# 그 이 동생이 되게 듣고 어 근데 되게 재미있다고 되게 칭찬을 많이 줘가지고 되게 저도 기분 되게 좋았어요 그래서
# ->  그 이 동생이 되게 듣고 어 근데 되게 재미있다고 되게 칭찬을 많이 줘가지고 되게 저도 기분 되게 좋았어요 그래서
#
# 사실은 저희가 이렇게 검토해 보면 느끼지만
# ->  사실은 저희가 이렇게 검토해 보면 느끼지만
#
# 네
# ->  네
#
# 이러니저러니 해도 저희 주변에 있는 사람들이 제일 소중하네요 이 (()) 여의치 않아 안 나와요 땅 파봐도
# ->  이러니저러니 해도 저희 주변에 있는 사람들이 제일 소중하네요 이  여의치 않아 안 나와요 땅 파봐도
#
# 그럼요 그럼요 (사만 원)/(4만 원) 더 필요합니다 네
# ->  그럼요 그럼요 사만 원 더 필요합니다 네
#
# 아 수많은 저희 지인분에도 너무 감사하고요 지인이 아니어도 이 방송을 이렇게 애정 있게 봐주시는 모든 분들 너무 감사합니다
# ->  아 수많은 저희 지인분에도 너무 감사하고요 지인이 아니어도 이 방송을 이렇게 애정 있게 봐주시는 모든 분들 너무 감사합니다
#
# 그럼요 감사합니다 제가 예
# ->  그럼요 감사합니다 제가 예
#
# 이 친구를 아는데 신촌에서 술 한잔 같이 했었거든요
# ->  이 친구를 아는데 신촌에서 술 한잔 같이 했었거든요
#
# 아 맞아요 맞아요 맞아요 맞아
# ->  아 맞아요 맞아요 맞아요 맞아
#
# 어 그래요
# ->  어 그래요
#
# @이름5도 같이 아마
# ->  @이름5도 같이 아마
#
# 저도 했어요
# ->  저도 했어요
#
# 삼겹살 같이 먹었잖아요
# ->  삼겹살 같이 먹었잖아요
#
# 아 언제지 아
# ->  아 언제지 아
#
# 그게 작년
# ->  그게 작년
#
# 재작년 됐을 거예요 재작년에
# ->  재작년 됐을 거예요 재작년에
#
# 아니야 작년이야
# ->  아니야 작년이야
#
# 아 그래요
# ->  아 그래요
#
# 작년에 작년에 작년에 분명히 여름 이후인데 가을이 되려는 약간
# ->  작년에 작년에 작년에 분명히 여름 이후인데 가을이 되려는 약간
#
# 아무튼 네 신촌에서 만나
# ->  아무튼 네 신촌에서 만나
#
# 춘천에서
# ->  춘천에서
#
# 네 그날 되게 재미있게
# ->  네 그날 되게 재미있게
#
# 통돼지 해서 먹었죠
# ->  통돼지 해서 먹었죠
#
# 군요
# ->  군요
#
# 맞아요
# ->  맞아요
#
# 통통 돼지 맛있어요 한번 가보세요
# ->  통통 돼지 맛있어요 한번 가보세요
#
# 신천 통통 돼지
# ->  신천 통통 돼지
#
# 네 맛있습니다
# ->  네 맛있습니다
#
# 이제 저희가 거의 댓글을 이제 다 읽었는데 댓글 쫙 읽어보니까 소감이 어때요 우리 윤형
# ->  이제 저희가 거의 댓글을 이제 다 읽었는데 댓글 쫙 읽어보니까 소감이 어때요 우리 윤형
#
# 저 근데 자꾸 장난으로 삼만 원만 땡겨주세요 했는데 정말 장난아니에요 신경쓰지 마시구요 약간 마음 걸려가지고
# ->  저 근데 자꾸 장난으로 삼만 원만 땡겨주세요 했는데 정말 장난아니에요 신경쓰지 마시구요 약간 마음 걸려가지고
#
# 돈 벌잖아요
# ->  돈 벌잖아요
#
# 네 이거 장난이고요 뭐 저 이거 거의 약간 자아 실현을 위해서 하는 거잖아요 그래서 뭐 돈 생각하고 하는 거 아니니까 그냥 오셔서 재미있게 같이 웃어 주셨으면 좋겠어요 그냥 그리고 뭔가 원하는 거
# ->  네 이거 장난이고요 뭐 저 이거 거의 약간 자아 실현을 위해서 하는 거잖아요 그래서 뭐 돈 생각하고 하는 거 아니니까 그냥 오셔서 재미있게 같이 웃어 주셨으면 좋겠어요 그냥 그리고 뭔가 원하는 거
#
# 있으시면 언제든지 댓글 달아 주시구요
# ->  있으시면 언제든지 댓글 달아 주시구요
#
# 네
# ->  네
#
# 그랬으면 좋겠습 어쨌든 저희 사실 암 그냥 평범한 직장 다니거나 백수인데 그런 평범한 사람들인데 이 방송하면서 되게
# ->  그랬으면 좋겠습 어쨌든 저희 사실 암 그냥 평범한 직장 다니거나 백수인데 그런 평범한 사람들인데 이 방송하면서 되게
#
# 수상소감인가요
# ->  수상소감인가요
#
# 어 근데 저는 약간 뭔가 풀 뭐야 분출구랄까
# ->  어 근데 저는 약간 뭔가 풀 뭐야 분출구랄까
#
# 네
# ->  네
#
# 네
# ->  네
#
# 그래서 저는 되게 굉장히 어 막상 갈 때는 귀찮은데 막상 이제 또 방송하면 너무 즐겁더라고요
# ->  그래서 저는 되게 굉장히 어 막상 갈 때는 귀찮은데 막상 이제 또 방송하면 너무 즐겁더라고요
#
# 휴지 어딨어 휴지 휴지
# ->  휴지 어딨어 휴지 휴지
#
# 휴지 눈물이 엄마 고맙고 감사합니다
# ->  휴지 눈물이 엄마 고맙고 감사합니다
#
# 우리 @이름5도 뭐 지금 삼 회차죠 오늘이
# ->  우리 @이름5도 뭐 지금 삼 회차죠 오늘이
#
# 예 그렇죠
# ->  예 그렇죠
#
# 어때요 댓글 좀 보니까
# ->  어때요 댓글 좀 보니까
#
# 댓글을 보니까 일단은 동기부여가 많이 되네요 그래도 모든 기록물이다 과 과거 역사와도 되지 않습니까
# ->  댓글을 보니까 일단은 동기부여가 많이 되네요 그래도 모든 기록물이다 과 과거 역사와도 되지 않습니까
#
# 똑똑해 역시
# ->  똑똑해 역시
#
# 앞으로 역사를 더 써야죠
# ->  앞으로 역사를 더 써야죠
#
# 음
# ->  음
#
# 구독자수 이백명 달성을 목표로 열심히 유익하고 재미있는 방송을 모토하겠습니다
# ->  구독자수 이백명 달성을 목표로 열심히 유익하고 재미있는 방송을 모토하겠습니다
#
# 네 아 감사해요 저도 한 말씀 드리자면
# ->  네 아 감사해요 저도 한 말씀 드리자면
#
# 네
# ->  네
#
# 저는 뭐 어디 다른 데 가서 댓글 잘 안 남기거든요
# ->  저는 뭐 어디 다른 데 가서 댓글 잘 안 남기거든요
#
# 아 아
# ->  아 아
#
# 이거 뭐 보겠어 하고 그냥 넘겼는데 제가 막상 댓글을 이렇게 받아 보니까 이렇게까지 힘 날 줄 몰랐어요
# ->  이거 뭐 보겠어 하고 그냥 넘겼는데 제가 막상 댓글을 이렇게 받아 보니까 이렇게까지 힘 날 줄 몰랐어요
#
# 그렇죠 그렇죠
# ->  그렇죠 그렇죠
#
# 정말 이렇게 힘이 되게 응원해주신 거 너무 감사하고 저도 다른 재미난 거 있으면 댓글도 많이 달고 하겠습니다
# ->  정말 이렇게 힘이 되게 응원해주신 거 너무 감사하고 저도 다른 재미난 거 있으면 댓글도 많이 달고 하겠습니다
#
# 그럼요
# ->  그럼요
#
# 맞습니다
# ->  맞습니다
#
# 댓글 품앗이 네
# ->  댓글 품앗이 네
#
# 네 아 너무 감사합니다
# ->  네 아 너무 감사합니다
#
# 감사합니다
# ->  감사합니다
#
# 여기까지 예
# ->  여기까지 예
#
# 꾸준히 들어오세요 네 우리 보편적으로 갑시다
# ->  꾸준히 들어오세요 네 우리 보편적으로 갑시다
#
# 네
# ->  네
#
# 네
# ->  네
#
# 고고씽
# ->  고고씽
#
# ----------------------------------------
# File: /mnt/a/maxseats/(주의-원본)주요 영역별 회의 음성인식 데이터/002.주요_영역별_회의_음성인식_데이터/01.데이터/unzipped_files/SRBAH21000005.json
#
# (십칠 일부터)/(17일부터) (티비에스가)/(TBS가) 서울특별시 미디어재단으로 공식 출범 했습니다 (천구백구십 년)/(1990년) 서울시 산하 사업소로 개옥한 이래 (삼십 년)/(30년) 만에 독립적인 서울시 출연기관이 된건데요. /(bgm)
# ->  십칠 일부터 티비에스가 서울특별시 미디어재단으로 공식 출범 했습니다 천구백구십 년 서울시 산하 사업소로 개옥한 이래 삼십 년 만에 독립적인 서울시 출연기관이 된건데요.
#
# 교통 기상정보 중심의 교통방송을 벗어나서 시민들에게 더 가까운 미디어로 거듭나기 위해서 시민의 눈으로 한걸음 더 라는 슬로건으로 새로운 모습을 저희가 보여 드리겠습니다. /(bgm)
# ->  교통 기상정보 중심의 교통방송을 벗어나서 시민들에게 더 가까운 미디어로 거듭나기 위해서 시민의 눈으로 한걸음 더 라는 슬로건으로 새로운 모습을 저희가 보여 드리겠습니다.
#
# 오늘 출범 한 곳이 하나 더 있습니다 바로 이 새로운 보수 통합을 내세운 @정당1인데요 자 그동안 보수통합에 대해서 국민들이 가졌던 /(bgm)
# ->  오늘 출범 한 곳이 하나 더 있습니다 바로 이 새로운 보수 통합을 내세운 @정당1인데요 자 그동안 보수통합에 대해서 국민들이 가졌던
#
# 그런 불신들을 모두 녹여 내고 총선의 승리를 위해서 정말 최선을 다하겠다는 각오를 밝혔습니다 정당도 그렇고요. /(bgm)
# ->  그런 불신들을 모두 녹여 내고 총선의 승리를 위해서 정말 최선을 다하겠다는 각오를 밝혔습니다 정당도 그렇고요.
#
# 저희 (티비에스도)/(TBS도) 국민들의 목소리에 더욱더 귀를 기울이면서 발전해 나가는 모습을 보여야 될 것 같습니다.
# ->  저희 티비에스도 국민들의 목소리에 더욱더 귀를 기울이면서 발전해 나가는 모습을 보여야 될 것 같습니다.
#
# 시민의 눈으로 한 걸음 더 지금부터 더 룸에서 사회 정치 관련 소식 자세하게 짚어보겠습니다 먼저 준비된 영상 함께 보시죠.
# ->  시민의 눈으로 한 걸음 더 지금부터 더 룸에서 사회 정치 관련 소식 자세하게 짚어보겠습니다 먼저 준비된 영상 함께 보시죠.
#
# (이천이십년 이월 십칠 일)/(2020년 2월 17일) 오전 (아홉시)/(9시) 현재 추가 확진 환자 (한 명을)/(1명을) 포함해 총 (삼십 명이)/(30명이) 확진되었습니다. /(bgm)
# ->  이천이십년 이월 십칠 일 오전 아홉시 현재 추가 확진 환자 한 명을 포함해 총 삼십 명이 확진되었습니다.
#
# (이천십구 년 십이월)/(2019년 12월) 이후 현재까지 외국을 방문한 적은 없었다고 진술하였으며 /(bgm)
# ->  이천십구 년 십이월 이후 현재까지 외국을 방문한 적은 없었다고 진술하였으며
#
# (코로나일구가)/(코로나19) 국내 지역 지역사회로 유입되는 것을 최대한 막아내고 이를 지연시키는 한편 지역사회로 전파되는 상황을 /(bgm)
# ->  코로나일구가 국내 지역 지역사회로 유입되는 것을 최대한 막아내고 이를 지연시키는 한편 지역사회로 전파되는 상황을
#
# 선제적으로 대비하여 유행의 규모와 여파를 줄이는 노력을 병행하는 것이 현 시점에서 적절한 방역 관리 대책의 주안점이 되어야 한다라고 생각합니다. /(bgm)
# ->  선제적으로 대비하여 유행의 규모와 여파를 줄이는 노력을 병행하는 것이 현 시점에서 적절한 방역 관리 대책의 주안점이 되어야 한다라고 생각합니다.
#
# 음성으로 확인된 우리 국민 승객 중 귀국 희망자가 있다면 국내 이송 방안을 추진하기로 하였습니다. /(bgm)
# ->  음성으로 확인된 우리 국민 승객 중 귀국 희망자가 있다면 국내 이송 방안을 추진하기로 하였습니다.
#
# 지금 국내에서 가장 주요한 이슈들입니다 (코로나일구와)/(코로나19와) 총선 관련 정치권 이야기 지금부터 더 룸에서 하나하나 짚어보겠습니다.
# ->  지금 국내에서 가장 주요한 이슈들입니다 코로나일구와 총선 관련 정치권 이야기 지금부터 더 룸에서 하나하나 짚어보겠습니다.
#
# 네 함께 이야기를 나눠주실 (두 분)/(2분) 선생님 모셨습니다 안녕하세요?
# ->  네 함께 이야기를 나눠주실 두 분 선생님 모셨습니다 안녕하세요?
#
# 안녕하세요?
# ->  안녕하세요?
#
# 네 먼저 저희 (코로나일구)/(코로나19) 얘기부터 좀 해보도록 하겠습니다 자 오늘을 기준으로해서 중앙방역대책본부에 따르면요 국내 (코로나일구)/(코로나19) 확진자는
# ->  네 먼저 저희 코로나일구 얘기부터 좀 해보도록 하겠습니다 자 오늘을 기준으로해서 중앙방역대책본부에 따르면요 국내 코로나일구 확진자는
#
# 총 (서른 명이고요)/(30명이고요) 완치로 격리 해제된 분들도 (열 명입니다)/(10명입니다) 자 그런데요 자 지금 정부와 전문가들이 예의주시하는 환자가 있습니다.
# ->  총 서른 명이고요 완치로 격리 해제된 분들도 열 명입니다 자 그런데요 자 지금 정부와 전문가들이 예의주시하는 환자가 있습니다.
#
# 바로 (이십구 번)/(29번) 그리고 (삼십 번)/(30번) 환자인데요 자 이분들은 (두 명)/(2명) 부부인데 해외를 다녀온 적이 (한 번도)/(1번도) 없는 걸로 지금 밝혀지고 있어요.
# ->  바로 이십구 번 그리고 삼십 번 환자인데요 자 이분들은 두 명 부부인데 해외를 다녀온 적이 한 번도 없는 걸로 지금 밝혀지고 있어요.
#
# 네 이분들이 해외여행이력이 없고요 (코로나일구)/(코로나19) 환자들과 접촉한 적도 없는 걸로 지금 얘기가 되고 있기 때문에 감염 경로가 어떻게 되는지 좀 궁금해 하고 있고
# ->  네 이분들이 해외여행이력이 없고요 코로나일구 환자들과 접촉한 적도 없는 걸로 지금 얘기가 되고 있기 때문에 감염 경로가 어떻게 되는지 좀 궁금해 하고 있고
#
# 특히 중요한게 지역사회로 감염이 확산되는 것 아닙니까 이런 얘기 아닙니까 이거 어떻게 봐야 될까요?
# ->  특히 중요한게 지역사회로 감염이 확산되는 것 아닙니까 이런 얘기 아닙니까 이거 어떻게 봐야 될까요?
#
# 환자까지 나왔을 때는 그래도 이게 (삼 차)/(3차) 감염까지도 있었어요 (삼 번)/(3번) 환자가 (육 번)/(6번) 환자에게 (육 번)/(6번) 환자가 가족 (십 번)/(10번) (십일 번)/(11번) 환자에게 이런 식의 이제 확산 많이 있었는데
# ->  환자까지 나왔을 때는 그래도 이게 삼 차 감염까지도 있었어요 삼 번 환자가 육 번 환자에게 육 번 환자가 가족 십 번 십일 번 환자에게 이런 식의 이제 확산 많이 있었는데
#
# 어쨌든 우한을 다녀온 혹은 태국 싱가폴 일본을 다녀온 이 여행력을 기점으로 해서 접촉의 관계망들이 관리 범위 내에 있었다는 거예요.
# ->  어쨌든 우한을 다녀온 혹은 태국 싱가폴 일본을 다녀온 이 여행력을 기점으로 해서 접촉의 관계망들이 관리 범위 내에 있었다는 거예요.
#
# 근데 (이십구 번)/(29번) 환자는 사실은 전혀 관리 대상이 아니었고 엉뚱한 지역에서 팔십대 초반의 어르신 인데 흉통 가슴에 통증이 있어서 동네 병원 갔더니 아 /(bgm)
# ->  근데 이십구 번 환자는 사실은 전혀 관리 대상이 아니었고 엉뚱한 지역에서 팔십대 초반의 어르신 인데 흉통 가슴에 통증이 있어서 동네 병원 갔더니 아
#
# 기저 질환으로 심장질환이 있으시군요 큰 병원 가보세요 고대 안암병원에 갔는데 메르스를 경험했던 의사가 아주 어렴풋한 폐렴 소견을 보고 일단 즉시 격리 /(bgm)
# ->  기저 질환으로 심장질환이 있으시군요 큰 병원 가보세요 고대 안암병원에 갔는데 메르스를 경험했던 의사가 아주 어렴풋한 폐렴 소견을 보고 일단 즉시 격리
#
# 검사 확진 근데 이게 빠르게 이루어졌으니 망정이지 돌아가셨으면 더 큰일 날 뻔 했습니다만 어쨌든 아무런 경로가 역학적으로 확인되지 않고 있고
# ->  검사 확진 근데 이게 빠르게 이루어졌으니 망정이지 돌아가셨으면 더 큰일 날 뻔 했습니다만 어쨌든 아무런 경로가 역학적으로 확인되지 않고 있고
#
# (삼십 번)/(30번) 확진자는 부인이기 때문에 부부 간에 누가 먼저 감염돼서 전염을 시켰는지 알 수 없으나 어쨌든 이 경로가 지금 오리무중이라
# ->  삼십 번 확진자는 부인이기 때문에 부부 간에 누가 먼저 감염돼서 전염을 시켰는지 알 수 없으나 어쨌든 이 경로가 지금 오리무중이라
#
# 말씀하신 대로 지역사회 방역망이 뚫린 것 아닌가 우려가 커지고 있습니다.
# ->  말씀하신 대로 지역사회 방역망이 뚫린 것 아닌가 우려가 커지고 있습니다.
#
# 음 지금 사실은 아직은 우려예요 지역감염이라는 확증이 나오지 않은 상태이고 아직은 감염 경로라든지 누구로부터 옮았다 감염됐다라는 게 안 나왔기 때문에 지역 감염이 아니겠냐 우려
# ->  음 지금 사실은 아직은 우려예요 지역감염이라는 확증이 나오지 않은 상태이고 아직은 감염 경로라든지 누구로부터 옮았다 감염됐다라는 게 안 나왔기 때문에 지역 감염이 아니겠냐 우려
#
# 우려를 가지고 대응하는 건 아주 좋은 방법이기는 합니다만 아직 확정된게 아니기 때문에 너무 또 그럴 일은 아닌 것 같고 일단은 (이십구 번)/(29번) (삼십 번)/(30번) 순서대로 이십구 삼십를 붙였습니다만
# ->  우려를 가지고 대응하는 건 아주 좋은 방법이기는 합니다만 아직 확정된게 아니기 때문에 너무 또 그럴 일은 아닌 것 같고 일단은 이십구 번 삼십 번 순서대로 이십구 삼십를 붙였습니다만
#
# 그게 누가 누구에 감염시켰느냐가 반대가 될 수도 있는 잠복기나 사람의 컨디션 때문에 있기 때문에 사실은 아직은 어~ 확신은 그렇습니다만 일단은 다행인건 그나마 다행인건
# ->  그게 누가 누구에 감염시켰느냐가 반대가 될 수도 있는 잠복기나 사람의 컨디션 때문에 있기 때문에 사실은 아직은 어~ 확신은 그렇습니다만 일단은 다행인건 그나마 다행인건
#
# (이십구 번)/(29번) 확진자가 나오고 (삼십 번)/(30번) 확진자는 그러니까 검사를 했더니 양성이 나온 거잖아요 아무런 증상이 없었음에도 불구하고 그리고 제가 지금 그나마 다행이라고 했던거는 아~
# ->  이십구 번 확진자가 나오고 삼십 번 확진자는 그러니까 검사를 했더니 양성이 나온 거잖아요 아무런 증상이 없었음에도 불구하고 그리고 제가 지금 그나마 다행이라고 했던거는 아~
#
# 이렇게 확진자인지 모르고 이 동네 저 동네 병원을 갔다라는 것에 또 걱정이 많으신데 다행히도 이동 경로가 그렇게 많지 않다고 합니다 다른분들처럼 연세도 있고 아무래도 그러다보니까 그런지
# ->  이렇게 확진자인지 모르고 이 동네 저 동네 병원을 갔다라는 것에 또 걱정이 많으신데 다행히도 이동 경로가 그렇게 많지 않다고 합니다 다른분들처럼 연세도 있고 아무래도 그러다보니까 그런지
#
# 그래서 이런 부분에 대해서도 일단 지금은 저는 아침부터 너무 이제 이 뉴스가 많이 나와서 저도 열심히 뉴스를 봤는데 확신 할 수 있는 게 없어요 대응은 철저히 해야겠지만 우리가 미리 걱정할 필요는 아직은 좀 없어 보인다 이런 생각도 좀 듭니다.
# ->  그래서 이런 부분에 대해서도 일단 지금은 저는 아침부터 너무 이제 이 뉴스가 많이 나와서 저도 열심히 뉴스를 봤는데 확신 할 수 있는 게 없어요 대응은 철저히 해야겠지만 우리가 미리 걱정할 필요는 아직은 좀 없어 보인다 이런 생각도 좀 듭니다.
#
# 맞습니다 자 일본에 정박 중인 크루즈선 다이아몬드프린세스호 계속 (코로나일구)/(코로나19) 확진자가 발생하고 있는데요 지금까지 상황을 한번 살펴보죠 자 지금 확진자가 계속 늘어나고 있어요.
# ->  맞습니다 자 일본에 정박 중인 크루즈선 다이아몬드프린세스호 계속 코로나일구 확진자가 발생하고 있는데요 지금까지 상황을 한번 살펴보죠 자 지금 확진자가 계속 늘어나고 있어요.
#
# 지금
# ->  지금
#
# 일단은 뭐 지금 쭉 보시면요 (십육 일까지)/(16일까지) 총 (삼백오십오 명으로)/(355명으로) 좀 나타나고 있는 거죠?
# ->  일단은 뭐 지금 쭉 보시면요 십육 일까지 총 삼백오십오 명으로 좀 나타나고 있는 거죠?
#
# 네 상당히 좀 많이 급증하는 영상인데요.
# ->  네 상당히 좀 많이 급증하는 영상인데요.
#
# 여기서 오늘만 (구십구 명이)/(99명이) 증가 됐습니다 지금 현재 (사백오십사 명으로)/(454명으로) (백 명)/(100명) 가까이 늘었습니다.
# ->  여기서 오늘만 구십구 명이 증가 됐습니다 지금 현재 사백오십사 명으로 백 명 가까이 늘었습니다.
#
# 내용을 좀 보니까 좀 더 심각하다라는 게 느껴지는 것 같아요.
# ->  내용을 좀 보니까 좀 더 심각하다라는 게 느껴지는 것 같아요.
#
# 지금 결국 우리 국적의 (열네 명이)/(14명이) 탑승을 하고 있습니다 다행히 정부가 이분들을 이송하겠다 이렇게 밝혔죠?
# ->  지금 결국 우리 국적의 열네 명이 탑승을 하고 있습니다 다행히 정부가 이분들을 이송하겠다 이렇게 밝혔죠?
#
# 그렇습니다 그 내용을 또 잠깐 보면요 일단은 (삼백쉰다섯 명이)/(355명이) 감염돼 일본 공포의 크루즈 어제 일자 신문이거든요 정부가 이제 한국인을 데려오겠다라는 내용의 기사입니다. /(bgm)
# ->  그렇습니다 그 내용을 또 잠깐 보면요 일단은 삼백쉰다섯 명이 감염돼 일본 공포의 크루즈 어제 일자 신문이거든요 정부가 이제 한국인을 데려오겠다라는 내용의 기사입니다.
#
# 그래서 크루즈 내에는 (열네 명의)/(14명의) 한국 국적자가 타고 있구요 어 (십구 일이라고)/(19일이라고) 일본에서는 밝혔지만 정부에서는 (십구일 전이라도)/(19일전이라도) 일본 당국 조사에서 음성으로 확인된 한국인이 귀국을 희망한다라고 하면 /(bgm)
# ->  그래서 크루즈 내에는 열네 명의 한국 국적자가 타고 있구요 어 십구 일이라고 일본에서는 밝혔지만 정부에서는 십구일 전이라도 일본 당국 조사에서 음성으로 확인된 한국인이 귀국을 희망한다라고 하면
#
# 데려오기로 했다라고 해서 한국인 승객의 의사를 먼저 파악을 하고요 일본 정부와 협의를 추진하겠다라는 내용의 기사 입니다 자 보신 것처럼 앞서 이제 일본 정부는 음성 판정자 같은 경우에는 /(bgm)
# ->  데려오기로 했다라고 해서 한국인 승객의 의사를 먼저 파악을 하고요 일본 정부와 협의를 추진하겠다라는 내용의 기사 입니다 자 보신 것처럼 앞서 이제 일본 정부는 음성 판정자 같은 경우에는
#
# (이월 십구 일에)/(2월 19일에) 희망한다면 배에서 내릴 수 있다라는 방침을 밝혔고요 그래서 이제 우리국민 승객 중에 희망자가 있다면 이송을 하겠다라는 건데 자 정부의 이런 결정 두 분은 어떻게 보셨는지 궁금합니다.
# ->  이월 십구 일에 희망한다면 배에서 내릴 수 있다라는 방침을 밝혔고요 그래서 이제 우리국민 승객 중에 희망자가 있다면 이송을 하겠다라는 건데 자 정부의 이런 결정 두 분은 어떻게 보셨는지 궁금합니다.
#
# 훌륭하다고 봅니다 아주 훌륭하다고 보고 당연히 해야 될 일인데 미국은 이미 (삼 백여 명의)/(300여명의) 자국민들을 데리고 갔는데 (삼백여 명)/(300여명) 중 (열네 명이)/(14명이) 확진으로 지금 나왔어요.
# ->  훌륭하다고 봅니다 아주 훌륭하다고 보고 당연히 해야 될 일인데 미국은 이미 삼 백여 명의 자국민들을 데리고 갔는데 삼백여 명 중 열네 명이 확진으로 지금 나왔어요.
#
# 미국으로 이제 이송된 원래 확진자는 일본에 내려놓고 지금 (사십여 명은)/(40여명은) 일본에서 치료중이거든요 근데 지금 캐나다 홍콩 대만 모두 자국민 데려오겠다.
# ->  미국으로 이제 이송된 원래 확진자는 일본에 내려놓고 지금 사십여 명은 일본에서 치료중이거든요 근데 지금 캐나다 홍콩 대만 모두 자국민 데려오겠다.
#
# 공포의 크루즈가 돼 있지 않습니까 근데 문제는 우리 정부가 타진을 다 했어요 (열네 명)/(14명) 중에 국내거주자 (다섯 명)/(5명) (아홉 명은)/(9명은) 승객 (다섯 명은)/(5명은) 승무원이거든요.
# ->  공포의 크루즈가 돼 있지 않습니까 근데 문제는 우리 정부가 타진을 다 했어요 열네 명 중에 국내거주자 다섯 명 아홉 명은 승객 다섯 명은 승무원이거든요.
#
# 그런데 승객 (아홉 명)/(9명) 중에 (한 명만)/(1명만) 국내 거주자고 (여덟 분은)/(8분은) 재일교포 교민이세요 그리고 승무원도 (두 명만)/(2명만) 국내거주자예요.
# ->  그런데 승객 아홉 명 중에 한 명만 국내 거주자고 여덟 분은 재일교포 교민이세요 그리고 승무원도 두 명만 국내거주자예요.
#
# (세 명)/(3명) 중에 (두 명이)/(2명이) 귀환을 귀국을 희망하고 있습니다 자 그러면 (십구 일)/(19일) 이후 내일모레인데요 일본 정부가 검사에서 음성이면 돌아가도 좋다하면
# ->  세 명 중에 두 명이 귀환을 귀국을 희망하고 있습니다 자 그러면 십구 일 이후 내일모레인데요 일본 정부가 검사에서 음성이면 돌아가도 좋다하면
#
# 이 (두 명을)/(2명을) 위해서 전세기는 좀 무리하고 뭐 (이백 인승)/(200인승) (사백 인승)/(400인승) 그래서 공군기를 보낼 예정이었는데 숫자가 너무 적어요.
# ->  이 두 명을 위해서 전세기는 좀 무리하고 뭐 이백 인승 사백 인승 그래서 공군기를 보낼 예정이었는데 숫자가 너무 적어요.
#
# 그래서 한일간을 오가는 선박 페리 선에 격리실을 마련해서 돌아올 것까지 지금 계획은 다 서 있고 아마 검토 후에 실행하게 될 것 같습니다.
# ->  그래서 한일간을 오가는 선박 페리 선에 격리실을 마련해서 돌아올 것까지 지금 계획은 다 서 있고 아마 검토 후에 실행하게 될 것 같습니다.
#
# 네 정부가 이 일본 수출 제재에 이어서 (코로나일구)/(코로나19) 까지 계속되는 악재 때문에 사실 경영난을 겪고 있는 이 중소기업들이 많지 않습니까?
# ->  네 정부가 이 일본 수출 제재에 이어서 코로나일구 까지 계속되는 악재 때문에 사실 경영난을 겪고 있는 이 중소기업들이 많지 않습니까?
#
# 그래서 (사천이백 억 원)/(4200억원) 규모의 긴급경영자금을 지원하기로 했다 이런 소식도 있더라고요?
# ->  그래서 사천이백 억 원 규모의 긴급경영자금을 지원하기로 했다 이런 소식도 있더라고요?
#
# (사천이백 억 )/(4200억) 플러스 알파 일단은 우리 이번에 뭐 가장 큰 타격을 입은 건 누가 뭐래도 항공 업계일껍니다 제주도 항공권 (삼천 원짜리)/(30000원짜리) 이렇게 기사가 될 정도면 /(bgm)
# ->  사천이백 억  플러스 알파 일단은 우리 이번에 뭐 가장 큰 타격을 입은 건 누가 뭐래도 항공 업계일껍니다 제주도 항공권 삼천 원짜리 이렇게 기사가 될 정도면
#
# 지금 아무도 비행기를 사실 거의 안 탄다라는 거잖아요 그러다 보니까 비행기 몇 명 탄 비행기를 띄우거나 아니면 운행을 중단하거나 이런 여객선들도 지금 나오고 있는 상황이다 보니까 일단은 /(bgm)
# ->  지금 아무도 비행기를 사실 거의 안 탄다라는 거잖아요 그러다 보니까 비행기 몇 명 탄 비행기를 띄우거나 아니면 운행을 중단하거나 이런 여객선들도 지금 나오고 있는 상황이다 보니까 일단은
#
# 아까 (사천이백 억 )/(4200억) 제가 플러스알파라고 말씀드렸는데 저비용 항공사 (엘씨씨라고)/(LCC라고) 하는 항공사들은 일단 (삼천 억)/(3천억) 범위 내에서 긴급 융자 프로그램 지원하겠다라는 발표가 있었고 /(bgm)
# ->  아까 사천이백 억  제가 플러스알파라고 말씀드렸는데 저비용 항공사 엘씨씨라고 하는 항공사들은 일단 삼천 억 범위 내에서 긴급 융자 프로그램 지원하겠다라는 발표가 있었고
#
# 융자 입니다 그냥 뭐 주겠다 이런 것들이 아니죠 그리고 해운업도 역시 마찬가지 (육백 억)/(600억) 정도 그리고 나머지는 관광업에 한 (오백 억)/(500억) 정도가 투입될 예정이고
# ->  융자 입니다 그냥 뭐 주겠다 이런 것들이 아니죠 그리고 해운업도 역시 마찬가지 육백 억 정도 그리고 나머지는 관광업에 한 오백 억 정도가 투입될 예정이고
#
# 마지막으로 외식사업 식당도 사실은 또 감염될까봐 못가시는 분들 많았었거든요 뭐 지금은 좀 완화됐습니다만 여기다 (백 억)/(100억) 정도를 즉 자금을 지원을 해서
# ->  마지막으로 외식사업 식당도 사실은 또 감염될까봐 못가시는 분들 많았었거든요 뭐 지금은 좀 완화됐습니다만 여기다 백 억 정도를 즉 자금을 지원을 해서
#
# 아주 저렴한 금리로 대출을 해주거나 혹은 항공이나 운송 같은 경우에는 뭐 면제해주는 이용료라든지 뭐 공항에 관련된 이런 시설료 같은 거는 면제를 해주는 여러가지 지원책을
# ->  아주 저렴한 금리로 대출을 해주거나 혹은 항공이나 운송 같은 경우에는 뭐 면제해주는 이용료라든지 뭐 공항에 관련된 이런 시설료 같은 거는 면제를 해주는 여러가지 지원책을
#
# 내고는 있습니다만 저는 지금 이거 보면서 일단 대응은 좀 빠르지만 그나마 다행인게 날이 따뜻해지면은 이런 바이러스 같은 것들은 확산이 굉장히 준다고 그러잖아요 많은 전문가들이
# ->  내고는 있습니다만 저는 지금 이거 보면서 일단 대응은 좀 빠르지만 그나마 다행인게 날이 따뜻해지면은 이런 바이러스 같은 것들은 확산이 굉장히 준다고 그러잖아요 많은 전문가들이
#
# 그리고 실제로 우리는 우리나라에서 확진자나 감염자 이런 수가 점점 확산세가 줄어들고 있는 분위기기 때문에 아 이 정도로 잘 그러니까 개선이 돼서 너무 위축되어 있는것도 지금 풀리는 분위기잖아요?
# ->  그리고 실제로 우리는 우리나라에서 확진자나 감염자 이런 수가 점점 확산세가 줄어들고 있는 분위기기 때문에 아 이 정도로 잘 그러니까 개선이 돼서 너무 위축되어 있는것도 지금 풀리는 분위기잖아요?
#
# 자금까지 지원이 좀 된다면 아~ 이 분위기를 좀 잘 타서 지역경제라든지 뭐 여러 가지 어려움에 처한 산업들이 좀 활성이 잘 되는 계기가 됐으면 하는 생각이 들었습니다.
# ->  자금까지 지원이 좀 된다면 아~ 이 분위기를 좀 잘 타서 지역경제라든지 뭐 여러 가지 어려움에 처한 산업들이 좀 활성이 잘 되는 계기가 됐으면 하는 생각이 들었습니다.
#
# 일단은 뭐 우리 시청자분들 또 코로나가 지금 더 심각해지면 안 되는데 걱정입니다라는 의견 그리고 이십구 번 삼십 번 환자에 대해서도 해외여행력이 없던데 왜 그런걸까요.
# ->  일단은 뭐 우리 시청자분들 또 코로나가 지금 더 심각해지면 안 되는데 걱정입니다라는 의견 그리고 이십구 번 삼십 번 환자에 대해서도 해외여행력이 없던데 왜 그런걸까요.
#
# 저분들의 동선 어디에 카드 사용 내역 내용만으로는 확인이 불가능한 걸까요 이런 걱정이 댓글을 올려주고 계시는데 일단은 또 그중에서
# ->  저분들의 동선 어디에 카드 사용 내역 내용만으로는 확인이 불가능한 걸까요 이런 걱정이 댓글을 올려주고 계시는데 일단은 또 그중에서
#
# 우리나라는 그래도 대처를 굉장히 잘하는 거 같아요라고 의견을 주시는 분들도 많거든요.
# ->  우리나라는 그래도 대처를 굉장히 잘하는 거 같아요라고 의견을 주시는 분들도 많거든요.
#
# (())
# ->
#
# 비어 있습니다~
# 그렇습니다 외신에서 호평을 하고 있거든요 일단 화면을 좀 보시면서 어
# ->  그렇습니다 외신에서 호평을 하고 있거든요 일단 화면을 좀 보시면서 어
#
# 월 스트리트 저널입니다 중국 등 다른 아시아 국가들도 동선 추적을 하고 있기는 하지만 한국의 (코로나일구)/(코로나19) 대응 전략이 대중에 공개하는 정보가 세부적이라는 측면에서
# ->  월 스트리트 저널입니다 중국 등 다른 아시아 국가들도 동선 추적을 하고 있기는 하지만 한국의 코로나일구 대응 전략이 대중에 공개하는 정보가 세부적이라는 측면에서
#
# 돋보인다라고 이렇게 극찬을 했고요.
# ->  돋보인다라고 이렇게 극찬을 했고요.
#
# 그리고 영국의 데일리메일 같은 경우에도 한국 정부의 광범위한 감시체계는 정보의 구체성과 그 정보가 온라인을 통해서 즉각 대중과 공유된다는 점이
# ->  그리고 영국의 데일리메일 같은 경우에도 한국 정부의 광범위한 감시체계는 정보의 구체성과 그 정보가 온라인을 통해서 즉각 대중과 공유된다는 점이
#
# 이웃국가들과는 차원이 다르다 이렇게 얘기를 하고 있습니다 그러니까는 미국 월스트리트 저널 그리고 영국 데일리메일이 웹 사이트를 통해서 한국의 보건복지부가 모든 것들을
# ->  이웃국가들과는 차원이 다르다 이렇게 얘기를 하고 있습니다 그러니까는 미국 월스트리트 저널 그리고 영국 데일리메일이 웹 사이트를 통해서 한국의 보건복지부가 모든 것들을
#
# 이제 면밀하게 추적한 뒤에 온라인에 공개를 하고 이런 부분들을 굉장히 높게 평가를 하고 있거든요 우리 (두 분은)/(2분은) 좀 어떻게 보시는지 궁금합니다.
# ->  이제 면밀하게 추적한 뒤에 온라인에 공개를 하고 이런 부분들을 굉장히 높게 평가를 하고 있거든요 우리 두 분은 좀 어떻게 보시는지 궁금합니다.
#
# 공개되는 나라가 바이러스를 빨리 퇴치한다고 해요 지금 중국은 정보 통제 중이죠 심각하고 일본만 해도 우리보다 선진국인 줄 알았어요.
# ->  공개되는 나라가 바이러스를 빨리 퇴치한다고 해요 지금 중국은 정보 통제 중이죠 심각하고 일본만 해도 우리보다 선진국인 줄 알았어요.
#
# 재난대응 선진국인줄 알았는데 @이름1 정부가 크루즈를 통제하기 시작하면서 문제가 커지고 있습니다 그래서 우리가 정보공개에서는
# ->  재난대응 선진국인줄 알았는데 @이름1 정부가 크루즈를 통제하기 시작하면서 문제가 커지고 있습니다 그래서 우리가 정보공개에서는
#
# 중국과 일본 이웃 나라보다 훨씬 앞서 있다는 게 확인된 것 같습니다.
# ->  중국과 일본 이웃 나라보다 훨씬 앞서 있다는 게 확인된 것 같습니다.
#
# 네 이번엔 본격적인 정치권 이야기 들어보겠습니다 먼저 준비된 영상보고 가겠습니다 정치권 키워드 (세 개가)/(3개가) 나왔습니다 자 먼저 칼럼 논란에 대해서 얘기를 해볼까요?
# ->  네 이번엔 본격적인 정치권 이야기 들어보겠습니다 먼저 준비된 영상보고 가겠습니다 정치권 키워드 세 개가 나왔습니다 자 먼저 칼럼 논란에 대해서 얘기를 해볼까요?
#
# 네 일단 (일월 이십팔 일이었죠)/(1월 28일이었죠) 어~ 경향신문의 한 칼럼이 실렸습니다 @정당2만 빼고라는 제목의 칼럼이었는데 @이름2 고려대학교 연구 교수가 작성한
# ->  네 일단 일월 이십팔 일이었죠 어~ 경향신문의 한 칼럼이 실렸습니다 @정당2만 빼고라는 제목의 칼럼이었는데 @이름2 고려대학교 연구 교수가 작성한
#
# 이 칼럼 내용을 한번 좀 살펴보시면요 지금 잘 보이지는 않지만 일단 @정당2만 빼고라는 제목이 크게 보이구요 내용 중에 이런 말이 있습니다.
# ->  이 칼럼 내용을 한번 좀 살펴보시면요 지금 잘 보이지는 않지만 일단 @정당2만 빼고라는 제목이 크게 보이구요 내용 중에 이런 말이 있습니다.
#
# 촛불정권을 자임하면서도 국민의 열망보다 정권의 이해에 골몰하고 있다 @정당2만 빼고 투표를 하자라고 제안을 했는데 이 부분이 논란이 됐습니다.
# ->  촛불정권을 자임하면서도 국민의 열망보다 정권의 이해에 골몰하고 있다 @정당2만 빼고 투표를 하자라고 제안을 했는데 이 부분이 논란이 됐습니다.
#
# 이 칼럼을 보면 사실 @정당2의 입장에서는 굉장히 불쾌할 수 있겠다 이런 생각이 드는데 어떻습니까 (())?
# ->  이 칼럼을 보면 사실 @정당2의 입장에서는 굉장히 불쾌할 수 있겠다 이런 생각이 드는데 어떻습니까 ?
#
# 이게 정치적인 얘기라 민감한 것 같아요 만일 광고카피였으면 이거 대박난 광고카피예요 이게 여러가지로 @정당2에게 좋은 쪽으로 해석될 수 있는 왜냐하면
# ->  이게 정치적인 얘기라 민감한 것 같아요 만일 광고카피였으면 이거 대박난 광고카피예요 이게 여러가지로 @정당2에게 좋은 쪽으로 해석될 수 있는 왜냐하면
#
# 이런 제목이 되게 우리 표현대로 광고계에서 섹시하다라는 표현을 많이 쓰잖아요 많은 사람들이 집중을 해서 보면 찬성하는 분들은 더 찬성을 할 수도 있고 반대하는 분들은 더 와 반대할 수도 있는 이런 내용인데 문제는
# ->  이런 제목이 되게 우리 표현대로 광고계에서 섹시하다라는 표현을 많이 쓰잖아요 많은 사람들이 집중을 해서 보면 찬성하는 분들은 더 찬성을 할 수도 있고 반대하는 분들은 더 와 반대할 수도 있는 이런 내용인데 문제는
#
# 선거를 얼마 안두고 있었다라는 것 그럼에도 불구하고 저는 여당 내에서도 대표적으로 @이름3 전 총리도 그렇고 고소 고발은 좀 이거는 잘못됐다라는 이걸 내놓은 만큼
# ->  선거를 얼마 안두고 있었다라는 것 그럼에도 불구하고 저는 여당 내에서도 대표적으로 @이름3 전 총리도 그렇고 고소 고발은 좀 이거는 잘못됐다라는 이걸 내놓은 만큼
#
# 전 약간 @정당2이 좀 조급했다라는 생각은 들어요 왜냐하면 @정당2 입장에서는 뭐 이해는 돼요 이 사람이 그 일반 국민이 아니라 그냥 평론가가 아니라 뭐 @이름4 측근에서 일도 했었고 등등등 으로
# ->  전 약간 @정당2이 좀 조급했다라는 생각은 들어요 왜냐하면 @정당2 입장에서는 뭐 이해는 돼요 이 사람이 그 일반 국민이 아니라 그냥 평론가가 아니라 뭐 @이름4 측근에서 일도 했었고 등등등 으로
#
# 순수한 평론가가 아니다라는 이런 생각 때문에 아마도 부정적인 의도가 있는거다라고 해석을 했을 수는 있겠습니다만 일반 국민들이 그렇게 많이 알지도 못 했거든요 심지어는 이 칼럼
# ->  순수한 평론가가 아니다라는 이런 생각 때문에 아마도 부정적인 의도가 있는거다라고 해석을 했을 수는 있겠습니다만 일반 국민들이 그렇게 많이 알지도 못 했거든요 심지어는 이 칼럼
#
# 다들 아시겠지만 안 읽은 사람이 더 많았는데 이것 때문에 다 찾아서 검색해서 젊은층들까지 볼 정도가 됐어요 그래서 오히려 @정당2이 조금 조금
# ->  다들 아시겠지만 안 읽은 사람이 더 많았는데 이것 때문에 다 찾아서 검색해서 젊은층들까지 볼 정도가 됐어요 그래서 오히려 @정당2이 조금 조금
#
# 조급해서 악수를 두게 됐다 물론 지금 빠르게 수습은 하고 있습니다만 고소 고발 자체는 적절하지는 않았다 생각합니다.
# ->  조급해서 악수를 두게 됐다 물론 지금 빠르게 수습은 하고 있습니다만 고소 고발 자체는 적절하지는 않았다 생각합니다.
#
# 그리고 언론중재위원회 산하에 있는 선거기사 심의위원회에서 이 @이름2 교수의 칼럼이 선거법상 공정보도를 위반했다 공정보도 의무를 위반했다는 유권 해석을 내렸는데
# ->  그리고 언론중재위원회 산하에 있는 선거기사 심의위원회에서 이 @이름2 교수의 칼럼이 선거법상 공정보도를 위반했다 공정보도 의무를 위반했다는 유권 해석을 내렸는데
#
# 그렇다면 최 평론가님 보시기에 이런 해석 어떻게 보십니까?
# ->  그렇다면 최 평론가님 보시기에 이런 해석 어떻게 보십니까?
#
# 저는 맞다고 봐요 아까 @이름5 교수님이 말씀하신 게 단순화하면 그 순서가 맞지만 이 칼럼을 야권에서 좋아라 하면서 널리 회자시키기 시작했고
# ->  저는 맞다고 봐요 아까 @이름5 교수님이 말씀하신 게 단순화하면 그 순서가 맞지만 이 칼럼을 야권에서 좋아라 하면서 널리 회자시키기 시작했고
#
# 거기에 @정당2이 놀라서 고발하게 된 거예요 @정당2이 이거 보고 고발해서 회자된 게 아니고 사실은 야권에서 이 칼럼을 이용하기 시작했죠.
# ->  거기에 @정당2이 놀라서 고발하게 된 거예요 @정당2이 이거 보고 고발해서 회자된 게 아니고 사실은 야권에서 이 칼럼을 이용하기 시작했죠.
#
# 봐라 정부가 얼마나 못하면 진보 성향 신문에 진보 성향 교수가 이걸 냈느냐 그런데 @이름2 교수의 프로필을 나중에 자기가 다 오픈 했습니다만 경력을 보니까
# ->  봐라 정부가 얼마나 못하면 진보 성향 신문에 진보 성향 교수가 이걸 냈느냐 그런데 @이름2 교수의 프로필을 나중에 자기가 다 오픈 했습니다만 경력을 보니까
#
# @정당3에서 이제 선거에 입후보한 경력도 있고 조금 이제 진보 성향으로만 보기에는 묘한 대목들이 많아요 그런 걸 가지고 갑론을박이 더 디테일하게 벌어진 건데
# ->  @정당3에서 이제 선거에 입후보한 경력도 있고 조금 이제 진보 성향으로만 보기에는 묘한 대목들이 많아요 그런 걸 가지고 갑론을박이 더 디테일하게 벌어진 건데
#
# 저는 이 내용은 동의하지 못하고 유권 해석이 맞다면 저도 이런 얘기하고 싶을 때가 많지만 방송에서 얘기를 거두절미합니다 왜 비판하는지에 대한 근거를 가지고
# ->  저는 이 내용은 동의하지 못하고 유권 해석이 맞다면 저도 이런 얘기하고 싶을 때가 많지만 방송에서 얘기를 거두절미합니다 왜 비판하는지에 대한 근거를 가지고
#
# 이런 문제를 좀 보완해야 되겠죠 보수는 또 @정당2은 이런 문제를 개선해야 되겠죠 제가 @정당2 빼고 투표합시다라고 했으면 저 고발당했을걸요?
# ->  이런 문제를 좀 보완해야 되겠죠 보수는 또 @정당2은 이런 문제를 개선해야 되겠죠 제가 @정당2 빼고 투표합시다라고 했으면 저 고발당했을걸요?
#
# 아침에 공장장도 그 얘기를 했습니다 우리는 다 조심하는 데 직격탄을 쓴 거예요 고발하라고 했는지 모르지만 결국 고발은 저는 잘못했다고 봐요 왜냐하면 언중위에서
# ->  아침에 공장장도 그 얘기를 했습니다 우리는 다 조심하는 데 직격탄을 쓴 거예요 고발하라고 했는지 모르지만 결국 고발은 저는 잘못했다고 봐요 왜냐하면 언중위에서
#
# 유권해석한 걸로 됐어요 여러 기구들이 있는데 당이 고발할 것 없었다 그래서 이제 그 문제는 @정당2도 좀 잘하진 않았지만 저는 이 칼럼 자체도 문제라고 봅니다.
# ->  유권해석한 걸로 됐어요 여러 기구들이 있는데 당이 고발할 것 없었다 그래서 이제 그 문제는 @정당2도 좀 잘하진 않았지만 저는 이 칼럼 자체도 문제라고 봅니다.
#
# 패널들이 방송을 나가게 되면 방송 중립 공정보도의무 때문에 여러가지 측면에서 좀 조심을 하라 이런 이야기를 많이 듣게 되는데
# ->  패널들이 방송을 나가게 되면 방송 중립 공정보도의무 때문에 여러가지 측면에서 좀 조심을 하라 이런 이야기를 많이 듣게 되는데
#
# 그런 의미에서 이제 이 칼럼이 좀 문제가 있었던 게 아니냐 이런 얘기가 나옵니다 어쨌든 @정당2은 이 칼럼이 공직선거법 위반 소지가 있다 그래서 지난 (십삼 일에)/(13일에)
# ->  그런 의미에서 이제 이 칼럼이 좀 문제가 있었던 게 아니냐 이런 얘기가 나옵니다 어쨌든 @정당2은 이 칼럼이 공직선거법 위반 소지가 있다 그래서 지난 십삼 일에
#
# 임 교수와 경향신문을 둘 다 검찰에 고발을 했는데 결국에는 이제 당 내부 혹은 바깥에 있는 사람들의 비판 때문에 고발 조치가 과도했다고해서 취소를 했습니다 그리고 (십육 일에는)/(16일에는)
# ->  임 교수와 경향신문을 둘 다 검찰에 고발을 했는데 결국에는 이제 당 내부 혹은 바깥에 있는 사람들의 비판 때문에 고발 조치가 과도했다고해서 취소를 했습니다 그리고 십육 일에는
#
# 윤미래 교수가 @정당2 지도부의 사과를 공식적으로 요구를 하는 그런 일이 벌어졌고요 (십칠 일)/(17일) 오늘 @이름3 전 총리와 @이름6 최고위원이 사과발언을 했습니다.
# ->  윤미래 교수가 @정당2 지도부의 사과를 공식적으로 요구를 하는 그런 일이 벌어졌고요 십칠 일 오늘 @이름3 전 총리와 @이름6 최고위원이 사과발언을 했습니다.
#
# 그 내용을 한번 보겠습니다 @이름6 최고위원이 마음을 아프게 한다면서 @정당2은 표현과 언론의 자유를 위해서 권위주의 정권에 투쟁해왔다라고 또 표현했고요.
# ->  그 내용을 한번 보겠습니다 @이름6 최고위원이 마음을 아프게 한다면서 @정당2은 표현과 언론의 자유를 위해서 권위주의 정권에 투쟁해왔다라고 또 표현했고요.
#
# @정당2이 앞으로 잘하겠다 낮은 자세로 국민과 소통하겠다 정의로운 대한민국에 애쓰겠다라고 얘기를 했습니다 @이름3 총리 역시 @이름3 전 총리 입니다 사과를 했죠?
# ->  @정당2이 앞으로 잘하겠다 낮은 자세로 국민과 소통하겠다 정의로운 대한민국에 애쓰겠다라고 얘기를 했습니다 @이름3 총리 역시 @이름3 전 총리 입니다 사과를 했죠?
#
# 그렇습니다 국민들께 미안하다 국민들께 미안하게 생각한다는 얘기를 거듭해서 했고요 자 그리고 이제 겸손함에 대한 얘기도 했고 앞으로 저부터 더 스스로 경계하고 주의하겠다.
# ->  그렇습니다 국민들께 미안하다 국민들께 미안하게 생각한다는 얘기를 거듭해서 했고요 자 그리고 이제 겸손함에 대한 얘기도 했고 앞으로 저부터 더 스스로 경계하고 주의하겠다.
#
# 당도 그렇게 해주기를 기대한다 이런 얘기를 했습니다 자 그리고 이 발언을 듣고 @이름2 교수도 사과를 수용하겠다 이런 이야기를 했거든요.
# ->  당도 그렇게 해주기를 기대한다 이런 얘기를 했습니다 자 그리고 이 발언을 듣고 @이름2 교수도 사과를 수용하겠다 이런 이야기를 했거든요.
#
# @정당2 당 대표의 공식 사과가 없는 것은 유감이긴 하지만 @이름3 전 총리와 @이름6 최고위원의 발언을 의미 있게 생각하고 수용한다 이렇게 얘기를 했습니다.
# ->  @정당2 당 대표의 공식 사과가 없는 것은 유감이긴 하지만 @이름3 전 총리와 @이름6 최고위원의 발언을 의미 있게 생각하고 수용한다 이렇게 얘기를 했습니다.
#
# 저는 그런데 전 약간 그 수용한다 이 표현이 좀 걸리기는 하더라고요 뭔가 사과를 받아내는 뭔가 좀
# ->  저는 그런데 전 약간 그 수용한다 이 표현이 좀 걸리기는 하더라고요 뭔가 사과를 받아내는 뭔가 좀
#
# 그런 뉘앙스이긴 했는데 어쨌든 그렇다면 이 칼럼 논란은 어떻게 이렇게 일단락이 되는 건지 총선을 앞두고 사실 @정당2은 국민하고 소통을 하고 공감하고 민생을 최우선으로 챙기겠다.
# ->  그런 뉘앙스이긴 했는데 어쨌든 그렇다면 이 칼럼 논란은 어떻게 이렇게 일단락이 되는 건지 총선을 앞두고 사실 @정당2은 국민하고 소통을 하고 공감하고 민생을 최우선으로 챙기겠다.
#
# 항상 이렇게 얘기를 해오고 있거든요 국민께 미안하다라는 뜻도 그래서 밝힌 건데 이 (사월 십오일)/(4월 15일) 총선에 어 이 관련된 일들이 어떤 영향을 미칠 거라고 보시나요?
# ->  항상 이렇게 얘기를 해오고 있거든요 국민께 미안하다라는 뜻도 그래서 밝힌 건데 이 사월 십오일 총선에 어 이 관련된 일들이 어떤 영향을 미칠 거라고 보시나요?
#
# 앞으로 한 달여 남았는데요 저는 허다한 일들이 쏟아질 거기 때문에 이것은 일단락 된 것으로 다만 @정당2는 더 낮아지는 계기로 삼아야 할 것이고 야권은 아마
# ->  앞으로 한 달여 남았는데요 저는 허다한 일들이 쏟아질 거기 때문에 이것은 일단락 된 것으로 다만 @정당2는 더 낮아지는 계기로 삼아야 할 것이고 야권은 아마
#
# 해시태그로 @정당2 빼고 라는 유행어를 계속 쓸 것 같습니다 하지만 이 이상 확전은 어렵다 이렇게 봅니다.
# ->  해시태그로 @정당2 빼고 라는 유행어를 계속 쓸 것 같습니다 하지만 이 이상 확전은 어렵다 이렇게 봅니다.
#
# 저도 임 교수가 일단 당 입장이 없는 것은 유감이지만 받아들이겠다 아까 막 수용이라는 단어가 좀 거북스럽잔 표현도 있었습니다만 이렇게 함으로서 일단락이 된 것 같아요 만약에 @이름2 교수가 여기에서
# ->  저도 임 교수가 일단 당 입장이 없는 것은 유감이지만 받아들이겠다 아까 막 수용이라는 단어가 좀 거북스럽잔 표현도 있었습니다만 이렇게 함으로서 일단락이 된 것 같아요 만약에 @이름2 교수가 여기에서
#
# 아 이건 @이름3 개인에 지금 사과인 거고 @이름6 최고의 개인의 사과인 것이 당 차원의 사과는 없었던 것 아니에요 만약에 따져 들었다면 또 지저분한 싸움으로 당연히 야권에선 이용할 것이고
# ->  아 이건 @이름3 개인에 지금 사과인 거고 @이름6 최고의 개인의 사과인 것이 당 차원의 사과는 없었던 것 아니에요 만약에 따져 들었다면 또 지저분한 싸움으로 당연히 야권에선 이용할 것이고
#
# 근데 다행히 이렇게 마무리가 된 것 자체 다만 꼬투리를 굳이 잡자면 지금 @이름3 총리 저는 사실은 @이름3 전 총리의 얘기가 굉장히 신뢰가 좀 있는 원래 무슨 얘기라도 좀 그런 게 있잖아요.
# ->  근데 다행히 이렇게 마무리가 된 것 자체 다만 꼬투리를 굳이 잡자면 지금 @이름3 총리 저는 사실은 @이름3 전 총리의 얘기가 굉장히 신뢰가 좀 있는 원래 무슨 얘기라도 좀 그런 게 있잖아요.
#
# 처음부터 여기에 대한 문제 제기를 했었고 결국은 당 입장이 안 나왔는데 본인이 이야기를 했거든요 앞으로 저부터 스스로 경계하고 주의할 것이다 그리고 뒤에 붙인말이
# ->  처음부터 여기에 대한 문제 제기를 했었고 결국은 당 입장이 안 나왔는데 본인이 이야기를 했거든요 앞으로 저부터 스스로 경계하고 주의할 것이다 그리고 뒤에 붙인말이
#
# 당도 그렇게 해주기를 기대한다라는 말은 당과 협의된 내용은 아니라는 어쨌든 의미일 수 있어요 나는 이렇게 생각하는데 당도 그러면 좋겠다.
# ->  당도 그렇게 해주기를 기대한다라는 말은 당과 협의된 내용은 아니라는 어쨌든 의미일 수 있어요 나는 이렇게 생각하는데 당도 그러면 좋겠다.
#
# 이 자체가 당의 입장이 아니라는 걸 어쩌면 더 명확하게 했다는 반증도 될 수 있기 때문에 모르겠어요 이 부분을 당 차원에서 굳이 사과를 해야 될지 말아야 될지는 의견이 나뉠 수 있겠습니다만
# ->  이 자체가 당의 입장이 아니라는 걸 어쩌면 더 명확하게 했다는 반증도 될 수 있기 때문에 모르겠어요 이 부분을 당 차원에서 굳이 사과를 해야 될지 말아야 될지는 의견이 나뉠 수 있겠습니다만
#
# 이 부분을 굳이 야권에서 꼬투리를 잡자면 아직 꼬투리의 여지는 있다 다만 전 앞서서도 @정당2이 조급했다고 말한 게 야권에서 @이름2 교수의 칼럼을 가지고 막 홍보를 할려고 한들
# ->  이 부분을 굳이 야권에서 꼬투리를 잡자면 아직 꼬투리의 여지는 있다 다만 전 앞서서도 @정당2이 조급했다고 말한 게 야권에서 @이름2 교수의 칼럼을 가지고 막 홍보를 할려고 한들
#
# 저는 어차피 지지자들이 그거 가지고 움직이진 않았을것 같아요 오히려 본인들이 미리 겁먹고 이게 우리가 선제적으로 뭘 해야 되는 것 아니야 건드려버림으로써 오히려 저는 야당이 더 원하는
# ->  저는 어차피 지지자들이 그거 가지고 움직이진 않았을것 같아요 오히려 본인들이 미리 겁먹고 이게 우리가 선제적으로 뭘 해야 되는 것 아니야 건드려버림으로써 오히려 저는 야당이 더 원하는
#
# 쪽으로 이렇게 몰려간거 같은 생각도 들 거든요 이런 식으로 차라리 그냥 놔뒀으면 아유 또 쟤네 저러다 말겠지 이러고 이제 말 수도 있었던 사건을 어쨌든 본인들이 좀 키웠다라는 아쉬움도 좀 있습니다.
# ->  쪽으로 이렇게 몰려간거 같은 생각도 들 거든요 이런 식으로 차라리 그냥 놔뒀으면 아유 또 쟤네 저러다 말겠지 이러고 이제 말 수도 있었던 사건을 어쨌든 본인들이 좀 키웠다라는 아쉬움도 좀 있습니다.
#
# 글쎄 뭐 당이 공식적으로 사과를 사안이었는지 아니었는지는 다 의견이 있습니다만은 어쨌든 보수 진영 정치 세력이 하나로 뭉친 오늘 @정당1 얘기도 한번 해 보겠습니다.
# ->  글쎄 뭐 당이 공식적으로 사과를 사안이었는지 아니었는지는 다 의견이 있습니다만은 어쨌든 보수 진영 정치 세력이 하나로 뭉친 오늘 @정당1 얘기도 한번 해 보겠습니다.
#
# 지금 (사일오)/(415) 총선을 (오십팔 일)/(58일) 앞두고 결과적으로는 이제 공식적으로 이 @정당1이 출범을 했는데요 이게 사실은 @이름7 정권에 대한 심판론을 기치로 삼고
# ->  지금 사일오 총선을 오십팔 일 앞두고 결과적으로는 이제 공식적으로 이 @정당1이 출범을 했는데요 이게 사실은 @이름7 정권에 대한 심판론을 기치로 삼고
#
# 지금 총선에서 승리하겠다 이렇게 선언한 거 아니겠습니까 보수 통합의 의미가 있다 아니다 이거 원래 도로 @정당4이다 이런 비판까지 나오고 있는 상황이에요 어떻게 보십니까?
# ->  지금 총선에서 승리하겠다 이렇게 선언한 거 아니겠습니까 보수 통합의 의미가 있다 아니다 이거 원래 도로 @정당4이다 이런 비판까지 나오고 있는 상황이에요 어떻게 보십니까?
#
# 저는 @이름8 의원이 오늘 불참한 것이 눈에 띄었고 그럼 이게 의미있는 게 되려면 @이름8 의원이 제시한 보수 통합 (삼 원칙)/(3원칙) 중에 뭐가 지켜지고 아직 부족한가를 따져봤어요.
# ->  저는 @이름8 의원이 오늘 불참한 것이 눈에 띄었고 그럼 이게 의미있는 게 되려면 @이름8 의원이 제시한 보수 통합 삼 원칙 중에 뭐가 지켜지고 아직 부족한가를 따져봤어요.
#
# 탄핵의 강을 건넜는가 물음표예요 개혁 보수로 나아갈 것인가 그럴 거라고 선언했고 이건 앞으로 지켜볼 문제예요 제일 중요한 게 (세번 짼데)/(3번짼데)
# ->  탄핵의 강을 건넜는가 물음표예요 개혁 보수로 나아갈 것인가 그럴 거라고 선언했고 이건 앞으로 지켜볼 문제예요 제일 중요한 게 세번 짼데
#
# 자 헌 집을 허물고 새 집을 지어야 합니다 여기에 대해서 @이름9 대표도 동의한 것으로 전제하고 @이름10 위원장이 (육 대)/(6대) 원칙을 내세웠거든요 네 오늘 핑크색 집이 새로 지어진 거예요.
# ->  자 헌 집을 허물고 새 집을 지어야 합니다 여기에 대해서 @이름9 대표도 동의한 것으로 전제하고 @이름10 위원장이 육 대 원칙을 내세웠거든요 네 오늘 핑크색 집이 새로 지어진 거예요.
#
# 간판도 바꿨어요 @정당5에서 네 그런데 이게 뭐냐하면 @이름9 대표 체제 그대로 그다음에 최고위원회도 그대로 (네 명만)/(4명만) 추가 @이름11 공간 위원장 체제 그대로
# ->  간판도 바꿨어요 @정당5에서 네 그런데 이게 뭐냐하면 @이름9 대표 체제 그대로 그다음에 최고위원회도 그대로 네 명만 추가 @이름11 공간 위원장 체제 그대로
#
# 그러면 제가 보기에는 이것은 허물지 않았어요 기존의 헌 집을 헌 집에 골조가 남아있는데
# ->  그러면 제가 보기에는 이것은 허물지 않았어요 기존의 헌 집을 헌 집에 골조가 남아있는데
#
# 리모델링 하는건가요 그러면?
# ->  리모델링 하는건가요 그러면?
#
# 리모델링도 아니예요 페인트를 핑크색으로 칠한 거예요 그리고 간판을 바꿔달았지요 이런 면에서는 아직은 개혁 보수로 가기에는 미흡한 점이 많은데
# ->  리모델링도 아니예요 페인트를 핑크색으로 칠한 거예요 그리고 간판을 바꿔달았지요 이런 면에서는 아직은 개혁 보수로 가기에는 미흡한 점이 많은데
#
# 총선 전에 통합을 해야 된다는 급박한 마음에 형식은 갖췄습니다 내용을 채워주셔야 됩니다.
# ->  총선 전에 통합을 해야 된다는 급박한 마음에 형식은 갖췄습니다 내용을 채워주셔야 됩니다.
#
# 자 @정당1 출범을 두고도 지금처럼 다양한 반응이 나오고 있는데요 이것도 잠깐 살펴보겠습니다 자 @이름12 @정당2 원내대표죠? /(bgm)
# ->  자 @정당1 출범을 두고도 지금처럼 다양한 반응이 나오고 있는데요 이것도 잠깐 살펴보겠습니다 자 @이름12 @정당2 원내대표죠?
#
# 돌고 돌아 도로 @정당4 뭐 그렇게 됐다 그리고 새로운 (제 일)/(제1) 야당에는 새 인물도 새 비전도 잘 보이지 않는다라고 했고요. /(bgm)
# ->  돌고 돌아 도로 @정당4 뭐 그렇게 됐다 그리고 새로운 제 일 야당에는 새 인물도 새 비전도 잘 보이지 않는다라고 했고요.
#
# @정당6의 @이름13 대변인은 이렇게 얘기를 했습니다 탄핵 이전과 무엇이 달라졌는지는 모르겠다.
# ->  @정당6의 @이름13 대변인은 이렇게 얘기를 했습니다 탄핵 이전과 무엇이 달라졌는지는 모르겠다.
#
# 어떤 쇄신과 변화가 있었는지 의문이지만 어쨌든 잘하길 기원합니다 라임을 맞추셨네요. /(noise)
# ->  어떤 쇄신과 변화가 있었는지 의문이지만 어쨌든 잘하길 기원합니다 라임을 맞추셨네요.
#
# 어쨌든 좋아하시나봐요 네 /(noise)
# ->  어쨌든 좋아하시나봐요 네
#
# 자 @이름14 @정당7 대변인입니다 탄핵 부정세력과 보수 정치 낭인들이 임시 거처를 마련했다 긍정적 의미도 찾기 어렵다라고 혹평을 했는데요.
# ->  자 @이름14 @정당7 대변인입니다 탄핵 부정세력과 보수 정치 낭인들이 임시 거처를 마련했다 긍정적 의미도 찾기 어렵다라고 혹평을 했는데요.
#
# 자 비전이 안 보인다 또 무엇이 달라졌는지 모르겠다 @이름5 평론가 어떻게 평가하고 계십니까? /(noise)
# ->  자 비전이 안 보인다 또 무엇이 달라졌는지 모르겠다 @이름5 평론가 어떻게 평가하고 계십니까?
#
# 저도 모르겠어요 근데 다만 이들이 그러니까 지금 보수 대통합해서 국민들에게 그러니까 보수를 지지하는 국민들에게 내세우고자 하는 메시지는 뭔지 알겠어요 우리는
# ->  저도 모르겠어요 근데 다만 이들이 그러니까 지금 보수 대통합해서 국민들에게 그러니까 보수를 지지하는 국민들에게 내세우고자 하는 메시지는 뭔지 알겠어요 우리는
#
# 보수가 분열됐다는 것 자체가 이슈가 막 됐었잖아요 역사적으로 보수가 이렇게 분열되는 건 이례적이다 그런데 우리 다 통합 한다 그러다보니까 결국은 주류의 그니까 보수 주류들만 모인 게 아니라 뭐
# ->  보수가 분열됐다는 것 자체가 이슈가 막 됐었잖아요 역사적으로 보수가 이렇게 분열되는 건 이례적이다 그런데 우리 다 통합 한다 그러다보니까 결국은 주류의 그니까 보수 주류들만 모인 게 아니라 뭐
#
# @정당1원들 여기 시민연대 뭐 이거 쭉 지금 다 끌어모으고 있거든요 @이름15 뭐 지금 뒤에 나오겠지만 그래서 우리가 분열되지 않았습니다.
# ->  @정당1원들 여기 시민연대 뭐 이거 쭉 지금 다 끌어모으고 있거든요 @이름15 뭐 지금 뒤에 나오겠지만 그래서 우리가 분열되지 않았습니다.
#
# 하나로 뭉쳐서 현 정부를 심판합시다라는 어떤 이걸로 가는 거 같아요 왜냐하면 지금 다 @정당5 그대로 체제로 가고 총선 이후에 뭔가 정비를 하겠다는 얘기는
# ->  하나로 뭉쳐서 현 정부를 심판합시다라는 어떤 이걸로 가는 거 같아요 왜냐하면 지금 다 @정당5 그대로 체제로 가고 총선 이후에 뭔가 정비를 하겠다는 얘기는
#
# 정비를 그때 가서하겠다라는 건 어쨌든 변화된 게 하나도 없다라는 걸 스스로 이야기한 거거든요 다만 이들이 내세우는 현 정부 잘못됐으니까 이거를 심판하자라는 얘기가 설득력이 많이 떨어지는 게
# ->  정비를 그때 가서하겠다라는 건 어쨌든 변화된 게 하나도 없다라는 걸 스스로 이야기한 거거든요 다만 이들이 내세우는 현 정부 잘못됐으니까 이거를 심판하자라는 얘기가 설득력이 많이 떨어지는 게
#
# 이게 그렇잖아요 기생충 이번에 막 상타고 이러니까 @정당5 의원들 올라타려고 했다가 바로 공격 당했잖아요 블랙리스트부터 사과해 탄핵도 마찬가지예요 대통령 탄핵 이야기 막 나오는데 어 니네가
# ->  이게 그렇잖아요 기생충 이번에 막 상타고 이러니까 @정당5 의원들 올라타려고 했다가 바로 공격 당했잖아요 블랙리스트부터 사과해 탄핵도 마찬가지예요 대통령 탄핵 이야기 막 나오는데 어 니네가
#
# 바로 직전 정권에 그런 일이 있었는데 뭘 반성했어 역풍을 맞을 게 굉장히 많아서 공격할 무기가 없어요 정권 심판하자고 할 근데 지금 이렇게 일단 통합해서 뭔가를
# ->  바로 직전 정권에 그런 일이 있었는데 뭘 반성했어 역풍을 맞을 게 굉장히 많아서 공격할 무기가 없어요 정권 심판하자고 할 근데 지금 이렇게 일단 통합해서 뭔가를
#
# 반정부 그러니까 지금 @정당 정부를 심판하자 이 자체가 원래 보수들한테는 하나 안 하나 똑같이 지지자들인데 새로운 중도층 지지자들을 끌어들이기 위한
# ->  반정부 그러니까 지금 @정당 정부를 심판하자 이 자체가 원래 보수들한테는 하나 안 하나 똑같이 지지자들인데 새로운 중도층 지지자들을 끌어들이기 위한
#
# 어떤 메시지로 설득력이 저는 그다지 보이지는 않습니다 저는 그렇게 해석합니다.
# ->  어떤 메시지로 설득력이 저는 그다지 보이지는 않습니다 저는 그렇게 해석합니다.
#
# 그렇습니다 자 이런 가운데 @이름16 @정당5 의원이 @정당1에 함께 참여해달라라고 하면서 러브콜을 보낸 의원들이 좀 있거든요 화면이 나오고 있죠?
# ->  그렇습니다 자 이런 가운데 @이름16 @정당5 의원이 @정당1에 함께 참여해달라라고 하면서 러브콜을 보낸 의원들이 좀 있거든요 화면이 나오고 있죠?
#
# @정당8의 @이름15 전 지사 @이름17 목사 또 @정당9의 @이름18 의원 그리고 @이름19 의원 무소속 @이름20 의원인데 사실 지금 이렇게 보고 계시는 의원들 모두
# ->  @정당8의 @이름15 전 지사 @이름17 목사 또 @정당9의 @이름18 의원 그리고 @이름19 의원 무소속 @이름20 의원인데 사실 지금 이렇게 보고 계시는 의원들 모두
#
# 보수통합 논의에는 참여를 하지를 않았거든요 근데 이들에게 @이름16 의원이 러브콜을 보낸 이유 뭐라고 생각하시나요?
# ->  보수통합 논의에는 참여를 하지를 않았거든요 근데 이들에게 @이름16 의원이 러브콜을 보낸 이유 뭐라고 생각하시나요?
#
# 이 인물들이 중요하잖아요 대부분 친박이고 원외인사도있는데 좀 논란이 많은 @이름17 씨 목사 이 호칭도 좀 논란이 있습니다 자 그런데 이제 문제는 뭐냐 하면
# ->  이 인물들이 중요하잖아요 대부분 친박이고 원외인사도있는데 좀 논란이 많은 @이름17 씨 목사 이 호칭도 좀 논란이 있습니다 자 그런데 이제 문제는 뭐냐 하면
#
# 이들의 뒤에 태극기 소위 태극기 부대 세력이 필요한 거예요 왜냐하면 통합한 이유는 최대한 표를 모아서 확장 해보자는 건데 아까 장 평론가 말씀 그대로
# ->  이들의 뒤에 태극기 소위 태극기 부대 세력이 필요한 거예요 왜냐하면 통합한 이유는 최대한 표를 모아서 확장 해보자는 건데 아까 장 평론가 말씀 그대로
#
# 지금 이게 이 중도 쪽으로 확장이 어려운 걸 스스로 알아요 그러면은 이게 지금 산토끼를 못잡으니까 집토끼라도 더 하나라도 모아보자 그러면 그분들이 누구냐?
# ->  지금 이게 이 중도 쪽으로 확장이 어려운 걸 스스로 알아요 그러면은 이게 지금 산토끼를 못잡으니까 집토끼라도 더 하나라도 모아보자 그러면 그분들이 누구냐?
#
# 바로 소위 태극기 부대 나가고 있는 강성 근데 이 @이름21 전 대통령에 대한 탄핵에 강을 못 건너고 어정쩡한 상황 때문에 그럼 이분들 막 끌어들이자는 거예요.
# ->  바로 소위 태극기 부대 나가고 있는 강성 근데 이 @이름21 전 대통령에 대한 탄핵에 강을 못 건너고 어정쩡한 상황 때문에 그럼 이분들 막 끌어들이자는 거예요.
#
# 이분들 들어오면 그럼 @이름16 의원에게 제가 묻습니다 그때 탄핵 때 멋있는 말을 딱 한 번 했어요.
# ->  이분들 들어오면 그럼 @이름16 의원에게 제가 묻습니다 그때 탄핵 때 멋있는 말을 딱 한 번 했어요.
#
# 뭐라고 했어요?
# ->  뭐라고 했어요?
#
# 제가 들은 중 뭐냐하면 이 당은 @정당4은 완전히 해체하고 그 자산은 국가에 헌납해야 할 땅이다 그러면서 @이름8 의원 손잡고 @정당10 만들어 나갔는데 슬그머니 복당 했단 말이에요.
# ->  제가 들은 중 뭐냐하면 이 당은 @정당4은 완전히 해체하고 그 자산은 국가에 헌납해야 할 땅이다 그러면서 @이름8 의원 손잡고 @정당10 만들어 나갔는데 슬그머니 복당 했단 말이에요.
#
# 그럼 @이름16 이 의원은 탄핵에 찬성한 걸 반성하는 입장이냐 그때 내가 잘못했다 박 전 대통령은 무고했다는 입장이냐 이걸 좀 똑바로 얘기해 줬으면 좋겠어요.
# ->  그럼 @이름16 이 의원은 탄핵에 찬성한 걸 반성하는 입장이냐 그때 내가 잘못했다 박 전 대통령은 무고했다는 입장이냐 이걸 좀 똑바로 얘기해 줬으면 좋겠어요.
#
# 자 @정당1 (십칠 일)/(17일) 출범을 했는데요 @정당5의 (오 선의)/(5선의) @이름22 의원하고 또 (사 선의)/(4선의) @이름23 의원 잇따라 총선 불출마를 선언했습니다.
# ->  자 @정당1 십칠 일 출범을 했는데요 @정당5의 오 선의 @이름22 의원하고 또 사 선의 @이름23 의원 잇따라 총선 불출마를 선언했습니다.
#
# 두 의원의 불출마 선언 입장을 한번 보죠.
# ->  두 의원의 불출마 선언 입장을 한번 보죠.
#
# 네 일단 @이름22 @정당5 의원은 이번 총선은 자유 대한민국을 지키고 망해가는 나라를 바로잡는 중차대한 선거라는 점에서 제가 마음을 내려놓는다.
# ->  네 일단 @이름22 @정당5 의원은 이번 총선은 자유 대한민국을 지키고 망해가는 나라를 바로잡는 중차대한 선거라는 점에서 제가 마음을 내려놓는다.
#
# 여러분의 한 표가 @이름7 정권의 잘못된 정책을 바로 잡을 수 있다 그 과업을 향해 백의종군하겠다 이렇게 얘기를 했고요.
# ->  여러분의 한 표가 @이름7 정권의 잘못된 정책을 바로 잡을 수 있다 그 과업을 향해 백의종군하겠다 이렇게 얘기를 했고요.
#
# @이름23 의원도 물꼬를 열어주면서 자신을 던지고 총선 승리와 정권 교체를 위한 밀알이 되겠다 이렇게 얘기했는데 두 의원 모두 피케이 출신 입니다.
# ->  @이름23 의원도 물꼬를 열어주면서 자신을 던지고 총선 승리와 정권 교체를 위한 밀알이 되겠다 이렇게 얘기했는데 두 의원 모두 피케이 출신 입니다.
#
# 부산하고 경남의 친박계 의원으로 분류되고 있는데 왜 갑자기 아니 갑자기는 아니죠 불출마 결심한 이유는 @이름5 평론가 뭡니까?
# ->  부산하고 경남의 친박계 의원으로 분류되고 있는데 왜 갑자기 아니 갑자기는 아니죠 불출마 결심한 이유는 @이름5 평론가 뭡니까?
#
# 저는 지금 일단 큰 메시지가 그거예요 계속 희생 이야기 하고 있고 예를 들면 황 대표가 험지 얘기하다가 한번 계속 미뤄 가지고 비판 받았잖아요.
# ->  저는 지금 일단 큰 메시지가 그거예요 계속 희생 이야기 하고 있고 예를 들면 황 대표가 험지 얘기하다가 한번 계속 미뤄 가지고 비판 받았잖아요.
#
# 그러면서 종로 갑자기 이야기 하고 @이름24 전 대표도 뭐 고향에 출마하겠다 당하고 대립각 세우는 것 가져다가 살짝 얼른 옮겼어요 양산 쪽으로 등등등을 가지고
# ->  그러면서 종로 갑자기 이야기 하고 @이름24 전 대표도 뭐 고향에 출마하겠다 당하고 대립각 세우는 것 가져다가 살짝 얼른 옮겼어요 양산 쪽으로 등등등을 가지고
#
# 지금 일단 통합해서 뭔가 구체적으로 체제를 정리하고 이런 게 없으니까 일단 그 이 큰 메세지로 가는 거 같아요 실제 이런 원인을 우리가 이유는 그들이 알겠지만
# ->  지금 일단 통합해서 뭔가 구체적으로 체제를 정리하고 이런 게 없으니까 일단 그 이 큰 메세지로 가는 거 같아요 실제 이런 원인을 우리가 이유는 그들이 알겠지만
#
# 일단 표면적으로는 희생하겠다 이런 얘기를 지금 계속 내보이고 있잖아요 우리가 정말 변하겠다 우리가 정말 혁신해서 다시 한번 해보겠다 이걸 그냥 홍보하기 위해서는 이런 중진의원들이
# ->  일단 표면적으로는 희생하겠다 이런 얘기를 지금 계속 내보이고 있잖아요 우리가 정말 변하겠다 우리가 정말 혁신해서 다시 한번 해보겠다 이걸 그냥 홍보하기 위해서는 이런 중진의원들이
#
# 굉장히 효과는 어느정도 있을거라 생각이 듭니다 보수 입장에서는
# ->  굉장히 효과는 어느정도 있을거라 생각이 듭니다 보수 입장에서는
#
# 어쨌든 한편 이제 호남 통합은 또 좀 브레이크가 걸렸습니다 @이름25 @정당6 대표가 호남 (삼 당)/(3당) @정당6 @정당11 @정당12에
# ->  어쨌든 한편 이제 호남 통합은 또 좀 브레이크가 걸렸습니다 @이름25 @정당6 대표가 호남 삼 당 @정당6 @정당11 @정당12에
#
# 이 그 협의안을 거부하고 있잖습니까 추인하는 것을 근데 여기에 대해서 @이름25 대표 입장이 뭔지 한번 일단 들어보고 얘기하겠습니다.
# ->  이 그 협의안을 거부하고 있잖습니까 추인하는 것을 근데 여기에 대해서 @이름25 대표 입장이 뭔지 한번 일단 들어보고 얘기하겠습니다.
#
# (십칠 일)/(17일) 기자하고 만나면서 얘기를 했던 건데요 합당 합의문 추이는 신중한 문제고 폭넓은 국민 또 당원 의견을 수렴해야 한다 그래서 오늘 최고위에서 /(bgm)
# ->  십칠 일 기자하고 만나면서 얘기를 했던 건데요 합당 합의문 추이는 신중한 문제고 폭넓은 국민 또 당원 의견을 수렴해야 한다 그래서 오늘 최고위에서
#
# 심사를 보류했다라고 하고 또 선거 편의를 위한 지역 이기주의 지역주의는 우리의 선택이 될 수 없다 구태로 회귀해서는 안 된다고 얘기했습니다. /(bgm)
# ->  심사를 보류했다라고 하고 또 선거 편의를 위한 지역 이기주의 지역주의는 우리의 선택이 될 수 없다 구태로 회귀해서는 안 된다고 얘기했습니다.
#
# 그 말의 의미는 기본적으로 호남을 기반으로 한 당끼리 모여봤자 무슨 의미가 있겠느냐 이런 뜻이 될텐데 위원님 보기에 어떠세요? /(bgm)
# ->  그 말의 의미는 기본적으로 호남을 기반으로 한 당끼리 모여봤자 무슨 의미가 있겠느냐 이런 뜻이 될텐데 위원님 보기에 어떠세요?
#
# 말씀은 맞아요 예를 들면 지금 누가 봐도 호남 신당 아니냐 그리고 @정당13에서 @이름4 전 대표만 빠져서 다시 @정당13 차렸고 지금 나머지가 모였을 때 호남 기반으로 몇표나
# ->  말씀은 맞아요 예를 들면 지금 누가 봐도 호남 신당 아니냐 그리고 @정당13에서 @이름4 전 대표만 빠져서 다시 @정당13 차렸고 지금 나머지가 모였을 때 호남 기반으로 몇표나
#
# 몇 의석이나 건질 수 있겠는가 고민이거든요 근데 @이름25 대표가 보기에는 새로운 건 없고 호남 도로 호남 신당이고 그래서 무슨 얘기를 했냐면 젊은층을 영입하자 이런 이야기를 했는데
# ...
#
# 마지막에 @이름4 @이름5 하 마지막 하구요.
# ->  마지막에 @이름4 @이름5 하 마지막 하구요.
#
# 사고 싶은 것에 사 바보처럼의 바 @이름4 @이름5의 바 사바하
# ->  사고 싶은 것에 사 바보처럼의 바 @이름4 @이름5의 바 사바하
#
# (()) 독특한 구조의 시네요 이게 그러면 이 이게 글을 놓고 봐야 돼요 그 앞글자를.
# ->  독특한 구조의 시네요 이게 그러면 이 이게 글을 놓고 봐야 돼요 그 앞글자를.
#
# 보여드리기가 쫌 그래서
# ->  보여드리기가 쫌 그래서
#
# 아
# ->  아
#
# 전 처음 부분에도 쫌 첫 (두 줄이)/(2줄이) 뭐였죠 다시 읽어줘요.
# ->  전 처음 부분에도 쫌 첫 두 줄이 뭐였죠 다시 읽어줘요.
#
# 아 시시때때로 밤이 무서워 시시한 게임으로 밤을 새운다.
# ->  아 시시때때로 밤이 무서워 시시한 게임으로 밤을 새운다.
#
# 전 앞에 (두 줄이)/(2줄이) 되게 좋았어요 왜냐하면 실제로 시인들이 시옷 발음을 일부러 넣어 가지고 운율을 많이 만들어요 어.
# ->  전 앞에 두 줄이 되게 좋았어요 왜냐하면 실제로 시인들이 시옷 발음을 일부러 넣어 가지고 운율을 많이 만들어요 어.
#
# 그래요?
# ->  그래요?
#
# 왜 그래요 시옷이 좀
# ->  왜 그래요 시옷이 좀
#
# 아니 그게 쫌 뭐 따른 걸 넣어도 상관없는데 리을을 쓰기도 하고 뭐 근데 시옷이나 리을 같은 거를 많이 쓰죠 어예 그이깐 리을을 많이 쓰면 약간 둥글둥글 흐르는 노래하는 듯한 느낌이 들구요.
# ->  아니 그게 쫌 뭐 따른 걸 넣어도 상관없는데 리을을 쓰기도 하고 뭐 근데 시옷이나 리을 같은 거를 많이 쓰죠 어예 그이깐 리을을 많이 쓰면 약간 둥글둥글 흐르는 노래하는 듯한 느낌이 들구요.
#
# 이서 시옷을 쓰면 약간 약간 긴장감이라고 하까 소리가 주는 시옷의 그 긴장감이 있죠.
# ->  이서 시옷을 쓰면 약간 약간 긴장감이라고 하까 소리가 주는 시옷의 그 긴장감이 있죠.
#
# 음
# ->  음
#
# 전 개인적으로 그~ 돈돌 님이 제 기대를 저버리지 않았 어떤 시가 나올지 상상을 할 수가 없었는데 정말 상상도 못할 시를
# ->  전 개인적으로 그~ 돈돌 님이 제 기대를 저버리지 않았 어떤 시가 나올지 상상을 할 수가 없었는데 정말 상상도 못할 시를
#
# 그~ 이게 독특한 새로운 형식의 시다.
# ->  그~ 이게 독특한 새로운 형식의 시다.
#
# 구조주의적
# ->  구조주의적
#
# 구조주의로 봤을 때의 이~ @이름6 시인의 시를 연상하게 하는 고런 새로운 좀 의미부여가 된다 라는
# ->  구조주의로 봤을 때의 이~ @이름6 시인의 시를 연상하게 하는 고런 새로운 좀 의미부여가 된다 라는
#
# 그 싯구의 앞글자들이 모여서 하나의 또 단어를 이루는 이 새로운 형식인 거죠 이게 네. /(noise)
# ->  그 싯구의 앞글자들이 모여서 하나의 또 단어를 이루는 이 새로운 형식인 거죠 이게 네.
#
# 어 요거는 굉장히 그~ 구조학적으로 아 의미가 있다 @이름7의 구조주의
# ->  어 요거는 굉장히 그~ 구조학적으로 아 의미가 있다 @이름7의 구조주의
#
# 아오 역시 국문학과 나오네요.
# ->  아오 역시 국문학과 나오네요.
#
# 사바하가 현실 세계잖아요 이 (()) 혼란스러운 현실 세계를 뜻하는데 고게 이제 어떤 그 사고 싶지만 못 사고 애 애 키우느라 힘들고 이게 마지막에 귀결되는 어 굉장히 위트 있는 어 시다.
# ->  사바하가 현실 세계잖아요 이  혼란스러운 현실 세계를 뜻하는데 고게 이제 어떤 그 사고 싶지만 못 사고 애 애 키우느라 힘들고 이게 마지막에 귀결되는 어 굉장히 위트 있는 어 시다.
#
# 아 이런 생각이 듭니다.
# ->  아 이런 생각이 듭니다.
#
# 솔직히 전 시밤 시밤 그럴 때 그 욕하는 줄 알았었어요 예.
# ->  솔직히 전 시밤 시밤 그럴 때 그 욕하는 줄 알았었어요 예.
#
# 일단 소리로 그런 의도를 하기도 하죠. /(noise)
# ->  일단 소리로 그런 의도를 하기도 하죠.
#
# 유도된 거구 중간에 가발 가발은 가슴 (()) 미어지는 한 같은 게 (()) /(noise)
# ->  유도된 거구 중간에 가발 가발은 가슴  미어지는 한 같은 게
#
# 그게 너무 마음이 벅차올라서 제대로 못 (()) 가발 가발은 /(noise)
# ->  그게 너무 마음이 벅차올라서 제대로 못  가발 가발은
#
# 아
# ->  아
#
# 예
# ->  예
#
# 확실한 근데 감정이입은 일어나
# ->  확실한 근데 감정이입은 일어나
#
# 그쵸 예 감정이입은 뭐 시가 뭐 대단한 게 있겠습니까 자 어 그~ 두 번째 시도 정말 기대 이상의 (()) 자 세 번째 시인을 소개해 드리도록 하겠습니다. /(noise)
# ->  그쵸 예 감정이입은 뭐 시가 뭐 대단한 게 있겠습니까 자 어 그~ 두 번째 시도 정말 기대 이상의  자 세 번째 시인을 소개해 드리도록 하겠습니다.
#
# 왜 이 전공자의 또 시는 어떨까 궁금하고 지금까지 만들어 오신 노래도 있지 않겠습니까 예 그까 굉장히 많은 작사를 해오셨어요 (()) 작곡도 잘 하시지만
# ->  왜 이 전공자의 또 시는 어떨까 궁금하고 지금까지 만들어 오신 노래도 있지 않겠습니까 예 그까 굉장히 많은 작사를 해오셨어요  작곡도 잘 하시지만
#
# @이름8 박사님의 그 위트 넘치는 그~ 저 뭐 최근에 발표한 노래도 되게 좋았고 (()) 가사들이 너무 아름답고 좋아요.
# ->  @이름8 박사님의 그 위트 넘치는 그~ 저 뭐 최근에 발표한 노래도 되게 좋았고  가사들이 너무 아름답고 좋아요.
#
# 음 그래서 이분 정말 시인이신 것 같아 아 이런 생각이 듭니다.
# ->  음 그래서 이분 정말 시인이신 것 같아 아 이런 생각이 듭니다.
#
# 뭐 안주시나요?
# ->  뭐 안주시나요?
#
# 그럼 이제 제 얘기하면 되나요?
# ->  그럼 이제 제 얘기하면 되나요?
#
# 네 이제 뭐 얘기하고 발표하실 거예요?
# ->  네 이제 뭐 얘기하고 발표하실 거예요?
#
# 다른 분에 비해서 비교적 소개는 간소했네요 예.
# ->  다른 분에 비해서 비교적 소개는 간소했네요 예.
#
# 저는 진짜 시를 못쓰겠더라구요 이게 시라고 생각하니까 더 못쓰겠어요 그래서 이 도저히 안 되겠다 이러다가는 내가 이거 마감을 못지키겠다 싶어서
# ->  저는 진짜 시를 못쓰겠더라구요 이게 시라고 생각하니까 더 못쓰겠어요 그래서 이 도저히 안 되겠다 이러다가는 내가 이거 마감을 못지키겠다 싶어서
#
# 한 이틀 전에 기타를 꺼내 들고 진짜 그냥 노래를 만들었습니다 노래를.
# ->  한 이틀 전에 기타를 꺼내 들고 진짜 그냥 노래를 만들었습니다 노래를.
#
# 예 가사도 결국 시 아니겠습니까 뭐 가사란 게 그~ 음표에 제한이 있기 때문에 글자수를 맞춰줘야 되거든요.
# ->  예 가사도 결국 시 아니겠습니까 뭐 가사란 게 그~ 음표에 제한이 있기 때문에 글자수를 맞춰줘야 되거든요.
#
# 음
# ->  음
#
# 예 글자수를 이렇게 마음대로 못쓰기 때문에 어쨌든 단어 선택에 고민을 좀 하게 돼요 가사는
# ->  예 글자수를 이렇게 마음대로 못쓰기 때문에 어쨌든 단어 선택에 고민을 좀 하게 돼요 가사는
#
# 원래 시의 출발이 노래
# ->  원래 시의 출발이 노래
#
# 아 그래요 네 그래서 저는 오늘 이 자리를 (()) 이제 신곡 발표를 하도록 하겠습니다 네 기타도 가져왔습니다 제가 오늘.
# ->  아 그래요 네 그래서 저는 오늘 이 자리를  이제 신곡 발표를 하도록 하겠습니다 네 기타도 가져왔습니다 제가 오늘.
#
# 오 진짜네?
# ->  오 진짜네?
#
# 아 여기서 얘기하셔야
# ->  아 여기서 얘기하셔야
#
# 이 노래를 직접 불르도록 하겠습니다 신곡 발표입니다.
# ->  이 노래를 직접 불르도록 하겠습니다 신곡 발표입니다.
#
# 기대가 돼요.
# ->  기대가 돼요.
#
# 야
# ->  야
#
# 기대가 됩니
# ->  기대가 됩니
#
# 제목이 지금 여기 안 적혀있죠 제목을 사실 (()) 정확하게 못 정했는데 노래 듣고 제목을 한번 또 정해보도록 하죠.
# ->  제목이 지금 여기 안 적혀있죠 제목을 사실  정확하게 못 정했는데 노래 듣고 제목을 한번 또 정해보도록 하죠.
#
# 좋습니다. /(noise)
# ->  좋습니다.
#
# 아주 그냥 조용하게 가을의 분위기로 발라드 곡을 한번 만들어 봤습니다.
# ->  아주 그냥 조용하게 가을의 분위기로 발라드 곡을 한번 만들어 봤습니다.
#
# 후벼파는 감성이네요 어.
# ->  후벼파는 감성이네요 어.
#
# 저는 이 어려운 표현은 없죠 그냥 이제 이게 썼는데 가상 제목은 갱년기입니다.
# ->  저는 이 어려운 표현은 없죠 그냥 이제 이게 썼는데 가상 제목은 갱년기입니다.
#
# (일 절은)/(1절은) 이게 뭐냐면 제가 애한테 심부름을 시키는데 뭘 사오려고 시키려는데 이 깜빡 생각이 안 나는 거야 (()) 나이가 드니까 건망증이 심해져서 그래서 애 뒷모습을 보는데 이제 /(noise)
# ->  일 절은 이게 뭐냐면 제가 애한테 심부름을 시키는데 뭘 사오려고 시키려는데 이 깜빡 생각이 안 나는 거야  나이가 드니까 건망증이 심해져서 그래서 애 뒷모습을 보는데 이제
#
# (()) 분명했는데 이게 흐려져가는 거야 니한테 너아게 이제 사오라고 할 말이 한마디 말이 나올듯 나올듯한데가 안 나오는 그 느낌 있잖아요 (()) 마음에 걸린 말이 이케 막 가슴에 막 이러다가 이제 흩어지는 /(noise)
# ->  분명했는데 이게 흐려져가는 거야 니한테 너아게 이제 사오라고 할 말이 한마디 말이 나올듯 나올듯한데가 안 나오는 그 느낌 있잖아요  마음에 걸린 말이 이케 막 가슴에 막 이러다가 이제 흩어지는
#
# (()) (일 절에)/(1절에) 가사가 그렇구요 이제 (이 절은)/(2절은) 뭐냐면 제가 이제 주말마다 그~ 밤새 밤새 게임을 해야지 생각을 하는데 /(noise)
# ->  일 절에 가사가 그렇구요 이제 이 절은 뭐냐면 제가 이제 주말마다 그~ 밤새 밤새 게임을 해야지 생각을 하는데
#
# 옛날에 그 게임 하고 싶은 그 열정이 오락 밤새 오락 해야지 그 마음이 뜨거웠는데 이제 식는 거예요 그게 그래 가지고 이제 선명했는데 지워져 간다 이거는 이제 그 게임 루트 깨는 게 옛날에는 뚜렷했는데 /(noise)
# ->  옛날에 그 게임 하고 싶은 그 열정이 오락 밤새 오락 해야지 그 마음이 뜨거웠는데 이제 식는 거예요 그게 그래 가지고 이제 선명했는데 지워져 간다 이거는 이제 그 게임 루트 깨는 게 옛날에는 뚜렷했는데
#
# 그래 가지고 이제 졸려는 거예요 제가 게임을 하다가 조는 거예요 자꾸 고런 심정을 예 (이 절에서)/(2절에서) 표현해서 이게 할 말도 자꾸 생각 안 나고 즐기던 일도 하다가 졸고 막 이런 /(noise)
# ->  그래 가지고 이제 졸려는 거예요 제가 게임을 하다가 조는 거예요 자꾸 고런 심정을 예 이 절에서 표현해서 이게 할 말도 자꾸 생각 안 나고 즐기던 일도 하다가 졸고 막 이런
#
# 체력저하를 노래한 갱년기라는 곡입니다. /(noise)
# ->  체력저하를 노래한 갱년기라는 곡입니다.
#
# 사실 저는 이거 네 들으면서 사실은 그~ 뭐랄까 특히 (이 절)/(2절) 부분에서 야 (()) 이게 지금 우리가 살아가는 지금 요 시대에 /(noise)
# ->  사실 저는 이거 네 들으면서 사실은 그~ 뭐랄까 특히 이 절 부분에서 야  이게 지금 우리가 살아가는 지금 요 시대에
#
# 할 일도 많고 이게 신경 쓸 게 많다 보니까 뭐 연애의 감정이나 이런 사랑의 감정에 이게 빠져 있기가 쉽지 않은데
# ->  할 일도 많고 이게 신경 쓸 게 많다 보니까 뭐 연애의 감정이나 이런 사랑의 감정에 이게 빠져 있기가 쉽지 않은데
#
# 마음이 쫌 그렇게 이케 좀 뭐랄까요 쫌 삭막하고 그런데 어떻게 이런 감성을 유지할 수 있을까 라는 감탄을 사실 좀 했거든요.
# ->  마음이 쫌 그렇게 이케 좀 뭐랄까요 쫌 삭막하고 그런데 어떻게 이런 감성을 유지할 수 있을까 라는 감탄을 사실 좀 했거든요.
#
# 아 그렇지.
# ->  아 그렇지.
#
# 어 제목은 그래서 공통적으로 인제 저는 다 흩어져만 흩어져만 간다가 아무래도 좋겠다 처음에 사실 저는 맘에 걸린 말들이 되게 와닿았는데
# ->  어 제목은 그래서 공통적으로 인제 저는 다 흩어져만 흩어져만 간다가 아무래도 좋겠다 처음에 사실 저는 맘에 걸린 말들이 되게 와닿았는데
#
# 그래도 공통적으로 흩어져만 간다가 좋겠다 라고 생각했는데 갱년기부터 마음이 무너져가면서 제가 @웃음 /(noise)
# ->  그래도 공통적으로 흩어져만 간다가 좋겠다 라고 생각했는데 갱년기부터 마음이 무너져가면서 제가 @웃음
#
# 아이 근데 요게 이제 중의적으로 좀 썼죠 사랑노래로도 읽힐 수 있게 이게 쓰기도 했고 요거는 이제 제가 지금 약간 설정에 맞게 그냥 글을 뭐랄까 의도대로 쓴 시이긴 해요 단어 단어를
# ->  아이 근데 요게 이제 중의적으로 좀 썼죠 사랑노래로도 읽힐 수 있게 이게 쓰기도 했고 요거는 이제 제가 지금 약간 설정에 맞게 그냥 글을 뭐랄까 의도대로 쓴 시이긴 해요 단어 단어를
#
# 그 설정에 맞게 근데 이제 두 번째는 이제 중의적 설정을 뭘 했냐면 엄청 사랑하는 사람을 떠올리면서 근데 이 사람이 죽는 거야 죽은 거야 죽은 거
# ->  그 설정에 맞게 근데 이제 두 번째는 이제 중의적 설정을 뭘 했냐면 엄청 사랑하는 사람을 떠올리면서 근데 이 사람이 죽는 거야 죽은 거야 죽은 거
#
# 이제 이런 마음이지 않을까 한번만 눈을 뜨면 그럴 것 같은데 이제 막 이렇게 막 그~ 내 눈 앞에 흙이 덮이는 장면을 막 상상을 한번 해 봤거든요.
# ->  이제 이런 마음이지 않을까 한번만 눈을 뜨면 그럴 것 같은데 이제 막 이렇게 막 그~ 내 눈 앞에 흙이 덮이는 장면을 막 상상을 한번 해 봤거든요.
#
# 아
# ->  아
#
# 그때 이제 갇혀있던 마음이 너에게 닿을듯 흩어져만 간다 (한 번만)/(1번만) 눈을 뜨면 갈 수 있을 것 같은데 뭐 그런 어떤 심정 요거를 이제 고 이게 양쪽으로 해석될 수 있도록 이걸 단어를 맞추느라
# ->  그때 이제 갇혀있던 마음이 너에게 닿을듯 흩어져만 간다 한 번만 눈을 뜨면 갈 수 있을 것 같은데 뭐 그런 어떤 심정 요거를 이제 고 이게 양쪽으로 해석될 수 있도록 이걸 단어를 맞추느라
#
# 게임 하면서 잠드는 거랑 그리워하는 사람을 그리워하다 죽는 거랑 요거를 (두 개를)/(2개를) 맞추느라 이제 단어를 좀 여러 가지
# ->  게임 하면서 잠드는 거랑 그리워하는 사람을 그리워하다 죽는 거랑 요거를 두 개를 맞추느라 이제 단어를 좀 여러 가지
#
# 게임은 사실 전혀 생각이 (())
# ->  게임은 사실 전혀 생각이
#
# 제가 뭐 정신줄을 딱 잡고 이 시를 되게 시적인 부분을 쫌 제가 좀 첨삭을 해드린다면 여기서 시어의 선택이 일부러 되게 좀
# ->  제가 뭐 정신줄을 딱 잡고 이 시를 되게 시적인 부분을 쫌 제가 좀 첨삭을 해드린다면 여기서 시어의 선택이 일부러 되게 좀
#
# 시의 운율이 중요하다고 했잖아요 이제 운율을 의식한 것으로 보이는 멀어져 작아져 흐려져 흩어져 이런 식어져
# ->  시의 운율이 중요하다고 했잖아요 이제 운율을 의식한 것으로 보이는 멀어져 작아져 흐려져 흩어져 이런 식어져
#
# 이런 표현을 많이 썼는데 실제로 뭐뭐 해지다 라는 표현 자체가 시간의 흐름을 느껴질 수 밖에 없는 단어들이에요 예 그러니까
# ->  이런 표현을 많이 썼는데 실제로 뭐뭐 해지다 라는 표현 자체가 시간의 흐름을 느껴질 수 밖에 없는 단어들이에요 예 그러니까
#
# 어~ 그런 단어들이 이~ 읽는 사람으로 하여금 어떤 그러한 흐름과 어떤 서서히 변해가는 거를 느낄 수 있게 하는 그런 표현들이라고 보이고 운율로도
# ->  어~ 그런 단어들이 이~ 읽는 사람으로 하여금 어떤 그러한 흐름과 어떤 서서히 변해가는 거를 느낄 수 있게 하는 그런 표현들이라고 보이고 운율로도
#
# 굉장히 어 좋은 반복적인 표현이라고 볼 수가 있을 거
# ->  굉장히 어 좋은 반복적인 표현이라고 볼 수가 있을 거
#
# 이게 뭐 곡이다 보니까 당연히 더욱이 은율이 또 좋은 같고 글은 뭐 기본적으로 센스가 좋은 것 같애요.
# ->  이게 뭐 곡이다 보니까 당연히 더욱이 은율이 또 좋은 같고 글은 뭐 기본적으로 센스가 좋은 것 같애요.
#
# 그리고 여기서 이제 노래 하실 때 (한마디)/(1마디) (한 번만)/(1번만) 이거를 좀 짚어서 부르시는 부분이 있었거든요.
# ->  그리고 여기서 이제 노래 하실 때 한마디 한 번만 이거를 좀 짚어서 부르시는 부분이 있었거든요.
#
# 전 그 부분도 되게 운율적으로도 좋고 노래로써도 되게 좋았던 부분
# ->  전 그 부분도 되게 운율적으로도 좋고 노래로써도 되게 좋았던 부분
#
# 그리고 이 노래는 유난히 쫌 공기를 좀 많이 쓰시던데 예. /(noise)
# ->  그리고 이 노래는 유난히 쫌 공기를 좀 많이 쓰시던데 예.
#
# 공기 한 (육십)/(60) 소리 한 (사)/(4)
# ->  공기 한 육십 소리 한 사
#
# 그래서 이 쫌 감성적인 그 감정 전달을 위해서 공기를 쫌 더 쓰신 것 같아요 평소보다
# ->  그래서 이 쫌 감성적인 그 감정 전달을 위해서 공기를 쫌 더 쓰신 것 같아요 평소보다
#
# 음
# ->  음
#
# 그~ 모두의 시라는 게 작가가 쓴 의도가 있지만 또 읽는 사람이 받아들이는 의도 되게 공감이 갔던 게 뭐냐면
# ->  그~ 모두의 시라는 게 작가가 쓴 의도가 있지만 또 읽는 사람이 받아들이는 의도 되게 공감이 갔던 게 뭐냐면
#
# 다들 고민을 하세요 시를 뭘 쓸까를 고민을 하셨던 거잖아요.
# ->  다들 고민을 하세요 시를 뭘 쓸까를 고민을 하셨던 거잖아요.
#
# 그렇죠.
# ->  그렇죠.
#
# 제가 이 노래를 와이프한테 불러줬어요 한번 들어봐라 어떤 느낌이 드냐 다 듣고나서 어떠냐 그러니까 뭐 딴 얘기하더라고요 갑자기 그냥.
# ->  제가 이 노래를 와이프한테 불러줬어요 한번 들어봐라 어떤 느낌이 드냐 다 듣고나서 어떠냐 그러니까 뭐 딴 얘기하더라고요 갑자기 그냥.
#
# 아 근데 우리 애가 오늘 뭐 뭔 일이 있었는데 그래서 그냥 아 그냥 별론가 보다 이러고
# ->  아 근데 우리 애가 오늘 뭐 뭔 일이 있었는데 그래서 그냥 아 그냥 별론가 보다 이러고
#
# 아니 그게 아니라 이 (이 절)/(2절) 땜에 어 나에게 애정이 식었다는 건가 그래서 쫌 말을 돌리신 게 아닐까요? /(noise)
# ->  아니 그게 아니라 이 이 절 땜에 어 나에게 애정이 식었다는 건가 그래서 쫌 말을 돌리신 게 아닐까요?
#
# (()) 뭐 바로 딴 얘기하더라고요 예.
# ->  뭐 바로 딴 얘기하더라고요 예.
#
# 오늘의 하이라이트
# ->  오늘의 하이라이트
#
# 정말 즉석에서 (()) 한 (두세 시간)/(2~3시간) 두드려는데 (열두 시가)/(12시가) 다 돼 가는 거예요.
# ->  정말 즉석에서  한 두세 시간 두드려는데 열두 시가 다 돼 가는 거예요.
#
# 아
# ->  아
#
# 차라리 그 시간에 쓰시지.
# ->  차라리 그 시간에 쓰시지.
#
# 에 그래서 차라리 그냥 쓰겠다 그
# ->  에 그래서 차라리 그냥 쓰겠다 그
#
# 근데 그 다 쓰기 위한 과정이라고 봐야죠.
# ->  근데 그 다 쓰기 위한 과정이라고 봐야죠.
#
# 아 그런가요 예 저도 이제 마지막 시를 그래서 어제 몇 시간을 투자했지만 단 (십 분)/(10분) 만에 시를 써 왔습니다.
# ->  아 그런가요 예 저도 이제 마지막 시를 그래서 어제 몇 시간을 투자했지만 단 십 분 만에 시를 써 왔습니다.
#
# 크
# ->  크
#
# 그렇죠 원래 이게 한순간에 쌓였던 게 탁 터져 터져 나오잖아요.
# ->  그렇죠 원래 이게 한순간에 쌓였던 게 탁 터져 터져 나오잖아요.
#
# 일단 시작하겠습니다.
# ->  일단 시작하겠습니다.
#
# (())
# ->
#
# 비어 있습니다~
# 아이 낭독 하는 목소리에
# ->  아이 낭독 하는 목소리에
#
# 응 울 뻔했어
# ->  응 울 뻔했어
#
# 같이 감정이 격해지네요.
# ->  같이 감정이 격해지네요.
#
# 저는 이제 이걸 들으신 청취자분들은 모르시겠지만 살짝 그 창밖에서 귀뚜라미 소리가 들렸어요 네 그래서 시가 쓰여지지 않는 밤에 이 귀뚜라미 소리가 너무 잘 어울리는 거예요.
# ->  저는 이제 이걸 들으신 청취자분들은 모르시겠지만 살짝 그 창밖에서 귀뚜라미 소리가 들렸어요 네 그래서 시가 쓰여지지 않는 밤에 이 귀뚜라미 소리가 너무 잘 어울리는 거예요.
#
# 좋네요 시가
# ->  좋네요 시가
#
# 의도는 잘 뭐 굳이 설명 안 해주셔도 될 거 같긴 한데 혹시
# ->  의도는 잘 뭐 굳이 설명 안 해주셔도 될 거 같긴 한데 혹시
#
# 뒤지고 뒤지고 뒤졌는데 그 내가 아닌 것 같은 거예요 그리고 참 한심한 거예요.
# ->  뒤지고 뒤지고 뒤졌는데 그 내가 아닌 것 같은 거예요 그리고 참 한심한 거예요.
#
# 근데 그게 다 나지 않을까 라는 생각에 이 시가 쓰여지지 (()) 그 밤에 나는 그것들이 모여서 내가 되었고
# ->  근데 그게 다 나지 않을까 라는 생각에 이 시가 쓰여지지  그 밤에 나는 그것들이 모여서 내가 되었고
#
# 그 밤이 비로써 이 밤에 지금 내 모습두 내가 된 게 아닌가 하면은 그런 마음으로 이 시를 썼습니다.
# ->  그 밤이 비로써 이 밤에 지금 내 모습두 내가 된 게 아닌가 하면은 그런 마음으로 이 시를 썼습니다.
#
# 저 어떤 테마나 어떤 주제를 갖다놔도 결국 쫌 이렇게 안쓰럽게 느껴지는 그런 /(noise)
# ->  저 어떤 테마나 어떤 주제를 갖다놔도 결국 쫌 이렇게 안쓰럽게 느껴지는 그런
#
# (()) /(noise)
# ->
#
# 비어 있습니다~
# 정말 이~ 일관되게 있는 것 같아요 이것도 막
# ->  정말 이~ 일관되게 있는 것 같아요 이것도 막
#
# 그런가요?
# ->  그런가요?
#
# 아 본인을 약간 자학하는 듯한 이런 감성에서 이거 아이 이게막 뭔가 이게 위로해 드리고 싶고 있잖아요 막 그러지 않아요 막 이렇게 말하고 싶은
# ->  아 본인을 약간 자학하는 듯한 이런 감성에서 이거 아이 이게막 뭔가 이게 위로해 드리고 싶고 있잖아요 막 그러지 않아요 막 이렇게 말하고 싶은
#
# 첫 구절이 시가 쓰여지지 않는 밤 이렇게 시작했잖아요.
# ->  첫 구절이 시가 쓰여지지 않는 밤 이렇게 시작했잖아요.
#
# (())
# ->
#
# 비어 있습니다~
# 에
# ->  에
#
# 창의적이다. /(noise)
# ->  창의적이다.
#
# 아무튼 아주 좋네요 예
# ->  아무튼 아주 좋네요 예
#
# 그리고 여기서 이제 운율적으로 내가 되었다 내가 되었다 라는 이제 부분을 반복하신 거하고 낭독도 되게 잘 해주셨지만 이제 마무리가 이제
# ->  그리고 여기서 이제 운율적으로 내가 되었다 내가 되었다 라는 이제 부분을 반복하신 거하고 낭독도 되게 잘 해주셨지만 이제 마무리가 이제
#
# 그것도 좋았어요 여태껏 내가 이제 했던 말들이 내가 돼서 내가 이렇게 시가 쓰이지 않는 밤에 또 이~ 내가 고민하는 것도 또 내가 되고 이런 과정이 되게 좋았던 것 같애요.
# ->  그것도 좋았어요 여태껏 내가 이제 했던 말들이 내가 돼서 내가 이렇게 시가 쓰이지 않는 밤에 또 이~ 내가 고민하는 것도 또 내가 되고 이런 과정이 되게 좋았던 것 같애요.
#
# 수미상관이네요 음.
# ->  수미상관이네요 음.
#
# 성찰이 드러나는 좋은 시였습니다.
# ->  성찰이 드러나는 좋은 시였습니다.
#
# 시밤 시밤보단 훨씬 좋네요. /(noise)
# ->  시밤 시밤보단 훨씬 좋네요.
#
# (()) 쓰는 편 (()) /(noise)
# ->  쓰는 편
#
# 아
# ->  아
#
# 아이
# ->  아이
#
# (()) (네 편의)/(4편의) 시를 다 감상했는데
# ->  네 편의 시를 다 감상했는데
#
# 괜히 갱년기라 그래 가지고 (()) 분위기가
# ->  괜히 갱년기라 그래 가지고  분위기가
#
# 아이 아이 좋았는데 그 예.
# ->  아이 아이 좋았는데 그 예.
#
# 저는 궁금한 게 저는 뭐 평소에도 뭐 글을 쓰고 있으니까 굉장히 그런 거에 이제 어~ 관심이 없으시거나
# ->  저는 궁금한 게 저는 뭐 평소에도 뭐 글을 쓰고 있으니까 굉장히 그런 거에 이제 어~ 관심이 없으시거나
#
# 어 도전을 잘 안 하시다가 이번에 써보시니까 어땠는지 좀 감상을 듣고 싶고요 그리고 이거를 그냥 쓰는 과정에서 좀 새롭게 내가 어떤 느낀거나 신선한 감정 느낀 게 있었는지도 궁금하고
# ->  어 도전을 잘 안 하시다가 이번에 써보시니까 어땠는지 좀 감상을 듣고 싶고요 그리고 이거를 그냥 쓰는 과정에서 좀 새롭게 내가 어떤 느낀거나 신선한 감정 느낀 게 있었는지도 궁금하고
#
# 그리고 여기서 직접 낭독을 하셨잖아요 낭독을 하고 다른 사람 앞에서 뭔가 내 시를 나누는 느낌이 어떠셨는지 그것도 좀 궁금해요.
# ->  그리고 여기서 직접 낭독을 하셨잖아요 낭독을 하고 다른 사람 앞에서 뭔가 내 시를 나누는 느낌이 어떠셨는지 그것도 좀 궁금해요.
#
# 음 조마조마하죠 뭐.
# ->  음 조마조마하죠 뭐.
#
# 어떻게 들릴까?
# ->  어떻게 들릴까?
#
# 그렇죠 다음 주도 우리가 이제 써온 글들을 나눌 텐데 뭐 저는 이제 다음 주가 더 그럴 것 같긴 해요. /(noise)
# ->  그렇죠 다음 주도 우리가 이제 써온 글들을 나눌 텐데 뭐 저는 이제 다음 주가 더 그럴 것 같긴 해요.
#
# 근데 이제 이번 주는 노래이고 일부러 그~ 창작자의 의도를 좀 약간 감춘 가사를 쓴 거 잖아요 저는 예 그러다 보니까 약간 한번 쫌 웃겨 봐야지 이런 좀 욕심도
# ->  근데 이제 이번 주는 노래이고 일부러 그~ 창작자의 의도를 좀 약간 감춘 가사를 쓴 거 잖아요 저는 예 그러다 보니까 약간 한번 쫌 웃겨 봐야지 이런 좀 욕심도
#
# 그쵸 그쵸.
# ->  그쵸 그쵸.
#
# 어 뭐 그런 것도 있었는데 어~ 아무튼 이제 낭독을 아 낭독이 아니죠 저는 이제 노래를 부를 때는 쫌 뭐랄까 이케 아무래도 이게 좀 좋게 들려야 될 텐데 하는 뭐 그런 걱정도 있고 긴장도 좀 있었고
# ->  어 뭐 그런 것도 있었는데 어~ 아무튼 이제 낭독을 아 낭독이 아니죠 저는 이제 노래를 부를 때는 쫌 뭐랄까 이케 아무래도 이게 좀 좋게 들려야 될 텐데 하는 뭐 그런 걱정도 있고 긴장도 좀 있었고
#
# (()) 글을 쓰면서는 저는 그 생각이 제일 많이 들었어요.
# ->  글을 쓰면서는 저는 그 생각이 제일 많이 들었어요.
#
# 이 글을 쓰는 행위가 내가 그냥 내 하고 싶은 말을 내가 쓰고 있나 아니면 내가 누구를 자꾸 의식하면서 쓰고 있나 이 생각이 자꾸 머릿속에 떠나지가 않더라구여.
# ->  이 글을 쓰는 행위가 내가 그냥 내 하고 싶은 말을 내가 쓰고 있나 아니면 내가 누구를 자꾸 의식하면서 쓰고 있나 이 생각이 자꾸 머릿속에 떠나지가 않더라구여.
#
# 그러면서 진짜 내가 된다는 게 또 내 글이 된다는 게 생각보다 어렵다.
# ->  그러면서 진짜 내가 된다는 게 또 내 글이 된다는 게 생각보다 어렵다.
#
# 맞아요.
# ->  맞아요.
#
# 자꾸 이걸 누가 읽으면 어떡하까 뭐 누가 볼 때는 어떻게 보일까 뭐 이런 식의 연상이 자꾸 되더라구요.
# ->  자꾸 이걸 누가 읽으면 어떡하까 뭐 누가 볼 때는 어떻게 보일까 뭐 이런 식의 연상이 자꾸 되더라구요.
#
# (()) 저는 이걸 읽을 사람을 의식하는 건 결코 나쁜 행위라고 생각하지 않아요.
# ->  저는 이걸 읽을 사람을 의식하는 건 결코 나쁜 행위라고 생각하지 않아요.
#
# 그래요 나쁜 행위는 아니구나.
# ->  그래요 나쁜 행위는 아니구나.
#
# 그게 자기 발전으로 위해서도 되게 좋은 거라서
# ->  그게 자기 발전으로 위해서도 되게 좋은 거라서
#
# (()) 이제 고런 생각이 어떤 게 진짜 내 말인가 이런 생각이 (()) 또 좀 비슷하게 들었습니다.
# ->  이제 고런 생각이 어떤 게 진짜 내 말인가 이런 생각이  또 좀 비슷하게 들었습니다.
#
# 네 우리
# ->  네 우리
#
# 어 뭐 막막하기도 하고 (()) 시 뭐 이케 최근에 뭐 이르케 시로 이렇게 뭐 당선됐던 것들 있지 않습니까 좀 읽어보니까
# ->  어 뭐 막막하기도 하고  시 뭐 이케 최근에 뭐 이르케 시로 이렇게 뭐 당선됐던 것들 있지 않습니까 좀 읽어보니까
#
# 그이 과거에 생각했던 시와는 너무 좀 다르고 산문인지 뭔지 알 수 없는 그런 글들이 많고 그 뭐 따른 분야도 다 그렇지만 이게 경계가 좀 많이 무너지고 그런 느낌도 있었구요 그래서 뭐
# ->  그이 과거에 생각했던 시와는 너무 좀 다르고 산문인지 뭔지 알 수 없는 그런 글들이 많고 그 뭐 따른 분야도 다 그렇지만 이게 경계가 좀 많이 무너지고 그런 느낌도 있었구요 그래서 뭐
#
# 뭘 써야 될지 모르겠지만 잘 쓸려고 노력하는 건 큰 의미는 없다 라는 생각을 했고
# ->  뭘 써야 될지 모르겠지만 잘 쓸려고 노력하는 건 큰 의미는 없다 라는 생각을 했고
#
# 음
# ->  음
#
# @웃음 쫌 그냥 뭐 에유 웃기기나 할까 뭐 그런 생각을 쫌 하긴 했었구요.
# ->  @웃음 쫌 그냥 뭐 에유 웃기기나 할까 뭐 그런 생각을 쫌 하긴 했었구요.
#
# 뭔가를 자기의 것을 창작해내는 것이 참 어렵구나 라는 생각이 많이 들고 그걸 또 따른 사람이 잘 받아들이도록
# ->  뭔가를 자기의 것을 창작해내는 것이 참 어렵구나 라는 생각이 많이 들고 그걸 또 따른 사람이 잘 받아들이도록
#
# 잘 정제해서 만드는 건 더욱 어렵구나 그런 생각도 많이 했고 참 세상에 쉬운 게 남이 해놓은 거 가지고 이렇다 저렇다 얘기하는 거구나 그런 생각도 쫌 들었고 그랬습니다.
# ->  잘 정제해서 만드는 건 더욱 어렵구나 그런 생각도 많이 했고 참 세상에 쉬운 게 남이 해놓은 거 가지고 이렇다 저렇다 얘기하는 거구나 그런 생각도 쫌 들었고 그랬습니다.
#
# 그래서 (()) 예전에 그 (에스에프)/(sf) 시라고 해야 되나 그 시를 한번 읽어주시고 했잖아요.
# ->  그래서  예전에 그 에스에프 시라고 해야 되나 그 시를 한번 읽어주시고 했잖아요.
#
# 그래서 이게 문턱이 너무 높아서 굉장히 부담스러웠습니다 이거 준비 할 때
# ->  그래서 이게 문턱이 너무 높아서 굉장히 부담스러웠습니다 이거 준비 할 때
#
# 아 그건 저의 잘못이죠.
# ->  아 그건 저의 잘못이죠.
#
# 저는 시가 되게 다른 문학작품보다 유독 되게 사람들이 문턱을 높게 여기는 이유가 되게 뭔가 대단한 걸 쓰는 게 시라고 생각하시는 경향이 있으신 것 같애서
# ->  저는 시가 되게 다른 문학작품보다 유독 되게 사람들이 문턱을 높게 여기는 이유가 되게 뭔가 대단한 걸 쓰는 게 시라고 생각하시는 경향이 있으신 것 같애서
#
# 뭐 당선집도 뒤져보셨다고 했는데 실제로 당선 기준도 쫌 그런 게 있어요 없지 않아 그래서 저는 일상 시나 그냥 일반 분들의 (에스앤에스에)/(sns에) 올리는 그런 짧은 단상 같은 것들이
# ->  뭐 당선집도 뒤져보셨다고 했는데 실제로 당선 기준도 쫌 그런 게 있어요 없지 않아 그래서 저는 일상 시나 그냥 일반 분들의 에스앤에스에 올리는 그런 짧은 단상 같은 것들이
#
# 다 시다 사실은 그렇게 생각을 해요.
# ->  다 시다 사실은 그렇게 생각을 해요.
#
# 네
# ->  네
#
# 그렇죠.
# ->  그렇죠.
#
# 그렇죠.
# ->  그렇죠.
#
# 저기 어렵죠 근데 이게 이분이 하고 싶었던 말이 제가 하고 싶었던 말이어서 까 뭐 울컥 뭔가 하고 싶은데
# ->  저기 어렵죠 근데 이게 이분이 하고 싶었던 말이 제가 하고 싶었던 말이어서 까 뭐 울컥 뭔가 하고 싶은데
#
# 그걸 어떻게 표현할지 모를 때 막 (()) 끄적그려 근데 그게 다 연습이었던 거야 이제 보니까 (()) 평생 이 사람이 시인이란 사람 이름으로 직업을 살아왔는데
# ->  그걸 어떻게 표현할지 모를 때 막  끄적그려 근데 그게 다 연습이었던 거야 이제 보니까  평생 이 사람이 시인이란 사람 이름으로 직업을 살아왔는데
#
# 지내놓고 보고 만들어놓고 보니까 그게 다 연습이었고 그러다 보니까 너무 허무한 거예요.
# ->  지내놓고 보고 만들어놓고 보니까 그게 다 연습이었고 그러다 보니까 너무 허무한 거예요.
#
# 음
# ->  음
#
# 그런 마음
# ->  그런 마음
#
# 자체가 시일 수 있다.
# ->  자체가 시일 수 있다.
#
# 예 우리가 되게 아까 똑같은 얘기인데 되게 어렵게 생각했던 그런 것들 근데 그냥 내 생각을 좀 정제하고 적어보는 거 근데 글로 적어 본다는 거는 어떤 정의를 내리는 거라는 생각이 가끔 들거든요.
# ->  예 우리가 되게 아까 똑같은 얘기인데 되게 어렵게 생각했던 그런 것들 근데 그냥 내 생각을 좀 정제하고 적어보는 거 근데 글로 적어 본다는 거는 어떤 정의를 내리는 거라는 생각이 가끔 들거든요.
#
# 음
# ->  음
#
# 까 정의되지 않는 것들을 내가 정의함으로써 분명하게 볼 수 있는 것들이 생기지 않을까 (()) 시를 써본다는 건 이 밤에 예.
# ->  까 정의되지 않는 것들을 내가 정의함으로써 분명하게 볼 수 있는 것들이 생기지 않을까  시를 써본다는 건 이 밤에 예.
#
# 내 마음이
# ->  내 마음이
#
# 내 마음을
# ->  내 마음을
#
# 분명하게
# ->  분명하게
#
# 까 내가 되었다는 내 시처럼 이게 이게 그게 되는 게 아닌가 저는 개인적으로 요번 시를 쓰면서 그런 생각이 좀 들었어요.
# ->  까 내가 되었다는 내 시처럼 이게 이게 그게 되는 게 아닌가 저는 개인적으로 요번 시를 쓰면서 그런 생각이 좀 들었어요.
#
# 알겠습니다.
# ->  알겠습니다.
#
# 뭐 나머지 우리 청취자분들도 (()) 가을밤
# ->  뭐 나머지 우리 청취자분들도  가을밤
#
# 낭만적인 밤 되시기 (()) /(noise)
# ->  낭만적인 밤 되시기
#
# ----------------------------------------

# %%
# 데이터셋 폴더를 10GB 단위로 쪼개서 저장하는 코드에요.

import os
import shutil
from tqdm import tqdm

# 기본 디렉토리 설정
base_dir = "/mnt/a/maxseats/(주의-원본-680GB)주요 영역별 회의 음성인식 데이터"
output_base_dir = "/mnt/a/maxseats/split_files"  # 나눌 폴더의 기본 디렉토리

# 최대 폴더 크기 (10GB)
max_folder_size = 10 * 1024 * 1024 * 1024  # 10GB in bytes

# 파일 목록 수집
file_sets = {}
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".json") or file.endswith(".txt") or file.endswith(".wav"):
            base_name = os.path.splitext(file)[0]
            if base_name not in file_sets:
                file_sets[base_name] = []
            file_sets[base_name].append(os.path.join(root, file))

# 파일을 10GB씩 나누어 저장
folder_index = 0
current_folder_size = 0
current_folder_files = []

file_sets_items = list(file_sets.items())
total_files = sum(len(files) for files in file_sets.values())

with tqdm(total=total_files, desc="Processing files") as pbar:
    for base_name, files in file_sets_items:
        set_size = sum(os.path.getsize(f) for f in files)
        
        if current_folder_size + set_size > max_folder_size:
            folder_path = os.path.join(output_base_dir, f"set_{folder_index}")
            os.makedirs(folder_path, exist_ok=True)
            
            for f in current_folder_files:
                shutil.copy(f, folder_path)
                pbar.update(1)
            
            folder_index += 1
            current_folder_size = 0
            current_folder_files = []
        
        current_folder_files.extend(files)
        current_folder_size += set_size

    # 마지막 폴더 저장
    if current_folder_files:
        folder_path = os.path.join(output_base_dir, f"set_{folder_index}")
        os.makedirs(folder_path, exist_ok=True)
        
        for f in current_folder_files:
            shutil.copy(f, folder_path)
            pbar.update(1)

print("Files have been split into folders.")
# Out:
# Processing files:  36%|███▋      | 9762/26826 [44:25<1:29:57,  3.16it/s]
